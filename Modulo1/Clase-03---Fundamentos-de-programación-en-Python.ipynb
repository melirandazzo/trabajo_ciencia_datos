# %% [markdown]
# # CLASE 3 - Introducción a Python
# ### Coderhouse - Data Science
# Profe Jorge Ruiz

# %% [markdown]
# #### Apuntar variables

# %%
p_juan= 78

# %%
p_juan
# Out:
# 78

# %%
x = 10 # Número
y = 20 # número
z = "2022" # Texto
v = 'Enero' # Texto
w = 0.5 # Decimales con punto
u = (0,6, 8) # que pasa con la coma?

# %% [markdown]
# Voy a guardar el valor de la gravedad en la variable g

# %%
g= 9.8

# %%
u
# Out:
# (0, 6, 8)

# %%
x=1.0
x.is_integer()
# Out:
# True

# %% [markdown]
# #### Identificar tipo de variables

# %%
type(y)
# Out:
# int

# %%
type(u)
# Out:
# tuple

# %%
type(z) #string
# Out:
# str

# %%
type(w)

# %%
type(q)

# %% [markdown]
# #### Ver lo que hay dentro de una variable

# %%
w

# %%
x
w

# %%
print(x)
print(w)
# Out:
# 1.0
# 0.5

# %%
print ("hola mundo")
# Out:
# hola mundo

# %%
print(v, z)
# Out:
# Enero 2022

# %% [markdown]
# #### Otros tipos - estructuras de datos

# %%
lista = [10, 10.5, 'hola']
lista
# Out:
# [10, 10.5, 'hola']

# %%
print(type(lista))
# Out:
# <class 'list'>

# %%
diccionario = {
    'nombre':'Juan',
    'edad':13,
    'profesion':'estudiante'
}
diccionario
# Out:
# {'nombre': 'Juan', 'edad': 13, 'profesion': 'estudiante'}

# %%
print(type(diccionario))
# Out:
# <class 'dict'>

# %%
booleanos = True # tambien puede ser False
booleanos

# %%
print(type(booleanos))

# %% [markdown]
# # Ejercicio

# %%
x = 1
type(x)
# Out:
# int

# %%
print(x)
x = "hola"
print(x)

# %%
x = [1, 2, 3] #listas
y = x
print(y, x)
# Out:
# [1, 2, 3] [1, 2, 3]

# %%
x.append(4)
print(y)
# Out:
# [1, 2, 3, 4]

# %%
x = 5
print(x, y)

# %% [markdown]
# # Ejercicio

# %%
x = [1, 2, 3]   # x es una lista
y = x           # el objeto al que apunta x ([1, 2, 3]) ahora es también
                # apuntado por y

# %%
print(y is x)   # x e y son el mismo objeto (True)
print(x, y)
# Out:
# True
# [1, 2, 3] [1, 2, 3]

# %%
x.append(4)     # aquí operó sobre el objeto [1, 2, 3] apuntado por x.
                # Los métodos se identifican luego de un punto (x.método())
print(y)        # como x e y apuntan al mismo objeto, y refleja los cambios
# Out:
# [1, 2, 3, 4]

# %%
x = "hola"      # al realizar asignación, ahora x apunta al objeto texto
                # (string) "hola"
print(x is y)   # x e y ahora no apuntan al mismo objeto (False)
print(x, y)     # x e y apuntan a dos objetos diferentes (“hola” [1, 2, 3, 4])
# Out:
# False
# hola [1, 2, 3, 4]

# %% [markdown]
# #### Operadores aritméticos

# %%
a = 8
b = 5

# %%
# Suma
print("suma:",a + b)

# Resta
print("resta:",a - b)

# Multiplicación
print("multiplicación:", a * b)

# División
print("División:",a / b)

# División entera (resultado sin decimal)
print("División entera:",a // b)

# Módulo (resto de la división entera)
print("Módulo (resto de la división entera):",a % b)

# Exponenciación
print("Exponenciación:", a ** b)

# Negativo
print("Negativo:",-a)
# Out:
# suma: 13
# resta: 3
# multiplicación: 40
# División: 1.6
# División entera: 1
# Módulo (resto de la división entera): 3
# Exponenciación: 32768
# Negativo: -8

# %% [markdown]
# #### Operadores de asignaciones

# %%
a = 100
b = 4

# a = a + b
a += b
print(a)

#a = a - b
a -= b
print(a)

#a = a * b
a *= b
print(a)

#a = a / b
a /= b
print(a)

#a = a // b
a //= b
print(a)

#a = a % b
a %= b
print(a)

#a = a ** b
a **= b
print(a)
# Out:
# 104
# 100
# 400
# 100.0
# 25.0
# 1.0
# 1.0

# %% [markdown]
# #### Operadores de comparación o lógicos

# %%
a = 5
b = 10

# igual a
print(a == b)

# distinto de
print(a != b)

# menor que
print(a < b)

# mayor que
print(a > b)

# menor o igual que
print(a <= b)

# mayor o igual que
print(a >= b)
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# #### Operadores de identidad y pertenecia

# %%
a = 10
b = [10, 5, 30]

# es el mismo objeto que
print(a is b)
# no es el mismo objeto que
print(a is not b)

### se utilizan con listas principalmente
# esta contenido en
print(a in b)
# no esta contenido en
print(a not in b)
# Out:
# False
# True
# True
# False

# %%
"j"  in "hola"
# Out:
# False

# %% [markdown]
# # DUDAS ADICIONALES

# %%
# ¿es posible usar operaciones con datos de diferente tipo?
a = 3
b = 'texto'

print(a + b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\jorge\Documents\fundamentos ds 1\clase 3 Hola python\Clase 03 - Fundamentos de programación en Python.ipynb Celda 51 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/jorge/Documents/fundamentos%20ds%201/clase%203%20Hola%20python/Clase%2003%20-%20Fundamentos%20de%20programaci%C3%B3n%20en%20Python.ipynb#Y101sZmlsZQ%3D%3D?line=1'>2</a> a = 3
#       <a href='vscode-notebook-cell:/c%3A/Users/jorge/Documents/fundamentos%20ds%201/clase%203%20Hola%20python/Clase%2003%20-%20Fundamentos%20de%20programaci%C3%B3n%20en%20Python.ipynb#Y101sZmlsZQ%3D%3D?line=2'>3</a> b = 'texto'
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jorge/Documents/fundamentos%20ds%201/clase%203%20Hola%20python/Clase%2003%20-%20Fundamentos%20de%20programaci%C3%B3n%20en%20Python.ipynb#Y101sZmlsZQ%3D%3D?line=4'>5</a> print(a + b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# En general no, pero hay algunas excepciones
a = 3
b = 'texto'
print(a * b)
# Out:
# textotextotexto

# %%
# ¿es posible usar operadores aritméticos con datos que no sean números?
a = 'Hola '
b = 'Mundo'

print(a * b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-08cde3fe88e5> in <cell line: 5>()
#       3 b = 'Mundo'
#       4
# ----> 5 print(a * b)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %% [markdown]
# respuesta

# %%
# la respuesta es NO, no obstante, hay operaciones que se pueden realizar y que tienen notaciones similares
# ejemplo:
a = 'Hola '
b = 'Mundo'
print(a + b) # Concatenar
# En el caso de los operadores de asignación la respuesta es la misma
a += b # a = a + b
print(a)
# los operadores logicos si funcionan con texto
print(a == b)
print(a != b)
print(a >= b)
# Out:
# Hola Mundo
# Hola Mundo
# False
# True
# False

# %%
"HOLA"=="hola"
# Out:
# False

# %%
# los operadores de identidad si funcionan con texto
a = 'Hola '
b = 'a'
print(a is b)
print(a is not b)
print(b in a)
print(b not in a)
# Out:
# False
# True
# True
# False

# %%
2>10 or 3>10
# Out:
# False

# %%
10>2 or 3>10
# Out:
# True

# %%
10>5 or 20>1
# Out:
# True

# %%
2>10 and 3>10
# Out:
# False

# %%
10>5 and 2>1
# Out:
# True
