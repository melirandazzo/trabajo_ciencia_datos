# %% [markdown]
# <a href="https://colab.research.google.com/github/melirandazzo/trabajo_ciencia_datos/blob/main/Unicornios(NICO).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##UNICORNIOS
#
# 1. Leer el dataframe compartido en la carpeta y determinar su shape.
# 2. Convertir las columnas Country, City, e Industry al tipo de dato que consideren adecuado.
# 3. Evaluar valores perdidos y eliminar, si creen preciso, alguna de las columnas.
# 4. Ver si existe alguna relación entre la valuación y su año de fundación.
# 5. Generar alguna visualización que consideren relevante para entender la info que presenta el dataset (ie. países con más unicornios, empresas mejor valuadas, año de fundación con más impacto, etc).
#
# * Para ello importar todas las paqueterías que consideren necesarias.

# %%
# https://drive.google.com/file/d/1s-Ro-ay2M-OCOcb7ELdBJ5A8f4YnhI1O/view?usp=sharing
! gdown --id 1s-Ro-ay2M-OCOcb7ELdBJ5A8f4YnhI1O
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1s-Ro-ay2M-OCOcb7ELdBJ5A8f4YnhI1O
# To: /content/Unicorn_Companies.csv
# 100% 153k/153k [00:00<00:00, 71.0MB/s]

# %%
# !pip install gspread pandas openpyxl

# %%
import gspread as gs
import pandas as pd
import numpy as np

from google.colab import auth
auth.authenticate_user()

# %%
# URL del archivo CSV en Google Drive (convertida en enlace directo)
csv_df = "https://drive.google.com/uc?id=1s-Ro-ay2M-OCOcb7ELdBJ5A8f4YnhI1O&export=download"
# Leer el archivo CSV en un DataFrame de pandas
df = pd.read_csv(csv_df)
# Mostrar las primeras filas del DataFrame
df.head()
# Out:
#       Company  Valuation (B) Date Joined        Country           City  \
# 0   Bytedance          140.0    4/7/2017          China        Beijing
# 1      SpaceX          100.3   12/1/2012  United States      Hawthorne
# 2      Stripe           95.0   1/23/2014  United States  San Francisco
# 3      Klarna           45.6  12/12/2011         Sweden      Stockholm
# 4  Epic Games           42.0  10/26/2018  United States           Cary
#
#                   Industry                                  Select Inverstors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 3                  Fintech  Institutional Venture Partners, Sequoia Capita...
# 4                    Other              Tencent Holdings, KKR, Smash Ventures
#
# ...

# %%
df.describe()
# Out:
#        Valuation (B)  Founded Year  Investors Count   Deal Terms  \
# count    1037.000000    986.000000      1028.000000  1000.000000
# mean        3.292083   2012.693712        14.372568     3.100000
# std         7.309781      5.960232         9.680299     2.165338
# min         1.000000   1919.000000         1.000000     1.000000
# 25%         1.080000   2011.000000         8.000000     1.000000
# 50%         1.600000   2014.000000        13.000000     3.000000
# 75%         3.100000   2016.000000        18.250000     4.000000
# max       140.000000   2021.000000        85.000000    19.000000
#
#        Portfolio Exits
# count        49.000000
# mean          1.346939
# std           0.751416
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1037 entries, 0 to 1036
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1037 non-null   object
#  1   Valuation (B)      1037 non-null   float64
#  2   Date Joined        1037 non-null   object
#  3   Country            1037 non-null   object
#  4   City               1037 non-null   object
#  5   Industry           1037 non-null   object
#  6   Select Inverstors  1020 non-null   object
#  7   Founded Year       986 non-null    float64
#  8   Total Raised       1005 non-null   object
#  9   Financial Stage    49 non-null     object
#  10  Investors Count    1028 non-null   float64
#  11  Deal Terms         1000 non-null   float64
#  12  Portfolio Exits    49 non-null     float64
# dtypes: float64(5), object(8)
# memory usage: 105.4+ KB

# %%
#Cambiar tipo de datos
df['City'] = df['City'].astype('category')
df['Country'] = df['Country'].astype('category')
df['Industry'] = df['Industry'].astype('category')

# %%
df['City'].dtype
# Out:
# CategoricalDtype(categories=['Aarhus', 'Aberdeen', 'Alameda', 'Alexandria', 'Altrincham',
#                   'Ambler', 'Amsterdam', 'Andheri', 'Arlington',
#                   'Artificial intelligence',
#                   ...
#                   'Washington', 'Washington DC', 'Waterloo', 'Westerville',
#                   'Wilmington', 'Wuhan', 'Wuxi', 'Zephyr Cove', 'Zhuhai',
#                   'Zurich'],
# , ordered=False, categories_dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1037 entries, 0 to 1036
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1037 non-null   object
#  1   Valuation (B)      1037 non-null   float64
#  2   Date Joined        1037 non-null   object
#  3   Country            1037 non-null   category
#  4   City               1037 non-null   category
#  5   Industry           1037 non-null   category
#  6   Select Inverstors  1020 non-null   object
#  7   Founded Year       986 non-null    float64
#  8   Total Raised       1005 non-null   object
#  9   Financial Stage    49 non-null     object
#  10  Investors Count    1028 non-null   float64
#  11  Deal Terms         1000 non-null   float64
#  12  Portfolio Exits    49 non-null     float64
# dtypes: category(3), float64(5), object(5)
# memory usage: 98.0+ KB

# %%
#Ver cantidad de nulos
df.isnull().sum()
# Out:
# Company                0
# Valuation (B)          0
# Date Joined            0
# Country                0
# City                   0
# Industry               0
# Select Inverstors     17
# Founded Year          51
# Total Raised          32
# Financial Stage      988
# Investors Count        9
# Deal Terms            37
# Portfolio Exits      988
# dtype: int64

# %%
#axis 0 -> elimina filas; axis 1 columna
df.drop('Select Inverstors', axis=1)
# Out:
#            Company  Valuation (B) Date Joined        Country           City  \
# 0        Bytedance          140.0    4/7/2017          China        Beijing
# 1           SpaceX          100.3   12/1/2012  United States      Hawthorne
# 2           Stripe           95.0   1/23/2014  United States  San Francisco
# 3           Klarna           45.6  12/12/2011         Sweden      Stockholm
# 4       Epic Games           42.0  10/26/2018  United States           Cary
# ...            ...            ...         ...            ...            ...
# 1032     Timescale            1.0   2/22/2022  United States       New York
# 1033      Scalapay            1.0   2/23/2022          Italy          Milan
# 1034  Omada Health            1.0   2/23/2022  United States  San Francisco
# 1035    BlueVoyant            1.0   2/23/2022  United States       New York
# 1036          Veev            1.0   2/24/2022  United States      San Mateo
#
# ...
