# %% [markdown]
# <a href="https://colab.research.google.com/github/melirandazzo/trabajo_ciencia_datos/blob/main/NPL_Randazzo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NPL Carta natal personal

# %% [markdown]
# ## Instalar librerias

# %%
# !pip install python-docx==0.8.11
# Out:
# Collecting python-docx==0.8.11
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 41.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from python-docx==0.8.11) (5.3.0)
# Building wheels for collected packages: python-docx
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184488 sha256=f777e6c7dacc20ae5e276978e1dd5a3e05b89ff0508fb5c2b382b88e7ba0b8f1
#   Stored in directory: /root/.cache/pip/wheels/80/27/06/837436d4c3bd989b957a91679966f207bfd71d358d63a8194d
# Successfully built python-docx
# Installing collected packages: python-docx
# Successfully installed python-docx-0.8.11

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.6)

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.13.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (4.66.6)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %%
import requests
from docx import Document
import nltk
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import spacy
from nltk.stem import PorterStemmer
from textblob import TextBlob
from sklearn.feature_extraction.text import TfidfVectorizer
from transformers import pipeline
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt_tab')
nltk.download('stopwords')
# !python -m spacy download en_core_web_sm
nltk.download('averaged_perceptron_tagger_eng')
nltk_stopwords = nltk.corpus.stopwords.words('english')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 83.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.13.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.2)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.

# %% [markdown]
# ### Carga de documento

# %%
# Descargar el documento
def download_file(url, local_path):
    with requests.get(url, stream=True) as r:
        r.raise_for_status()
        with open(local_path, 'wb') as f:
            for chunk in r.iter_content(chunk_size=8192):
                f.write(chunk)

# Cargar el archivo .docx
def extract_text_from_docx(file_path):
    document = Document(file_path)
    full_text = []
    for para in document.paragraphs:
        full_text.append(para.text)
    return '\n'.join(full_text)

url = 'https://github.com/melirandazzo/trabajo_ciencia_datos/raw/main/Carta_natal.docx'
local_file_path = 'Carta_natal.docx'
download_file(url, local_file_path)

# Ruta del archivo .docx (local path)
file_path = local_file_path

# Extraer el texto
extracted_text = extract_text_from_docx(file_path)

# %% [markdown]
# ### Limpieza y tokenización

# %%
def preprocess_text(text):
    # Convertir el texto a minúsculas
    text = text.lower()
    # Remover caracteres no alfabéticos
    text = re.sub(r'[^a-záéíóúüñ\s]', '', text)
    # Tokenizar el texto
    tokens = word_tokenize(text)
    # Remover stopwords
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [word for word in tokens if word not in stop_words]
    return filtered_tokens


# Preprocesar el texto y mostrar los tokens
preprocessed_tokens = preprocess_text(extracted_text)
print("\nTokens preprocesados:")
print(preprocessed_tokens)
# Out:
# Tokens preprocesados:
# ['st', 'house', 'ascendant', 'asc', 'physical', 'personality', 'ascendant', 'asc', 'symbolizes', 'basic', 'personality', 'traits', 'physical', 'appearance', 'temperament', 'behaviour', 'relationship', 'life', 'first', 'impression', 'person', 'gives', 'ascendant', 'capricorn', 'capricorn', 'ruler', 'saturn', 'people', 'capricorn', 'ascendant', 'must', 'first', 'become', 'aware', 'two', 'opposing', 'sides', 'one', 'obedience', 'performing', 'duties', 'properly', 'need', 'manage', 'energy', 'well', 'requires', 'discipline', 'selfcontrol', 'must', 'achieve', 'social', 'prestige', 'recognition', 'side', 'ability', 'organize', 'practical', 'matters', 'achieve', 'goals', 'also', 'ability', 'enjoy', 'sensual', 'pleasures', 'ruler', 'ascendant', 'saturn', 'people', 'tend', 'act', 'slowly', 'caution', 'avoid', 'kind', 'control', 'love', 'solitude', 'hate', 'crowds', 'want', 'stand', 'isolate', 'others', 'actions', 'valued', 'time', 'may', 'become', 'politicians', 'consultants', 'engineers', 'etc', 'main', 'feature', 'endurance', 'ruler', 'ascendant', 'saturn', 'capricorn', 'people', 'raise', 'slowly', 'steadily', 'without', 'others', 'noticing', 'actions', 'glamorous', 'creditable', 'constructive', 'push', 'accordance', 'time', 'ruler', 'ascendant', 'saturn', 'th', 'house', 'people', 'predestined', 'hide', 'run', 'away', 'subject', 'illusions', 'closing', 'others', 'rich', 'inner', 'life', 'social', 'life', 'may', 'cause', 'life', 'test', 'selfpunishment', 'selfdestruction', 'may', 'occur', 'planets', 'st', 'house', 'planet', 'ascendant', 'aspects', 'square', 'moon', 'separating', 'trine', 'jupiter', 'separating', 'contraparallel', 'mercury', 'th', 'house', 'medium', 'coeli', 'mc', 'career', 'prestige', 'reputation', 'medium', 'coeli', 'mc', 'symbolizes', 'social', 'status', 'career', 'reputation', 'honours', 'fame', 'success', 'authoritative', 'personality', 'father', 'th', 'house', 'libra', 'libra', 'ruler', 'venus', 'people', 'libra', 'tenth', 'house', 'cusp', 'often', 'business', 'work', 'together', 'partner', 'may', 'also', 'work', 'project', 'together', 'people', 'people', 'job', 'seem', 'professional', 'calm', 'prudent', 'kind', 'tactful', 'working', 'also', 'cultured', 'organised', 'become', 'supervisors', 'administrators', 'best', 'objective', 'aspects', 'personality', 'revealed', 'communicate', 'public', 'ruler', 'th', 'house', 'venus', 'th', 'house', 'career', 'people', 'related', 'entertainment', 'games', 'theatre', 'possibility', 'creative', 'activity', 'profession', 'people', 'love', 'job', 'often', 'authority', 'area', 'planets', 'th', 'house', 'pluto', 'mc', 'aspects', 'trine', 'sun', 'applying', 'opposition', 'moon', 'applying', 'interpretations', 'planets', 'signs', 'planets', 'houses', 'planets', 'describe', 'certain', 'process', 'happening', 'eg', 'mars', 'fights', 'saturn', 'limits', 'jupiter', 'expands', 'sign', 'planet', 'located', 'determines', 'planet', 'manifesting', 'example', 'mars', 'may', 'manifest', 'way', 'aries', 'would', 'behave', 'vigorously', 'irritably', 'manner', 'taurus', 'slowly', 'gradually', 'consistently', 'houses', 'show', 'special', 'areas', 'everyday', 'life', 'takes', 'place', 'location', 'house', 'shows', 'whether', 'example', 'mars', 'manifests', 'relationships', 'th', 'house', 'employment', 'th', 'house', 'family', 'th', 'house', 'elsewhere', 'hint', 'planets', 'show', 'us', 'happening', 'signs', 'show', 'us', 'happening', 'houses', 'show', 'us', 'happening', 'planets', 'sun', 'self', 'individuality', 'personality', 'sun', 'symbolizes', 'personal', 'identity', 'shows', 'us', 'areas', 'person', 'learn', 'independent', 'fulfill', 'potential', 'differentiate', 'others', 'shine', 'position', 'sun', 'may', 'tell', 'us', 'profession', 'would', 'best', 'suit', 'character', 'person', 'sun', 'gemini', 'people', 'born', 'sign', 'gemini', 'people', 'many', 'talents', 'able', 'use', 'skills', 'theory', 'practice', 'intelligent', 'quickwitted', 'people', 'interested', 'everything', 'happen', 'around' ...

# %%
# Análisis de frecuencia de palabras
def get_most_frequent_words(tokens, n=10):
    word_freq = Counter(tokens)
    most_common = word_freq.most_common(n)
    return most_common

# Obtener y mostrar las palabras más frecuentes
most_frequent_words = get_most_frequent_words(preprocessed_tokens)
print("\nPalabras más frecuentes:")
print(most_frequent_words)
# Out:
# Palabras más frecuentes:
# [('people', 128), ('house', 48), ('separating', 48), ('life', 39), ('often', 39), ('aspect', 39), ('venus', 34), ('sun', 33), ('saturn', 29), ('also', 28)]

# %%
def plot_wordcloud(tokens, title):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(tokens))
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(title)
    plt.show()

# Visualizar las palabras con una nube de palabras
plot_wordcloud(preprocessed_tokens, '')

# %% [markdown]
# # Evaluar caracteristicas personales

# %%
# Lista de signos zodiacales y sus elementos
zodiac_signs = {
    'aries': 'fire', 'taurus': 'earth', 'gemini': 'air', 'cancer': 'water',
    'leo': 'fire', 'virgo': 'earth', 'libra': 'air', 'scorpio': 'water',
    'sagittarius': 'fire', 'capricorn': 'earth', 'aquarius': 'air', 'pisces': 'water'
}

# Filtrar y contar signos zodiacales
def filter_and_count_zodiac_signs(tokens):
    filtered_signs = [word for word in tokens if word in zodiac_signs]
    sign_counts = Counter(filtered_signs)
    return sign_counts

def plot_element_wordcloud(sign_counts):
    # Convertir los signos a sus elementos correspondientes
    element_counts = Counter()
    for sign, count in sign_counts.items():
        element = zodiac_signs[sign]
        element_counts[element] += count

    wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(element_counts)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title('Nube de Palabras de Elementos astrales')
    plt.show()

# Filtrar y contar signos zodiacales
zodiac_sign_counts = filter_and_count_zodiac_signs(preprocessed_tokens)
print("\nFrecuencia de signos zodiacales:")
print(zodiac_sign_counts)

plot_element_wordcloud(zodiac_sign_counts)
# Out:
# Frecuencia de signos zodiacales:
# Counter({'capricorn': 11, 'gemini': 9, 'taurus': 5, 'pisces': 5, 'libra': 3, 'sagittarius': 3, 'scorpio': 3, 'aries': 2, 'virgo': 2})

# %%
plot_wordcloud(zodiac_sign_counts, "Nube de signos zodiacales")

# %%
planets = ['mercury', 'venus', 'earth', 'mars', 'jupiter', 'saturn', 'uranus', 'neptune', 'pluto', 'moon', 'sun']
# Filtrar y contar signos zodiacales
def filter_and_count_planets(tokens):
    filtered_signs = [word for word in tokens if word in planets]
    sign_counts = Counter(filtered_signs)
    return sign_counts

plot_wordcloud(filter_and_count_planets(preprocessed_tokens), "Nube de planetas zodiacales")

# %%
import spacy

# Cargar el modelo de spaCy en inglés (asegúrate de tener instalado 'en_core_web_sm')
nlp = spacy.load('en_core_web_sm')

# Función para extraer conceptos clave de la personalidad
def extract_key_concepts(text):
    doc = nlp(text)
    keywords = []

    for token in doc:
        # Filtrar adjetivos y sustantivos que podrían describir personalidad
        if token.pos_ in ['ADJ', 'NOUN'] and not token.is_stop:
            keywords.append(token.text)

    # Extraer entidades nombradas (pueden indicar aspectos de la carta)
    entities = [ent.text for ent in doc.ents]

    # Combinar y eliminar duplicados
    key_concepts = set(keywords + entities)

    return key_concepts

# Extraer conceptos clave
concepts = extract_key_concepts(extracted_text)

plot_wordcloud(concepts, "Conceptos clave de la personalidad")

# %% [markdown]
# ## Lematización

# %%
# Cargar el modelo de spaCy
nlp = spacy.load("en_core_web_sm")

doc = nlp(extracted_text)
lemmatized_text = [(token.text, token.lemma_) for token in doc]
print("Lematización:")
for word, lemma in lemmatized_text:
    print(f"{word} -> {lemma}")
# Out:
# Streaming output truncated to the last 5000 lines.
# ° -> °
# 22 -> 22
# ’ -> '
# , -> ,
# Applying -> apply
# ) -> )
#
#  ->
#
# Opposition -> Opposition
# Mercury -> Mercury
# ( -> (
# 5 -> 5
# ° -> °
# 54 -> 54
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# Opposition -> Opposition
# Venus -> Venus
# ( -> (
# 5 -> 5
# ° -> °
# 56 -> 56
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# Conjunction -> Conjunction
# Uranus -> Uranus
# ( -> (
# 0 -> 0
# ° -> °
# 32 -> 32
# ’ -> '
# , -> ,
# Applying -> apply
# ) -> )
#
#  ->
#
# Contra -> Contra
# - -> -
# Parallel -> Parallel
# Sun -> Sun
# ( -> (
# 0 -> 0
# ° -> °
# 43 -> 43
# ’ -> '
# ) -> )
#
#  ->
#
# Contra -> Contra
# - -> -
# Parallel -> Parallel
# Venus -> Venus
# ( -> (
# 0 -> 0
# ° -> °
# 53 -> 53
# ’ -> '
# ) -> )
#
#  ->
#
# Parallel -> Parallel
# Neptune -> Neptune
# ( -> (
# 0 -> 0
# ° -> °
# 10 -> 10
# ’ -> '
# ) -> )
#
#
#   ->
#
#
# Uranus -> Uranus
# - -> -
# Originality -> Originality
# , -> ,
# freedom -> freedom
# , -> ,
# revolution -> revolution
#
#  ->
#
# Uranus -> Uranus
# is -> be
# the -> the
# power -> power
# of -> of
# awakening -> awakening
# , -> ,
# which -> which
# often -> often
# means -> mean
# that -> that
# there -> there
# will -> will
# be -> be
# some -> some
# disruption -> disruption
# and -> and
# change -> change
# . -> .
# Events -> event
# under -> under
# the -> the
# influence -> influence
# of -> of
# Uranus -> Uranus
# are -> be
# unexpected -> unexpected
# or -> or
# unpredictable -> unpredictable
# , -> ,
# forcing -> force
# us -> we
# to -> to
# do -> do
# things -> thing
# in -> in
# a -> a
# new -> new
# way -> way
# and -> and
# face -> face
# the -> the
# truth -> truth
# about -> about
# this -> this
# or -> or
# that -> that
# issue -> issue
# . -> .
#
#
#  ->
#
#
# Uranus -> Uranus
# in -> in
# Sagittarius -> Sagittarius
#
#  ->
#
# ( -> (
# Note -> note
# : -> :
# Uranus -> Uranus
# is -> be
# a -> a
# slow -> slow
# transpersonal -> transpersonal
# planet -> planet
# and -> and
# may -> may
# remain -> remain
# in -> in
# a -> a
# single -> single
# sign -> sign
# for -> for
# up -> up
# to -> to
# many -> many
# years -> year
# . -> .
# The -> the
# description -> description
# of -> of
# Uranus -> Uranus
# in -> in
# Sagittarius -> Sagittarius
# is -> be
# therefore -> therefore
# valid -> valid
# for -> for
# the -> the
# entire -> entire
# generation -> generation
# of -> of
# people -> people
# and -> and
# is -> be
# very -> very
# general -> general
# . -> .
# The -> the
# characteristic -> characteristic
# of -> of
# the -> the
# personality -> personality
# is -> be
# in -> in
# the -> the
# description -> description
# of -> of
# Uranus -> Uranus
# in -> in
# the -> the
# 12th -> 12th
# house -> house
# . -> .
# ) -> )
#
#  ->
#
# People -> People
# with -> with
# Uranus -> Uranus
# in -> in
# Sagittarius -> Sagittarius
# strive -> strive
# for -> for
# spiritual -> spiritual
# progress -> progress
# and -> and
# intellectual -> intellectual
# growth -> growth
# . -> .
# They -> they
# often -> often
# have -> have
# revolutionary -> revolutionary
# thoughts -> thought
# . -> .
# They -> they
# see -> see
# other -> other
# races -> race
# as -> as
# equals -> equal
# and -> and
# they -> they
# often -> often
# fight -> fight
# against -> against
# xenophobia -> xenophobia
# . -> .
# They -> they
# love -> love
# flying -> fly
# and -> and
# they -> they
# consider -> consider
# expeditions -> expedition
# to -> to
# space -> space
# very -> very
# exciting -> exciting
# . -> .
# They -> they
# bring -> bring
# new -> new
# directions -> direction
# to -> to
# philosophy -> philosophy
# . -> .
# They -> they
# are -> be
# optimistic -> optimistic
# and -> and
# they -> they
# tend -> tend
# to -> to
# make -> make
# unexpected -> unexpected
# and -> and
# unplanned -> unplanned
# journeys -> journey
# to -> to
# other -> other
# countries -> country
# . -> .
#
#
#  ->
#
#
# Uranus -> Uranus
# in -> in
# the -> the
# 12th -> 12th
# House -> House
#
#  ->
#
# Uranus -> Uranus
# in -> in
# the -> the
# twelfth -> twelfth
# house -> house
# suggests -> suggest
# volatility -> volatility
# and -> and
# changes -> change
# in -> in
# the -> the
# subconscious -> subconscious
# mind -> mind
# . -> .
# It -> it
# can -> can
# mean -> mean
# a -> a
# subconscious -> subconscious
# feeling -> feeling
# of -> of
# imprisonment -> imprisonment
# or -> or
# a -> a
# desire -> desire
# for -> for
# liberation -> liberation
# and -> and
# independence -> independence
# . -> .
# These -> these
# people -> people
# like -> like
# to -> to
# spend -> spend
# time -> time
# alone -> alone
# so -> so
# they -> they
# often -> often
# find -> find
# a -> a
# job -> job
# where -> where
# they -> they
# can -> can
# work -> work
# independently -> independently
# . -> .
# They -> they
# are -> be
# gifted -> gifted
# researchers -> researcher
# who -> who
# may -> may
# have -> have
# a -> a
# good -> good
# mental -> mental
# potential -> potential
# . -> .
# They -> they
# need -> need
# to -> to
# accept -> accept
# life -> life
# as -> as
# it -> it
# is -> be
# and -> and
# stop -> stop
# subconsciously -> subconsciously
# being -> be
# in -> in
# the -> the
# opposition -> opposition
# . -> .
#
#
#  ->
#
#
# Uranus -> Uranus
# aspects -> aspect
#
#  ->
#
# Trine -> Trine
# Moon -> Moon
# ( -> (
# 4 -> 4
# ° -> °
# 49 -> 49
# ’ -> '
# , -> ,
# Applying -> apply
# ) -> )
#
#  ->
#
# Opposition -> Opposition
# Mercury -> Mercury
# ( -> (
# 5 -> 5
# ° -> °
# 21 -> 21
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# Opposition -> Opposition
# Venus -> Venus
# ( -> (
# 5 -> 5
# ° -> °
# 23 -> 23
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# Conjunction -> Conjunction
# Saturn -> Saturn
# ( -> (
# 0 -> 0
# ° -> °
# 32 -> 32
# ’ -> '
# , -> ,
# Applying -> apply
# ) -> )
#
#  ->
#
# Contra -> Contra
# - -> -
# Parallel -> Parallel
# Sun -> Sun
# ( -> (
# 0 -> 0
# ° -> °
# 38 -> 38
# ’ -> '
# ) -> )
#
#  ->
#
# Contra -> Contra
# - -> -
# Parallel -> Parallel
# Venus -> Venus
# ( -> (
# 0 -> 0
# ° -> °
# 28 -> 28
# ’ -> '
# ) -> )
#
#
#   ->
#
#
# Neptune -> Neptune
# - -> -
# Fantasy -> Fantasy
# , -> ,
# illusion -> illusion
# , -> ,
# spirituality -> spirituality
# , -> ,
# imagination -> imagination
#
#  ->
#
# Neptune -> Neptune
# is -> be
# called -> call
# the -> the
# Lord -> Lord
# of -> of
# the -> the
# Invisible -> Invisible
# Empire -> Empire
# , -> ,
# which -> which
# is -> be
# a -> a
# mysterious -> mysterious
# name -> name
# of -> of
# a -> a
# mysterious -> mysterious
# planet -> planet
# . -> .
# Perhaps -> perhaps
# we -> we
# could -> could
# describe -> describe
# it -> it
# as -> as
# a -> a
# dimension -> dimension
# of -> of
# life -> life
# that -> that
# can -> can
# not -> not
# be -> be
# experienced -> experience
# by -> by
# our -> our
# five -> five
# senses -> sense
# and -> and
# we -> we
# can -> can
# only -> only
# understand -> understand
# and -> and
# perceive -> perceive
# it -> it
# in -> in
# our -> our
# imagination -> imagination
# . -> .
#
#
#  ->
#
#
# Neptune -> Neptune
# in -> in
# Capricorn -> Capricorn
#
#  ->
#
# ( -> (
# Note -> note
# : -> :
# Neptune -> Neptune
# is -> be
# a -> a
# slow -> slow
# transpersonal -> transpersonal
# planet -> planet
# and -> and
# may -> may
# remain -> remain
# in -> in
# a -> a
# single -> single
# sign -> sign
# for -> for
# up -> up
# to -> to
# many -> many
# years -> year
# . -> .
# The -> the
# description -> description
# of -> of
# Neptune -> Neptune
# in -> in
# Capricorn -> Capricorn
# is -> be
# therefore -> therefore
# valid -> valid
# for -> for
# the -> the
# entire -> entire
# generation -> generation
# of -> of
# people -> people
# and -> and
# is -> be
# very -> very
# general -> general
# . -> .
# The -> the
# characteristic -> characteristic
# of -> of
# the -> the
# personality -> personality
# is -> be
# in -> in
# the -> the
# description -> description
# of -> of
# Neptune -> Neptune
# in -> in
# the -> the
# 12th -> 12th
# house -> house
# . -> .
# ) -> )
#
#  ->
#
# Neptune -> Neptune
# in -> in
# Capricorn -> Capricorn
# gives -> give
# people -> people
# determination -> determination
# and -> and
# the -> the
# ability -> ability
# to -> to
# concentrate -> concentrate
# . -> .
# However -> however
# , -> ,
# it -> it
# can -> can
# ruin -> ruin
# their -> their
# typical -> typical
# Capricorn -> Capricorn
# rationality -> rationality
# . -> .
# This -> this
# position -> position
# somewhat -> somewhat
# shatters -> shatter
# their -> their
# natural -> natural
# desire -> desire
# for -> for
# perfection -> perfection
# , -> ,
# but -> but
# it -> it
# gives -> give
# people -> people
# desire -> desire
# to -> to
# achieve -> achieve
# spiritual -> spiritual
# goals -> goal
# . -> .
#
#
#  ->
#
#
# Neptune -> Neptune
# in -> in
# the -> the
# 12th -> 12th
# House -> House
#
#  ->
#
# Neptune -> Neptune
# in -> in
# the -> the
# twelfth -> twelfth
# house -> house
# affects -> affect
# the -> the
# unconscious -> unconscious
# mind -> mind
# . -> .
# Sometimes -> sometimes
# it -> it
# causes -> cause
# fears -> fear
# and -> and
# difficulties -> difficulty
# with -> with
# problems -> problem
# that -> that
# spring -> spring
# from -> from
# the -> the
# past -> past
# . -> .
# These -> these
# people -> people
# have -> have
# the -> the
# tendency -> tendency
# to -> to
# focus -> focus
# on -> on
# the -> the
# wrong -> wrong
# side -> side
# of -> of
# life -> life
# . -> .
# They -> they
# often -> often
# display -> display
# great -> great
# empathy -> empathy
# towards -> towards
# physically -> physically
# or -> or
# mentally -> mentally
# handicapped -> handicapped
# people -> people
# . -> .
# Neptune -> Neptune
# in -> in
# the -> the
# twelfth -> twelfth
# house -> house
# suggests -> suggest
# people -> people
# who -> who
# focus -> focus
# on -> on
# their -> their
# own -> own
# soul -> soul
# and -> and
# avoid -> avoid
# everyday -> everyday
# affairs -> affair
# . -> .
#
#
#  ->
#
#
# Neptune -> Neptune
# aspects -> aspect
#
#  ->
#
# Sextile -> Sextile
# Mars -> Mars
# ( -> (
# 2 -> 2
# ° -> °
# 16 -> 16
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# Sextile -> Sextile
# Pluto -> Pluto
# ( -> (
# 0 -> 0
# ° -> °
# 50 -> 50
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# Contra -> Contra
# - -> -
# Parallel -> Parallel
# Sun -> Sun
# ( -> (
# 0 -> 0
# ° -> °
# 53 -> 53
# ’ -> '
# ) -> )
#
#  ->
#
# Contra -> Contra
# - -> -
# Parallel -> Parallel
# Venus -> Venus
# ( -> (
# 1 -> 1
# ° -> °
# 03 -> 03
# ’ -> '
# ) -> )
#
#  ->
#
# Parallel -> Parallel
# Saturn -> Saturn
# ( -> (
# 0 -> 0
# ° -> °
# 10 -> 10
# ’ -> '
# ) -> )
#
#
#   ->
#
#
# Pluto -> Pluto
# - -> -
# Transformation -> Transformation
# , -> ,
# regeneration -> regeneration
# , -> ,
# power -> power
#
#  ->
#
# Pluto -> Pluto
# is -> be
# the -> the
# planet -> planet
# of -> of
# death -> death
# and -> and
# rebirth -> rebirth
# . -> .
# It -> it
# is -> be
# the -> the
# end -> end
# of -> of
# all -> all
# things -> thing
# , -> ,
# it -> it
# is -> be
# the -> the
# Judgment -> Judgment
# Day -> Day
# . -> .
# It -> it
# can -> can
# give -> give
# rise -> rise
# to -> to
# obsessions -> obsession
# or -> or
# convictions -> conviction
# . -> .
# On -> on
# the -> the
# dark -> dark
# end -> end
# of -> of
# its -> its
# spectrum -> spectrum
# it -> it
# can -> can
# manifest -> manifest
# as -> as
# " -> "
# succumbing -> succumb
# to -> to
# the -> the
# urge -> urge
# , -> ,
# " -> "
# or -> or
# it -> it
# can -> can
# create -> create
# an -> an
# individual -> individual
# who -> who
# has -> have
# the -> the
# ability -> ability
# to -> to
# get -> get
# to -> to
# the -> the
# core -> core
# of -> of
# things -> thing
# , -> ,
# destroy -> destroy
# negative -> negative
# things -> thing
# and -> and
# bring -> bring
# on -> on
# healing -> healing
# and -> and
# transformation -> transformation
# . -> .
#
#
#  ->
#
#
# Pluto -> Pluto
# in -> in
# Scorpio -> Scorpio
#
#  ->
#
# ( -> (
# Note -> note
# : -> :
# Pluto -> Pluto
# is -> be
# a -> a
# slow -> slow
# transpersonal -> transpersonal
# planet -> planet
# and -> and
# may -> may
# remain -> remain
# in -> in
# a -> a
# single -> single
# sign -> sign
# for -> for
# up -> up
# to -> to
# many -> many
# years -> year
# . -> .
# The -> the
# description -> description
# of -> of
# Pluto -> Pluto
# in -> in
# Scorpio -> Scorpio
# is -> be
# therefore -> therefore
# valid -> valid
# for -> for
# the -> the
# entire -> entire
# generation -> generation
# of -> of
# people -> people
# and -> and
# is -> be
# very -> very
# general -> general
# . -> .
# The -> the
# characteristic -> characteristic
# of -> of
# the -> the
# personality -> personality
# is -> be
# in -> in
# the -> the
# description -> description
# of -> of
# Pluto -> Pluto
# in -> in
# the -> the
# 10th -> 10th
# house -> house
# . -> .
# ) -> )
#
#  ->
#
# People -> People
# with -> with
# Pluto -> Pluto
# in -> in
# Scorpio -> Scorpio
# have -> have
# a -> a
# passionate -> passionate
# desire -> desire
# for -> for
# mystery -> mystery
# . -> .
# They -> they
# like -> like
# to -> to
# use -> use
# intrigues -> intrigue
# and -> and
# they -> they
# have -> have
# a -> a
# great -> great
# disposition -> disposition
# for -> for
# personal -> personal
# transformation -> transformation
# that -> that
# can -> can
# happen -> happen
# especially -> especially
# through -> through
# their -> their
# desires -> desire
# . -> .
# They -> they
# are -> be
# prolific -> prolific
# , -> ,
# universal -> universal
# and -> and
# capable -> capable
# . -> .
# They -> they
# radiate -> radiate
# occult -> occult
# powers -> power
# . -> .
# Their -> their
# sexuality -> sexuality
# is -> be
# also -> also
# transforming -> transform
# for -> for
# them -> they
# , -> ,
# but -> but
# at -> at
# the -> the
# same -> same
# time -> time
# they -> they
# can -> can
# feel -> feel
# restricted -> restrict
# by -> by
# it -> it
# . -> .
#
#
#  ->
#
#
# Pluto -> Pluto
# in -> in
# the -> the
# 10th -> 10th
# House -> House
#
#  ->
#
# Pluto -> Pluto
# in -> in
# the -> the
# tenth -> tenth
# house -> house
# suggests -> suggest
# a -> a
# person -> person
# who -> who
# has -> have
# a -> a
# strong -> strong
# will -> will
# and -> and
# need -> need
# to -> to
# achieve -> achieve
# success -> success
# in -> in
# his -> his
# career -> career
# . -> .
# Pluto -> pluto
# in -> in
# this -> this
# house -> house
# suggests -> suggest
# a -> a
# career -> career
# in -> in
# a -> a
# scientific -> scientific
# field -> field
# , -> ,
# in -> in
# healing -> healing
# or -> or
# medicine -> medicine
# , -> ,
# or -> or
# in -> in
# a -> a
# profession -> profession
# where -> where
# one -> one
# can -> can
# deal -> deal
# with -> with
# powerful -> powerful
# individuals -> individual
# , -> ,
# for -> for
# example -> example
# politics -> politic
# . -> .
# This -> this
# planet -> planet
# will -> will
# cause -> cause
# changes -> change
# and -> and
# interruptions -> interruption
# in -> in
# business -> business
# or -> or
# occupational -> occupational
# matters -> matter
# . -> .
#
#
#  ->
#
#
# Pluto -> Pluto
# aspects -> aspect
#
#  ->
#
# Trine -> Trine
# Mars -> Mars
# ( -> (
# 1 -> 1
# ° -> °
# 26 -> 26
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# Sextile -> Sextile
# Neptune -> Neptune
# ( -> (
# 0 -> 0
# ° -> °
# 50 -> 50
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#
#  ->
#
#
# Objects -> object
# : -> :
#
#
#   ->
#
#
# Lunar -> Lunar
# Nodes -> Nodes
# - -> -
# North -> North
# Node -> Node
# and -> and
# South -> South
# Node -> Node
#
#  ->
#
# The -> the
# Lunar -> Lunar
# Nodes -> Nodes
# are -> be
# n’t -> not
# planets -> planet
# , -> ,
# but -> but
# rather -> rather
# astrology -> astrology
# mathematical -> mathematical
# points -> point
# , -> ,
# that -> that
# are -> be
# directly -> directly
# opposite -> opposite
# each -> each
# other -> other
# in -> in
# the -> the
# chart -> chart
# . -> .
# It -> it
# is -> be
# said -> say
# , -> ,
# that -> that
# your -> your
# life -> life
# purpose -> purpose
# is -> be
# encoded -> encode
# between -> between
# them -> they
# - -> -
# in -> in
# the -> the
# line -> line
# between -> between
# North -> North
# Node -> Node
# and -> and
# South -> South
# Node -> Node
# . -> .
# The -> the
# South -> South
# Node -> Node
# indicates -> indicate
# your -> your
# comfort -> comfort
# zone -> zone
# , -> ,
# your -> your
# habitual -> habitual
# place -> place
# , -> ,
# while -> while
# your -> your
# North -> North
# Node -> Node
# shows -> show
# life -> life
# lessons -> lesson
# and -> and
# what -> what
# you -> you
# ’re -> ’re
# striving -> strive
# for -> for
# in -> in
# this -> this
# lifetime -> lifetime
# . -> .
# Both -> both
# Lunar -> Lunar
# Nodes -> Nodes
# are -> be
# almost -> almost
# always -> always
# retrogade -> retrogade
# . -> .
#
#
#  ->
#
#
# North -> North
# Node -> Node
# ( -> (
# Mean -> Mean
# ) -> )
# in -> in
# Pisces -> Pisces
# - -> -
# South -> South
# Node -> Node
# in -> in
# Virgo -> Virgo
#
#  ->
#
# North -> North
# Node -> Node
# in -> in
# Pisces -> Pisces
# brings -> bring
# the -> the
# conflict -> conflict
# between -> between
# transcendental -> transcendental
# effort -> effort
# and -> and
# everyday -> everyday
# reality -> reality
# , -> ,
# between -> between
# chaos -> chaos
# and -> and
# order -> order
# , -> ,
# and -> and
# between -> between
# spirituality -> spirituality
# and -> and
# reason -> reason
# . -> .
#
#  ->
#
# These -> these
# people -> people
# need -> need
# to -> to
# open -> open
# up -> up
# to -> to
# their -> their
# spirituality -> spirituality
# and -> and
# imagination -> imagination
# . -> .
# They -> they
# need -> need
# to -> to
# escape -> escape
# the -> the
# constraints -> constraint
# of -> of
# the -> the
# usual -> usual
# and -> and
# explainable -> explainable
# and -> and
# be -> be
# open -> open
# to -> to
# the -> the
# unusual -> unusual
# and -> and
# unexplainable -> unexplainable
# . -> .
# They -> they
# need -> need
# to -> to
# go -> go
# beyond -> beyond
# the -> the
# rational -> rational
# and -> and
# analytical -> analytical
# , -> ,
# develop -> develop
# imaginative -> imaginative
# powers -> power
# and -> and
# spiritual -> spiritual
# awareness -> awareness
# . -> .
# They -> they
# should -> should
# stop -> stop
# working -> work
# so -> so
# hard -> hard
# and -> and
# find -> find
# time -> time
# for -> for
# themselves -> themselves
# . -> .
# They -> they
# should -> should
# learn -> learn
# to -> to
# make -> make
# self -> self
# - -> -
# sacrifice -> sacrifice
# and -> and
# show -> show
# love -> love
# for -> for
# other -> other
# people -> people
# . -> .
#
#  ->
#
# Beware -> beware
# of -> of
# morbid -> morbid
# obsession -> obsession
# with -> with
# order -> order
# , -> ,
# cleanliness -> cleanliness
# and -> and
# rejection -> rejection
# of -> of
# everything -> everything
# that -> that
# is -> be
# not -> not
# in -> in
# perfect -> perfect
# order -> order
# or -> or
# can -> can
# not -> not
# be -> be
# explained -> explain
# . -> .
#
#
#  ->
#
#
# North -> North
# Node -> Node
# ( -> (
# Mean -> Mean
# ) -> )
# in -> in
# the -> the
# 3rd -> 3rd
# House -> House
# - -> -
# South -> South
# Node -> Node
# in -> in
# the -> the
# 9th -> 9th
# House -> House
#
#  ->
#
# North -> North
# Node -> Node
# in -> in
# the -> the
# third -> third
# house -> house
# brings -> bring
# the -> the
# conflict -> conflict
# between -> between
# seeking -> seek
# objectivity -> objectivity
# and -> and
# lively -> lively
# communication -> communication
# on -> on
# the -> the
# one -> one
# hand -> hand
# , -> ,
# and -> and
# clinging -> cling
# to -> to
# a -> a
# highly -> highly
# subjective -> subjective
# understanding -> understanding
# , -> ,
# firmly -> firmly
# anchored -> anchor
# opinions -> opinion
# and -> and
# commands -> command
# on -> on
# the -> the
# other -> other
# . -> .
#
#  ->
#
# These -> these
# people -> people
# need -> need
# to -> to
# learn -> learn
# how -> how
# to -> to
# express -> express
# complex -> complex
# contexts -> context
# and -> and
# ideas -> idea
# in -> in
# everyday -> everyday
# language -> language
# , -> ,
# how -> how
# to -> to
# convey -> convey
# spiritual -> spiritual
# thinking -> thinking
# into -> into
# practical -> practical
# life -> life
# , -> ,
# transfer -> transfer
# it -> it
# in -> in
# comprehensible -> comprehensible
# form -> form
# and -> and
# show -> show
# clearly -> clearly
# the -> the
# connection -> connection
# between -> between
# the -> the
# philosophical -> philosophical
# and -> and
# noble -> noble
# knowledge -> knowledge
# and -> and
# values -> value
# of -> of
# everyday -> everyday
# life -> life
# . -> .
#
#  ->
#
# Beware -> beware
# of -> of
# prejudices -> prejudice
# and -> and
# stubborn -> stubborn
# beliefs -> belief
# . -> .
#
#
#  ->
#
#
# Node -> Node
# ( -> (
# Mean -> Mean
# ) -> )
# aspects -> aspect
#
#  ->
#
# Square -> Square
# Sun -> Sun
# ( -> (
# 0 -> 0
# ° -> °
# 40 -> 40
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# Square -> Square
# Mercury -> Mercury
# ( -> (
# 5 -> 5
# ° -> °
# 27 -> 27
# ’ -> '
# , -> ,
# Applying -> apply
# ) -> )
#
#  ->
#
# Square -> Square
# Venus -> Venus
# ( -> (
# 5 -> 5
# ° -> °
# 25 -> 25
# ’ -> '
# , -> ,
# Applying -> Applying
# ) -> )
#
#  ->
#
# Sextile -> Sextile
# Jupiter -> Jupiter
# ( -> (
# 2 -> 2
# ° -> °
# 54 -> 54
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#
#   ->
#
#
# Lilith -> Lilith
# - -> -
# Black -> Black
# Moon -> Moon
# - -> -
# Fascination -> Fascination
# and -> and
# Denial -> Denial
#
#  ->
#
# Lilith -> Lilith
# is -> be
# a -> a
# fictional -> fictional
# point -> point
# - -> -
# the -> the
# second -> second
# empty -> empty
# focal -> focal
# point -> point
# of -> of
# elliptical -> elliptical
# orbit -> orbit
# of -> of
# the -> the
# Moon -> Moon
# around -> around
# the -> the
# Earth -> Earth
# . -> .
#
#  ->
#
# In -> in
# mythology -> mythology
# , -> ,
# Lilith -> Lilith
# refused -> refuse
# to -> to
# submit -> submit
# to -> to
# Adam -> Adam
# , -> ,
# rebelled -> rebel
# against -> against
# the -> the
# connection -> connection
# between -> between
# Adam -> Adam
# and -> and
# Eve -> Eve
# , -> ,
# decided -> decide
# to -> to
# escape -> escape
# from -> from
# the -> the
# world -> world
# of -> of
# people -> people
# and -> and
# made -> make
# a -> a
# connection -> connection
# with -> with
# Satan -> Satan
# . -> .
#
#  ->
#
# In -> in
# astrology -> astrology
# , -> ,
# Lilith -> Lilith
# symbolizes -> symbolize
# either -> either
# fascination -> fascination
# or -> or
# refusal -> refusal
# of -> of
# topics -> topic
# with -> with
# which -> which
# she -> she
# is -> be
# connected -> connect
# with -> with
# . -> .
# Both -> both
# , -> ,
# the -> the
# fascination -> fascination
# or -> or
# the -> the
# rejection -> rejection
# of -> of
# the -> the
# given -> give
# topics -> topic
# , -> ,
# can -> can
# eventually -> eventually
# engulf -> engulf
# the -> the
# person -> person
# and -> and
# take -> take
# him -> he
# " -> "
# away -> away
# " -> "
# from -> from
# the -> the
# human -> human
# world -> world
# . -> .
#
#
#  ->
#
#
# Lilith -> Lilith
# ( -> (
# Mean -> Mean
# ) -> )
# in -> in
# Virgo -> Virgo
#
#  ->
#
# Rebellion -> Rebellion
# against -> against
# order -> order
# ; -> ;
# provocative -> provocative
# humour -> humour
# . -> .
#
#  ->
#
# Their -> their
# sensuality -> sensuality
# is -> be
# strongly -> strongly
# suppressed -> suppress
# by -> by
# trying -> try
# to -> to
# appear -> appear
# calm -> calm
# ; -> ;
# emotional -> emotional
# conflicts -> conflict
# often -> often
# occur -> occur
# because -> because
# it -> it
# is -> be
# very -> very
# difficult -> difficult
# for -> for
# these -> these
# people -> people
# to -> to
# feel -> feel
# relaxed -> relaxed
# . -> .
# They -> they
# want -> want
# to -> to
# suppress -> suppress
# their -> their
# instincts -> instinct
# or -> or
# they -> they
# appear -> appear
# to -> to
# be -> be
# cold -> cold
# and -> and
# perverted -> pervert
# . -> .
#
#  ->
#
# Beware -> beware
# of -> of
# alcoholism -> alcoholism
# and -> and
# surgery -> surgery
# of -> of
# the -> the
# intestines -> intestine
# . -> .
#
#
#  ->
#
#
# Lilith -> Lilith
# ( -> (
# Mean -> Mean
# ) -> )
# in -> in
# the -> the
# 8th -> 8th
# House -> House
#
#  ->
#
# Tendency -> Tendency
# to -> to
# ask -> ask
# questions -> question
# about -> about
# death -> death
# or -> or
# an -> an
# obsession -> obsession
# with -> with
# death -> death
# . -> .
#
#   ->
#
# Chiron -> Chiron
# - -> -
# Wounded -> wound
# Healer -> Healer
# , -> ,
# inner -> inner
# teacher -> teacher
#
#  ->
#
# Chiron -> Chiron
# is -> be
# an -> an
# asteroid -> asteroid
# between -> between
# Saturn -> Saturn
# and -> and
# Uranus -> Uranus
# . -> .
# Its -> its
# orbit -> orbit
# is -> be
# very -> very
# unusual -> unusual
# and -> and
# represents -> represent
# a -> a
# bridge -> bridge
# between -> between
# material -> material
# and -> and
# spiritual -> spiritual
# worlds -> world
# . -> .
#
#  ->
#
# According -> accord
# to -> to
# mythology -> mythology
# , -> ,
# Chiron -> Chiron
# was -> be
# a -> a
# great -> great
# healer -> healer
# , -> ,
# wise -> wise
# teacher -> teacher
# and -> and
# one -> one
# of -> of
# the -> the
# immortal -> immortal
# Centaurs -> Centaurs
# . -> .
# Unfortunately -> unfortunately
# , -> ,
# he -> he
# was -> be
# " -> "
# deadly -> deadly
# " -> "
# injured -> injure
# by -> by
# a -> a
# poisonous -> poisonous
# arrow -> arrow
# by -> by
# Heracles -> Heracles
# , -> ,
# his -> his
# favourite -> favourite
# disciple -> disciple
# . -> .
# He -> he
# was -> be
# suffering -> suffer
# in -> in
# great -> great
# pain -> pain
# but -> but
# he -> he
# could -> could
# not -> not
# die -> die
# . -> .
# Finally -> finally
# , -> ,
# he -> he
# gave -> give
# up -> up
# his -> his
# immortality -> immortality
# for -> for
# the -> the
# benefit -> benefit
# of -> of
# Prometheus -> Prometheus
# who -> who
# was -> be
# also -> also
# suffering -> suffer
# , -> ,
# and -> and
# Chiron -> Chiron
# was -> be
# sent -> send
# to -> to
# the -> the
# underworld -> underworld
# . -> .
# In -> in
# the -> the
# underworld -> underworld
# Zeus -> Zeus
# had -> have
# mercy -> mercy
# for -> for
# him -> he
# and -> and
# he -> he
# raised -> raise
# him -> he
# to -> to
# the -> the
# heaven -> heaven
# . -> .
#
#  ->
#
# In -> in
# astrology -> astrology
# , -> ,
# Chiron -> Chiron
# symbolizes -> symbolize
# our -> our
# unhealable -> unhealable
# injuries -> injury
# and -> and
# incurable -> incurable
# trauma -> trauma
# . -> .
# However -> however
# , -> ,
# if -> if
# a -> a
# person -> person
# , -> ,
# instead -> instead
# of -> of
# drowning -> drown
# in -> in
# his -> his
# own -> own
# trauma -> trauma
# , -> ,
# is -> be
# able -> able
# to -> to
# accept -> accept
# the -> the
# trauma -> trauma
# and -> and
# help -> help
# others -> other
# who -> who
# are -> be
# also -> also
# suffering -> suffer
# , -> ,
# and -> and
# accept -> accept
# that -> that
# suffering -> suffering
# is -> be
# part -> part
# of -> of
# life -> life
# , -> ,
# then -> then
# Chiron -> Chiron
# may -> may
# be -> be
# the -> the
# key -> key
# to -> to
# wisdom -> wisdom
# , -> ,
# or -> or
# even -> even
# to -> to
# some -> some
# sort -> sort
# of -> of
# " -> "
# Initiation -> Initiation
# Gate -> Gate
# " -> "
# . -> .
#
#
#  ->
#
#
# Chiron -> Chiron
# in -> in
# Gemini -> Gemini
#
#  ->
#
# Without -> without
# success -> success
# , -> ,
# these -> these
# people -> people
# keep -> keep
# trying -> try
# to -> to
# explain -> explain
# to -> to
# other -> other
# what -> what
# they -> they
# wanted -> want
# to -> to
# say -> say
# , -> ,
# what -> what
# they -> they
# said -> say
# and -> and
# what -> what
# they -> they
# meant -> mean
# by -> by
# it -> it
# . -> .
# They -> they
# either -> either
# believe -> believe
# that -> that
# nobody -> nobody
# listens -> listen
# to -> to
# them -> they
# , -> ,
# or -> or
# that -> that
# no -> no
# matter -> matter
# how -> how
# hard -> hard
# they -> they
# try -> try
# , -> ,
# others -> other
# can -> can
# not -> not
# understand -> understand
# them -> they
# or -> or
# do -> do
# not -> not
# want -> want
# to -> to
# understand -> understand
# them -> they
# . -> .
# The -> the
# more -> more
# they -> they
# try -> try
# to -> to
# correct -> correct
# this -> this
# misunderstanding -> misunderstanding
# , -> ,
# the -> the
# more -> more
# this -> this
# sense -> sense
# of -> of
# misunderstanding -> misunderstanding
# that -> that
# they -> they
# can -> can
# never -> never
# overcome -> overcome
# hurts -> hurt
# them -> they
# . -> .
#
#
#  ->
#
#
# Chiron -> Chiron
# in -> in
# the -> the
# 6th -> 6th
# House -> House
#
#  ->
#
# These -> these
# people -> people
# are -> be
# sick -> sick
# all -> all
# their -> their
# life -> life
# ; -> ;
# their -> their
# illnesses -> illness
# are -> be
# not -> not
# too -> too
# serious -> serious
# , -> ,
# but -> but
# they -> they
# are -> be
# chronic -> chronic
# and -> and
# it -> it
# seems -> seem
# that -> that
# they -> they
# can -> can
# not -> not
# be -> be
# cured -> cure
# , -> ,
# especially -> especially
# when -> when
# both -> both
# medical -> medical
# professionals -> professional
# and -> and
# traditional -> traditional
# healers -> healer
# can -> can
# not -> not
# give -> give
# the -> the
# correct -> correct
# diagnosis -> diagnosis
# . -> .
# It -> it
# is -> be
# as -> as
# if -> if
# these -> these
# people -> people
# took -> take
# all -> all
# the -> the
# illness -> illness
# of -> of
# others -> other
# on -> on
# themselves -> themselves
# and -> and
# had -> have
# no -> no
# choice -> choice
# but -> but
# to -> to
# learn -> learn
# to -> to
# live -> live
# with -> with
# their -> their
# health -> health
# problems -> problem
# and -> and
# keep -> keep
# searching -> search
# for -> for
# new -> new
# ways -> way
# to -> to
# cure -> cure
# them -> they
# or -> or
# at -> at
# least -> least
# to -> to
# alleviate -> alleviate
# the -> the
# symptoms -> symptom
# . -> .
# But -> but
# there -> there
# is -> be
# always -> always
# the -> the
# fear -> fear
# that -> that
# once -> once
# one -> one
# illness -> illness
# is -> be
# cured -> cure
# , -> ,
# another -> another
# , -> ,
# more -> more
# serious -> serious
# illness -> illness
# will -> will
# suddenly -> suddenly
# appear -> appear
# . -> .
#
#  ->
#
# Main -> main
# aspects -> aspect
#
#   ->
#
# Sun -> Sun
# Sextile -> Sextile
# Moon -> Moon
# ( -> (
# 5 -> 5
# ° -> °
# 18 -> 18
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# Emotions -> emotion
# and -> and
# feelings -> feeling
# of -> of
# the -> the
# Moon -> Moon
# are -> be
# in -> in
# harmony -> harmony
# with -> with
# ego -> ego
# and -> and
# individuality -> individuality
# of -> of
# the -> the
# Sun -> Sun
# . -> .
# This -> this
# contributes -> contribute
# to -> to
# balance -> balance
# , -> ,
# relaxation -> relaxation
# and -> and
# inner -> inner
# peace -> peace
# . -> .
# This -> this
# aspect -> aspect
# also -> also
# greatly -> greatly
# increases -> increase
# the -> the
# chance -> chance
# to -> to
# find -> find
# success -> success
# and -> and
# satisfaction -> satisfaction
# in -> in
# life -> life
# . -> .
# Relationships -> relationship
# with -> with
# the -> the
# opposite -> opposite
# sex -> sex
# are -> be
# mostly -> mostly
# balanced -> balanced
# and -> and
# harmonious -> harmonious
# . -> .
#
#
#   ->
#
#
# Sun -> Sun
# Conjunction -> Conjunction
# Mercury -> Mercury
# ( -> (
# 4 -> 4
# ° -> °
# 47 -> 47
# ’ -> '
# , -> ,
# Applying -> apply
# ) -> )
#
#  ->
#
# There -> there
# can -> can
# only -> only
# be -> be
# conjunction -> conjunction
# between -> between
# the -> the
# Sun -> Sun
# and -> and
# Mercury -> Mercury
# . -> .
# People -> People
# with -> with
# this -> this
# aspect -> aspect
# are -> be
# subjective -> subjective
# and -> and
# creative -> creative
# ; -> ;
# they -> they
# can -> can
# express -> express
# their -> their
# ideas -> idea
# well -> well
# and -> and
# they -> they
# are -> be
# often -> often
# very -> very
# artistic -> artistic
# . -> .
# This -> this
# is -> be
# a -> a
# great -> great
# aspect -> aspect
# for -> for
# artists -> artist
# who -> who
# perform -> perform
# on -> on
# stage -> stage
# . -> .
# These -> these
# people -> people
# are -> be
# intellectuals -> intellectual
# , -> ,
# but -> but
# their -> their
# thinking -> thinking
# is -> be
# very -> very
# subjective -> subjective
# and -> and
# they -> they
# can -> can
# sometimes -> sometimes
# lack -> lack
# objectivity -> objectivity
# or -> or
# the -> the
# ability -> ability
# to -> to
# see -> see
# things -> thing
# from -> from
# the -> the
# outside -> outside
# . -> .
#
#
#   ->
#
#
# Sun -> Sun
# Conjunction -> Conjunction
# Venus -> Venus
# ( -> (
# 4 -> 4
# ° -> °
# 45 -> 45
# ’ -> '
# , -> ,
# Applying -> apply
# ) -> )
#
#  ->
#
# There -> there
# can -> can
# only -> only
# be -> be
# conjunction -> conjunction
# between -> between
# the -> the
# Sun -> Sun
# and -> and
# Venus -> Venus
# . -> .
# This -> this
# aspect -> aspect
# highlights -> highlight
# feminine -> feminine
# characteristics -> characteristic
# of -> of
# both -> both
# sexes -> sex
# . -> .
# It -> it
# also -> also
# supports -> support
# artistic -> artistic
# and -> and
# creative -> creative
# inclinations -> inclination
# . -> .
# These -> these
# people -> people
# are -> be
# often -> often
# optimistic -> optimistic
# and -> and
# they -> they
# enjoy -> enjoy
# the -> the
# company -> company
# of -> of
# other -> other
# people -> people
# . -> .
# They -> they
# have -> have
# a -> a
# good -> good
# taste -> taste
# for -> for
# fashionable -> fashionable
# clothes -> clothe
# . -> .
#
#
#   ->
#
#
# Sun -> Sun
# Square -> Square
# Mars -> Mars
# ( -> (
# 7 -> 7
# ° -> °
# 41 -> 41
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# This -> this
# aspect -> aspect
# give -> give
# these -> these
# people -> people
# physical -> physical
# strength -> strength
# and -> and
# the -> the
# ability -> ability
# to -> to
# work -> work
# hard -> hard
# . -> .
# However -> however
# they -> they
# tend -> tend
# to -> to
# take -> take
# unnecessary -> unnecessary
# risks -> risk
# . -> .
# They -> they
# may -> may
# also -> also
# be -> be
# too -> too
# impulsive -> impulsive
# , -> ,
# easily -> easily
# excitable -> excitable
# and -> and
# selfish -> selfish
# . -> .
#
#
#   ->
#
#
# Moon -> Moon
# Sextile -> Sextile
# Mercury -> Mercury
# ( -> (
# 0 -> 0
# ° -> °
# 31 -> 31
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# This -> this
# harmonious -> harmonious
# aspect -> aspect
# give -> give
# people -> people
# good -> good
# memory -> memory
# , -> ,
# poetic -> poetic
# soul -> soul
# and -> and
# the -> the
# ability -> ability
# to -> to
# understand -> understand
# others -> other
# . -> .
# It -> it
# helps -> help
# people -> people
# to -> to
# become -> become
# good -> good
# teachers -> teacher
# , -> ,
# journalists -> journalist
# and -> and
# psychologists -> psychologist
# . -> .
# These -> these
# people -> people
# are -> be
# interested -> interested
# in -> in
# their -> their
# origin -> origin
# and -> and
# roots -> root
# and -> and
# in -> in
# environmental -> environmental
# problems -> problem
# . -> .
# They -> they
# are -> be
# often -> often
# very -> very
# intelligent -> intelligent
# . -> .
#
#
#   ->
#
#
# Moon -> Moon
# Sextile -> Sextile
# Venus -> Venus
# ( -> (
# 0 -> 0
# ° -> °
# 33 -> 33
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# This -> this
# harmonious -> harmonious
# aspect -> aspect
# gives -> give
# people -> people
# balanced -> balanced
# temperament -> temperament
# , -> ,
# charming -> charming
# manners -> manner
# and -> and
# usually -> usually
# also -> also
# good -> good
# looks -> look
# . -> .
# Social -> social
# success -> success
# is -> be
# almost -> almost
# guaranteed -> guarantee
# . -> .
# These -> these
# people -> people
# have -> have
# creative -> creative
# abilities -> ability
# and -> and
# they -> they
# need -> need
# to -> to
# create -> create
# a -> a
# pleasant -> pleasant
# home -> home
# environment -> environment
# . -> .
#
#
#   ->
#
#
# Moon -> Moon
# Trine -> Trine
# Saturn -> Saturn
# ( -> (
# 5 -> 5
# ° -> °
# 22 -> 22
# ’ -> '
# , -> ,
# Applying -> apply
# ) -> )
#
#  ->
#
# This -> this
# harmonious -> harmonious
# aspect -> aspect
# gives -> give
# people -> people
# emotional -> emotional
# stability -> stability
# . -> .
# In -> in
# their -> their
# home -> home
# environment -> environment
# they -> they
# often -> often
# do -> do
# things -> thing
# in -> in
# a -> a
# way -> way
# they -> they
# think -> think
# is -> be
# right -> right
# . -> .
# They -> they
# are -> be
# reliable -> reliable
# , -> ,
# stable -> stable
# and -> and
# helpful -> helpful
# . -> .
# However -> however
# , -> ,
# sometimes -> sometimes
# they -> they
# may -> may
# be -> be
# pedant -> pedant
# . -> .
#
#
#   ->
#
#
# Moon -> Moon
# Trine -> Trine
# Uranus -> Uranus
# ( -> (
# 4 -> 4
# ° -> °
# 49 -> 49
# ’ -> '
# , -> ,
# Applying -> apply
# ) -> )
#
#  ->
#
# This -> this
# harmonious -> harmonious
# aspect -> aspect
# brings -> bring
# people -> people
# the -> the
# need -> need
# for -> for
# considerable -> considerable
# emotional -> emotional
# independence -> independence
# and -> and
# freedom -> freedom
# in -> in
# the -> the
# family -> family
# environment -> environment
# . -> .
# These -> these
# people -> people
# often -> often
# lead -> lead
# unconventional -> unconventional
# life -> life
# and -> and
# they -> they
# do -> do
# not -> not
# like -> like
# to -> to
# yield -> yield
# to -> to
# the -> the
# will -> will
# of -> of
# others -> other
# . -> .
# They -> they
# feel -> feel
# separated -> separate
# from -> from
# society -> society
# ( -> (
# complex -> complex
# of -> of
# separation -> separation
# ) -> )
# . -> .
# They -> they
# often -> often
# experience -> experience
# stormy -> stormy
# emotions -> emotion
# and -> and
# mood -> mood
# swings -> swing
# . -> .
#
#
#   ->
#
#
# Mercury -> Mercury
# Conjunction -> Conjunction
# Venus -> Venus
# ( -> (
# 0 -> 0
# ° -> °
# 01 -> 01
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# This -> this
# conjunction -> conjunction
# gives -> give
# people -> people
# good -> good
# manners -> manner
# and -> and
# mental -> mental
# balance -> balance
# . -> .
# They -> they
# can -> can
# express -> express
# themselves -> themselves
# well -> well
# and -> and
# they -> they
# are -> be
# convincing -> convincing
# . -> .
# Their -> their
# views -> view
# are -> be
# also -> also
# well -> well
# - -> -
# balanced -> balanced
# . -> .
# Their -> their
# thinking -> thinking
# is -> be
# often -> often
# so -> so
# rational -> rational
# that -> that
# they -> they
# are -> be
# not -> not
# able -> able
# to -> to
# express -> express
# their -> their
# feelings -> feeling
# too -> too
# openly -> openly
# . -> .
#
#
#   ->
#
#
# Mercury -> Mercury
# Opposition -> Opposition
# Saturn -> Saturn
# ( -> (
# 5 -> 5
# ° -> °
# 54 -> 54
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# This -> this
# aspect -> aspect
# gives -> give
# people -> people
# serious -> serious
# , -> ,
# conservative -> conservative
# and -> and
# practical -> practical
# mental -> mental
# processes -> process
# . -> .
# However -> however
# , -> ,
# these -> these
# people -> people
# also -> also
# have -> have
# the -> the
# ability -> ability
# to -> to
# calculate -> calculate
# clearly -> clearly
# and -> and
# calmly -> calmly
# , -> ,
# and -> and
# this -> this
# ability -> ability
# is -> be
# often -> often
# responsible -> responsible
# for -> for
# their -> their
# success -> success
# . -> .
#
#
#   ->
#
#
# Mercury -> Mercury
# Opposition -> Opposition
# Uranus -> Uranus
# ( -> (
# 5 -> 5
# ° -> °
# 21 -> 21
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# This -> this
# aspect -> aspect
# often -> often
# brings -> bring
# extreme -> extreme
# views -> view
# and -> and
# a -> a
# strong -> strong
# need -> need
# for -> for
# independence -> independence
# . -> .
# These -> these
# people -> people
# force -> force
# their -> their
# opinions -> opinion
# , -> ,
# which -> which
# are -> be
# often -> often
# extreme -> extreme
# an -> an
# unrealistic -> unrealistic
# , -> ,
# on -> on
# others -> other
# with -> with
# arrogance -> arrogance
# and -> and
# reluctance -> reluctance
# to -> to
# compromise -> compromise
# . -> .
# Their -> their
# opinions -> opinion
# are -> be
# often -> often
# way -> way
# ahead -> ahead
# and -> and
# these -> these
# people -> people
# are -> be
# inclined -> inclined
# to -> to
# get -> get
# involved -> involve
# in -> in
# movements -> movement
# that -> that
# have -> have
# views -> view
# that -> that
# may -> may
# even -> even
# be -> be
# accepted -> accept
# in -> in
# the -> the
# future -> future
# . -> .
# They -> they
# are -> be
# curious -> curious
# and -> and
# intelligent -> intelligent
# . -> .
# They -> they
# have -> have
# novel -> novel
# way -> way
# of -> of
# thinking -> thinking
# and -> and
# they -> they
# like -> like
# to -> to
# argue -> argue
# about -> about
# opinions -> opinion
# . -> .
# Their -> their
# creative -> creative
# activity -> activity
# is -> be
# often -> often
# destructive -> destructive
# and -> and
# it -> it
# tends -> tend
# to -> to
# be -> be
# rebellious -> rebellious
# and -> and
# chaotic -> chaotic
# . -> .
#
#
#   ->
#
#
# Venus -> Venus
# Opposition -> Opposition
# Saturn -> Saturn
# ( -> (
# 5 -> 5
# ° -> °
# 56 -> 56
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# People -> People
# with -> with
# this -> this
# aspect -> aspect
# are -> be
# responsible -> responsible
# , -> ,
# reserved -> reserve
# and -> and
# hesitant -> hesitant
# . -> .
# They -> they
# also -> also
# have -> have
# restraints -> restraint
# that -> that
# are -> be
# often -> often
# the -> the
# result -> result
# of -> of
# poor -> poor
# parenting -> parenting
# or -> or
# fear -> fear
# of -> of
# other -> other
# authorities -> authority
# . -> .
# This -> this
# also -> also
# causes -> cause
# fear -> fear
# of -> of
# loss -> loss
# - -> -
# they -> they
# are -> be
# afraid -> afraid
# to -> to
# lose -> lose
# both -> both
# their -> their
# property -> property
# and -> and
# their -> their
# loved -> love
# ones -> one
# . -> .
# These -> these
# people -> people
# often -> often
# submit -> submit
# their -> their
# feelings -> feeling
# to -> to
# practicality -> practicality
# ( -> (
# typical -> typical
# manifestation -> manifestation
# of -> of
# this -> this
# is -> be
# getting -> getting
# married -> marry
# for -> for
# security -> security
# ) -> )
# . -> .
# They -> they
# subconsciously -> subconsciously
# fear -> fear
# unemployment -> unemployment
# and -> and
# poverty -> poverty
# . -> .
#
#
#   ->
#
#
# Venus -> Venus
# Opposition -> Opposition
# Uranus -> Uranus
# ( -> (
# 5 -> 5
# ° -> °
# 23 -> 23
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# This -> this
# aspect -> aspect
# complicates -> complicate
# any -> any
# relationship -> relationship
# because -> because
# these -> these
# people -> people
# see -> see
# relationships -> relationship
# literally -> literally
# as -> as
# a -> a
# loss -> loss
# of -> of
# personal -> personal
# freedom -> freedom
# and -> and
# integrity -> integrity
# . -> .
# They -> they
# are -> be
# mentally -> mentally
# unstable -> unstable
# and -> and
# their -> their
# feelings -> feeling
# constantly -> constantly
# change -> change
# . -> .
# They -> they
# often -> often
# get -> get
# involved -> involve
# in -> in
# great -> great
# number -> number
# of -> of
# relationships -> relationship
# throughout -> throughout
# their -> their
# life -> life
# . -> .
# They -> they
# are -> be
# unconventional -> unconventional
# , -> ,
# difficult -> difficult
# to -> to
# get -> get
# along -> along
# with -> with
# , -> ,
# eccentric -> eccentric
# and -> and
# original -> original
# when -> when
# they -> they
# create -> create
# art -> art
# . -> .
# They -> they
# are -> be
# just -> just
# as -> as
# unstable -> unstable
# in -> in
# their -> their
# ways -> way
# of -> of
# dealing -> deal
# with -> with
# money -> money
# . -> .
# They -> they
# are -> be
# adventurous -> adventurous
# and -> and
# they -> they
# lead -> lead
# unstable -> unstable
# love -> love
# life -> life
# . -> .
#
#
#   ->
#
#
# Mars -> Mars
# Sextile -> Sextile
# Neptune -> Neptune
# ( -> (
# 2 -> 2
# ° -> °
# 16 -> 16
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# This -> this
# harmonious -> harmonious
# aspect -> aspect
# manifests -> manifest
# itself -> itself
# by -> by
# giving -> give
# people -> people
# great -> great
# fantasy -> fantasy
# , -> ,
# creativity -> creativity
# , -> ,
# idealism -> idealism
# and -> and
# artistic -> artistic
# talent -> talent
# . -> .
# However -> however
# , -> ,
# people -> people
# with -> with
# this -> this
# aspect -> aspect
# are -> be
# very -> very
# impractical -> impractical
# . -> .
# A -> a
# typical -> typical
# image -> image
# of -> of
# people -> people
# with -> with
# this -> this
# aspect -> aspect
# is -> be
# an -> an
# artist -> artist
# who -> who
# knows -> know
# the -> the
# entire -> entire
# world -> world
# of -> of
# culture -> culture
# but -> but
# he -> he
# or -> or
# she -> she
# is -> be
# useless -> useless
# in -> in
# his -> his
# or -> or
# her -> her
# private -> private
# life -> life
# . -> .
#
#
#   ->
#
#
# Mars -> Mars
# Trine -> Trine
# Pluto -> Pluto
# ( -> (
# 1 -> 1
# ° -> °
# 26 -> 26
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# This -> this
# aspect -> aspect
# increases -> increase
# Mars -> Mars
# ' -> '
# power -> power
# , -> ,
# so -> so
# these -> these
# people -> people
# are -> be
# hardworking -> hardworke
# and -> and
# very -> very
# thorough -> thorough
# in -> in
# all -> all
# their -> their
# activities -> activity
# . -> .
# However -> however
# , -> ,
# they -> they
# are -> be
# also -> also
# stubborn -> stubborn
# , -> ,
# and -> and
# if -> if
# they -> they
# have -> have
# a -> a
# goal -> goal
# , -> ,
# they -> they
# are -> be
# not -> not
# easily -> easily
# discouraged -> discourage
# from -> from
# trying -> try
# to -> to
# achieve -> achieve
# it -> it
# . -> .
# This -> this
# harmonious -> harmonious
# aspect -> aspect
# is -> be
# typical -> typical
# for -> for
# army -> army
# commanders -> commander
# and -> and
# it -> it
# gives -> give
# them -> they
# great -> great
# talent -> talent
# for -> for
# strategy -> strategy
# . -> .
# These -> these
# people´s -> people´s
# aim -> aim
# is -> be
# to -> to
# control -> control
# both -> both
# themselves -> themselves
# and -> and
# others -> other
# . -> .
# It -> it
# is -> be
# the -> the
# only -> only
# aspect -> aspect
# that -> that
# gives -> give
# people -> people
# the -> the
# ability -> ability
# to -> to
# achieve -> achieve
# their -> their
# objectives -> objective
# despite -> despite
# all -> all
# possible -> possible
# obstacles -> obstacle
# . -> .
#
#
#   ->
#
#
# Saturn -> Saturn
# Conjunction -> Conjunction
# Uranus -> Uranus
# ( -> (
# 0 -> 0
# ° -> °
# 32 -> 32
# ’ -> '
# , -> ,
# Applying -> apply
# ) -> )
#
#  ->
#
# This -> this
# conjunction -> conjunction
# gives -> give
# people -> people
# determination -> determination
# , -> ,
# originality -> originality
# , -> ,
# the -> the
# ability -> ability
# to -> to
# work -> work
# hard -> hard
# , -> ,
# and -> and
# the -> the
# ability -> ability
# to -> to
# find -> find
# new -> new
# solutions -> solution
# to -> to
# all -> all
# problems -> problem
# . -> .
# These -> these
# people -> people
# have -> have
# democratic -> democratic
# ideals -> ideal
# but -> but
# they -> they
# are -> be
# often -> often
# too -> too
# authoritative -> authoritative
# . -> .
#
#
#   ->
#
#
# Neptune -> Neptune
# Sextile -> Sextile
# Pluto -> Pluto
# ( -> (
# 0 -> 0
# ° -> °
# 50 -> 50
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# This -> this
# harmonious -> harmonious
# aspect -> aspect
# is -> be
# long -> long
# - -> -
# lasting -> last
# and -> and
# it -> it
# affects -> affect
# peace -> peace
# - -> -
# making -> make
# attitudes -> attitude
# . -> .
# In -> in
# connection -> connection
# with -> with
# other -> other
# aspects -> aspect
# it -> it
# further -> far
# enhances -> enhance
# peace -> peace
# - -> -
# building -> building
# and -> and
# transformative -> transformative
# actions -> action
# on -> on
# global -> global
# scale -> scale
# . -> .
#
#  ->
#
# Other -> other
# aspects -> aspect
#
#   ->
#
# Ascendant -> Ascendant
# Square -> Square
# Moon -> Moon
# ( -> (
# 3 -> 3
# ° -> °
# 22 -> 22
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# This -> this
# aspect -> aspect
# can -> can
# bring -> bring
# people -> people
# instability -> instability
# and -> and
# they -> they
# may -> may
# easily -> easily
# get -> get
# influenced -> influence
# by -> by
# others -> other
# . -> .
#
#
#   ->
#
#
# Ascendant -> Ascendant
# Trine -> Trine
# Jupiter -> Jupiter
# ( -> (
# 6 -> 6
# ° -> °
# 26 -> 26
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# The -> the
# positive -> positive
# thing -> thing
# about -> about
# this -> this
# aspect -> aspect
# is -> be
# that -> that
# these -> these
# people -> people
# are -> be
# generous -> generous
# , -> ,
# kind -> kind
# and -> and
# that -> that
# they -> they
# are -> be
# usually -> usually
# in -> in
# excellent -> excellent
# health -> health
# . -> .
#
#
#   ->
#
#
# MC -> MC
# Trine -> Trine
# Sun -> Sun
# ( -> (
# 2 -> 2
# ° -> °
# 55 -> 55
# ’ -> '
# , -> ,
# Applying -> apply
# ) -> )
#
#  ->
#
# This -> this
# aspect -> aspect
# indicates -> indicate
# the -> the
# ability -> ability
# to -> to
# succeed -> succeed
# using -> use
# own -> own
# means -> mean
# or -> or
# with -> with
# the -> the
# help -> help
# of -> of
# others -> other
# . -> .
#
#
#   ->
#
#
# MC -> MC
# Opposition -> Opposition
# Moon -> Moon
# ( -> (
# 8 -> 8
# ° -> °
# 14 -> 14
# ’ -> '
# , -> ,
# Applying -> apply
# ) -> )
#
#  ->
#
# This -> this
# aspect -> aspect
# can -> can
# bring -> bring
# instability -> instability
# in -> in
# professional -> professional
# life -> life
# and -> and
# these -> these
# people -> people
# often -> often
# have -> have
# unstable -> unstable
# professions -> profession
# . -> .
#
#
#   ->
#
#
# Node -> Node
# Square -> Square
# Sun -> Sun
# ( -> (
# 0 -> 0
# ° -> °
# 40 -> 40
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# Frequent -> frequent
# conflicts -> conflict
# and -> and
# tension -> tension
# among -> among
# the -> the
# demands -> demand
# of -> of
# the -> the
# Sun -> Sun
# and -> and
# the -> the
# tasks -> task
# of -> of
# the -> the
# lunar -> lunar
# node -> node
# that -> that
# are -> be
# waiting -> wait
# to -> to
# be -> be
# realised -> realise
# . -> .
# For -> for
# this -> this
# reason -> reason
# the -> the
# life -> life
# path -> path
# of -> of
# these -> these
# people -> people
# is -> be
# not -> not
# clear -> clear
# . -> .
# They -> they
# are -> be
# indecisive -> indecisive
# , -> ,
# chaotic -> chaotic
# and -> and
# they -> they
# have -> have
# restraints -> restraint
# . -> .
#
#
#   ->
#
#
# Node -> Node
# Square -> Square
# Mercury -> Mercury
# ( -> (
# 5 -> 5
# ° -> °
# 27 -> 27
# ’ -> '
# , -> ,
# Applying -> apply
# ) -> )
#
#  ->
#
# The -> the
# positive -> positive
# thing -> thing
# about -> about
# this -> this
# aspect -> aspect
# is -> be
# that -> that
# it -> it
# gives -> give
# people -> people
# intelligence -> intelligence
# and -> and
# good -> good
# life -> life
# orientation -> orientation
# . -> .
# They -> they
# enjoy -> enjoy
# searching -> search
# for -> for
# the -> the
# background -> background
# of -> of
# their -> their
# motives -> motive
# and -> and
# they -> they
# are -> be
# able -> able
# to -> to
# critically -> critically
# and -> and
# creatively -> creatively
# deal -> deal
# with -> with
# their -> their
# personality -> personality
# . -> .
# They -> they
# are -> be
# open -> open
# towards -> towards
# others -> other
# . -> .
# They -> they
# accept -> accept
# criticism -> criticism
# easily -> easily
# and -> and
# they -> they
# do -> do
# not -> not
# avoid -> avoid
# conflicts -> conflict
# . -> .
# They -> they
# manage -> manage
# life -> life
# challenges -> challenge
# with -> with
# the -> the
# help -> help
# of -> of
# their -> their
# analytical -> analytical
# and -> and
# logical -> logical
# thinking -> thinking
# . -> .
#
#  ->
#
# The -> the
# negative -> negative
# side -> side
# of -> of
# this -> this
# aspect -> aspect
# is -> be
# that -> that
# these -> these
# people -> people
# may -> may
# have -> have
# poor -> poor
# focus -> focus
# on -> on
# their -> their
# life -> life
# path -> path
# . -> .
# Their -> their
# intellect -> intellect
# always -> always
# finds -> find
# " -> "
# good -> good
# reasons -> reason
# " -> "
# that -> that
# stop -> stop
# them -> they
# from -> from
# focusing -> focus
# on -> on
# a -> a
# set -> set
# goal -> goal
# . -> .
# This -> this
# is -> be
# the -> the
# reason -> reason
# why -> why
# these -> these
# people -> people
# are -> be
# often -> often
# stubborn -> stubborn
# , -> ,
# have -> have
# defensive -> defensive
# attitudes -> attitude
# and -> and
# why -> why
# they -> they
# cling -> cling
# to -> to
# things -> thing
# that -> that
# put -> put
# them -> they
# at -> at
# disadvantage -> disadvantage
# . -> .
#
#
#   ->
#
#
# Node -> Node
# Square -> Square
# Venus -> Venus
# ( -> (
# 5 -> 5
# ° -> °
# 25 -> 25
# ’ -> '
# , -> ,
# Applying -> apply
# ) -> )
#
#  ->
#
# The -> the
# positive -> positive
# thing -> thing
# about -> about
# this -> this
# aspect -> aspect
# is -> be
# that -> that
# these -> these
# people -> people
# are -> be
# often -> often
# pleasant -> pleasant
# , -> ,
# graceful -> graceful
# , -> ,
# sexy -> sexy
# and -> and
# affectionate -> affectionate
# . -> .
# They -> they
# can -> can
# appreciate -> appreciate
# beauty -> beauty
# and -> and
# they -> they
# like -> like
# art -> art
# . -> .
# They -> they
# have -> have
# a -> a
# good -> good
# taste -> taste
# . -> .
# This -> this
# harmonious -> harmonious
# connection -> connection
# forms -> form
# the -> the
# focal -> focal
# point -> point
# of -> of
# their -> their
# life -> life
# and -> and
# it -> it
# helps -> help
# them -> they
# achieve -> achieve
# their -> their
# goals -> goal
# . -> .
# They -> they
# have -> have
# somewhat -> somewhat
# feminine -> feminine
# radiating -> radiating
# power -> power
# that -> that
# is -> be
# very -> very
# valuable -> valuable
# and -> and
# deserves -> deserve
# to -> to
# be -> be
# acknowledged -> acknowledge
# and -> and
# developed -> develop
# . -> .
#
#  ->
#
# The -> the
# negative -> negative
# side -> side
# of -> of
# this -> this
# aspect -> aspect
# is -> be
# that -> that
# it -> it
# can -> can
# be -> be
# difficult -> difficult
# for -> for
# these -> these
# people -> people
# to -> to
# find -> find
# inner -> inner
# peace -> peace
# because -> because
# their -> their
# love -> love
# life -> life
# is -> be
# in -> in
# constant -> constant
# conflict -> conflict
# with -> with
# the -> the
# direction -> direction
# of -> of
# their -> their
# life -> life
# . -> .
# They -> they
# can -> can
# experience -> experience
# feelings -> feeling
# of -> of
# unfulfillment -> unfulfillment
# and -> and
# they -> they
# may -> may
# have -> have
# great -> great
# need -> need
# for -> for
# affection -> affection
# that -> that
# is -> be
# very -> very
# hard -> hard
# to -> to
# satisfy -> satisfy
# . -> .
#
#
#   ->
#
#
# Node -> Node
# Sextile -> Sextile
# Jupiter -> Jupiter
# ( -> (
# 2 -> 2
# ° -> °
# 54 -> 54
# ’ -> '
# , -> ,
# Separating -> Separating
# ) -> )
#
#  ->
#
# The -> the
# positive -> positive
# thing -> thing
# about -> about
# this -> this
# aspect -> aspect
# is -> be
# that -> that
# these -> these
# people -> people
# are -> be
# confident -> confident
# in -> in
# their -> their
# abilities -> ability
# and -> and
# this -> this
# helps -> help
# them -> they
# overcome -> overcome
# challenges -> challenge
# in -> in
# life -> life
# . -> .
# Their -> their
# life -> life
# challenges -> challenge
# are -> be
# often -> often
# connected -> connect
# with -> with
# profound -> profound
# sensory -> sensory
# experience -> experience
# and -> and
# it -> it
# gives -> give
# people -> people
# luck -> luck
# on -> on
# their -> their
# life -> life
# journey -> journey
# . -> .
#
#  ->
#
# Declination -> Declination
# aspects -> aspect
# - -> -
# Parallels -> Parallels
# and -> and
# Contra -> Contra
# - -> -
# Parallels -> Parallels
#
#  ->
#
# Parallels -> Parallels
# and -> and
# Contra -> Contra
# - -> -
# Parallels -> Parallels
# are -> be
# aspects -> aspect
# , -> ,
# which -> which
# refer -> refer
# to -> to
# degrees -> degree
# of -> of
# declination -> declination
# above -> above
# or -> or
# below -> below
# the -> the
# celestial -> celestial
# equator -> equator
# . -> .
#
#  ->
#
# Parallel -> Parallel
# is -> be
# similar -> similar
# to -> to
# a -> a
# conjunction -> conjunction
# , -> ,
# but -> but
# usually -> usually
# provides -> provide
# benefits -> benefit
# . -> .
#
#  ->
#
# Contra -> Contra
# - -> -
# Parallel -> Parallel
# is -> be
# said -> say
# to -> to
# be -> be
# similar -> similar
# to -> to
# the -> the
# opposition -> opposition
# , -> ,
# but -> but
# weaker -> weak
# . -> .
#
#  ->
#
# Note -> note
# : -> :
# The -> the
# following -> follow
# parallel -> parallel
# and -> and
# contra -> contra
# - -> -
# parallel -> parallel
# interpretations -> interpretation
# are -> be
# the -> the
# same -> same
# as -> as
# the -> the
# interpretations -> interpretation
# used -> use
# for -> for
# the -> the
# conjunction -> conjunction
# and -> and
# opposition -> opposition
# . -> .
#
#   ->
#
# Sun -> Sun
# Parallel -> Parallel
# Venus -> Venus
# ( -> (
# 0 -> 0
# ° -> °
# 10 -> 10
# ’ -> '
# ) -> )
#
#  ->
#
# There -> there
# can -> can
# only -> only
# be -> be
# conjunction -> conjunction
# between -> between
# the -> the
# Sun -> Sun
# and -> and
# Venus -> Venus
# . -> .
# This -> this
# aspect -> aspect
# highlights -> highlight
# feminine -> feminine
# characteristics -> characteristic
# of -> of
# both -> both
# sexes -> sex
# . -> .
# It -> it
# also -> also
# supports -> support
# artistic -> artistic
# and -> and
# creative -> creative
# inclinations -> inclination
# . -> .
# These -> these
# people -> people
# are -> be
# often -> often
# optimistic -> optimistic
# and -> and
# they -> they
# enjoy -> enjoy
# the -> the
# company -> company
# of -> of
# other -> other
# people -> people
# . -> .
# They -> they
# have -> have
# a -> a
# good -> good
# taste -> taste
# for -> for
# fashionable -> fashionable
# clothes -> clothe
# . -> .
#
#
#   ->
#
#
# Sun -> Sun
# Contra -> Contra
# - -> -
# Parallel -> Parallel
# Saturn -> Saturn
# ( -> (
# 0 -> 0
# ° -> °
# 43 -> 43
# ’ -> '
# ) -> )
#
#  ->
#
# This -> this
# aspect -> aspect
# creates -> create
# two -> two
# groups -> group
# of -> of
# people -> people
# . -> .
# People -> People
# in -> in
# the -> the
# first -> first
# group -> group
# tend -> tend
# to -> to
# give -> give
# up -> up
# when -> when
# they -> they
# encounter -> encounter
# problems -> problem
# . -> .
# When -> when
# people -> people
# in -> in
# the -> the
# second -> second
# group -> group
# encounter -> encounter
# problems -> problem
# they -> they
# get -> get
# stimulated -> stimulate
# by -> by
# them -> they
# and -> and
# perform -> perform
# better -> well
# . -> .
# These -> these
# people -> people
# often -> often
# have -> have
# lower -> low
# self -> self
# - -> -
# esteem -> esteem
# that -> that
# can -> can
# be -> be
# improved -> improve
# by -> by
# good -> good
# work -> work
# . -> .
#
#
#   ->
#
#
# Sun -> Sun
# Contra -> Contra
# - -> -
# Parallel -> Parallel
# Uranus -> Uranus
# ( -> (
# 0 -> 0
# ° -> °
# 38 -> 38
# ’ -> '
# ) -> )
#
#  ->
#
# This -> this
# aspect -> aspect
# creates -> create
# people -> people
# that -> that
# are -> be
# too -> too
# individualistic -> individualistic
# , -> ,
# selfish -> selfish
# and -> and
# eccentric -> eccentric
# . -> .
# They -> they
# are -> be
# very -> very
# independent -> independent
# and -> and
# they -> they
# guard -> guard
# their -> their
# independence -> independence
# carefully -> carefully
# . -> .
# They -> they
# are -> be
# not -> not
# always -> always
# considerate -> considerate
# towards -> towards
# other -> other
# people -> people
# and -> and
# they -> they
# sometimes -> sometimes
# suffer -> suffer
# from -> from
# mental -> mental
# exhaustion -> exhaustion
# . -> .
# These -> these
# people -> people
# have -> have
# the -> the
# need -> need
# to -> to
# be -> be
# different -> different
# and -> and
# they -> they
# want -> want
# to -> to
# show -> show
# their -> their
# uniqueness -> uniqueness
# . -> .
# They -> they
# want -> want
# to -> to
# be -> be
# teachers -> teacher
# , -> ,
# mentors -> mentor
# and -> and
# examples -> example
# to -> to
# others -> other
# . -> .
# These -> these
# people -> people
# are -> be
# willing -> willing
# to -> to
# go -> go
# to -> to
# the -> the
# extremes -> extreme
# in -> in
# order -> order
# to -> to
# show -> show
# their -> their
# originality -> originality
# . -> .
# They -> they
# have -> have
# trouble -> trouble
# accepting -> accept
# authorities -> authority
# . -> .
# They -> they
# use -> use
# rebellion -> rebellion
# as -> as
# means -> mean
# of -> of
# attracting -> attract
# attention -> attention
# of -> of
# other -> other
# people -> people
# . -> .
#
#
#   ->
#
#
# Sun -> Sun
# Contra -> Contra
# - -> -
# Parallel -> Parallel
# Neptune -> Neptune
# ( -> (
# 0 -> 0
# ° -> °
# 53 -> 53
# ’ -> '
# ) -> )
#
#  ->
#
# This -> this
# aspect -> aspect
# creates -> create
# people -> people
# that -> that
# are -> be
# overly -> overly
# empathetic -> empathetic
# and -> and
# too -> too
# willing -> willing
# to -> to
# sacrifice -> sacrifice
# themselves -> themselves
# , -> ,
# and -> and
# thus -> thus
# they -> they
# may -> may
# easily -> easily
# be -> be
# used -> use
# by -> by
# others -> other
# or -> or
# cheated -> cheat
# . -> .
# These -> these
# people -> people
# should -> should
# stay -> stay
# away -> away
# from -> from
# drugs -> drug
# , -> ,
# alcohol -> alcohol
# and -> and
# tobacco -> tobacco
# because -> because
# they -> they
# have -> have
# considerable -> considerable
# tendencies -> tendency
# to -> to
# use -> use
# drugs -> drug
# and -> and
# alcohol -> alcohol
# to -> to
# solve -> solve
# their -> their
# problems -> problem
# . -> .
#
#
#   ->
#
#
# Venus -> Venus
# Contra -> Contra
# - -> -
# Parallel -> Parallel
# Saturn -> Saturn
# ( -> (
# 0 -> 0
# ° -> °
# 53 -> 53
# ’ -> '
# ) -> )
#
#  ->
#
# People -> People
# with -> with
# this -> this
# aspect -> aspect
# are -> be
# responsible -> responsible
# , -> ,
# reserved -> reserve
# and -> and
# hesitant -> hesitant
# . -> .
# They -> they
# also -> also
# have -> have
# restraints -> restraint
# that -> that
# are -> be
# often -> often
# the -> the
# result -> result
# of -> of
# poor -> poor
# parenting -> parenting
# or -> or
# fear -> fear
# of -> of
# other -> other
# authorities -> authority
# . -> .
# This -> this
# also -> also
# causes -> cause
# fear -> fear
# of -> of
# loss -> loss
# - -> -
# they -> they
# are -> be
# afraid -> afraid
# to -> to
# lose -> lose
# both -> both
# their -> their
# property -> property
# and -> and
# their -> their
# loved -> love
# ones -> one
# . -> .
# These -> these
# people -> people
# often -> often
# submit -> submit
# their -> their
# feelings -> feeling
# to -> to
# practicality -> practicality
# ( -> (
# typical -> typical
# manifestation -> manifestation
# of -> of
# this -> this
# is -> be
# getting -> getting
# married -> marry
# for -> for
# security -> security
# ) -> )
# . -> .
# They -> they
# subconsciously -> subconsciously
# fear -> fear
# unemployment -> unemployment
# and -> and
# poverty -> poverty
# . -> .
#
#
#   ->
#
#
# Venus -> Venus
# Contra -> Contra
# - -> -
# Parallel -> Parallel
# Uranus -> Uranus
# ( -> (
# 0 -> 0
# ° -> °
# 28 -> 28
# ’ -> '
# ) -> )
#
#  ->
#
# This -> this
# aspect -> aspect
# complicates -> complicate
# any -> any
# relationship -> relationship
# because -> because
# these -> these
# people -> people
# see -> see
# relationships -> relationship
# literally -> literally
# as -> as
# a -> a
# loss -> loss
# of -> of
# personal -> personal
# freedom -> freedom
# and -> and
# integrity -> integrity
# . -> .
# They -> they
# are -> be
# mentally -> mentally
# unstable -> unstable
# and -> and
# their -> their
# feelings -> feeling
# constantly -> constantly
# change -> change
# . -> .
# They -> they
# often -> often
# get -> get
# involved -> involve
# in -> in
# great -> great
# number -> number
# of -> of
# relationships -> relationship
# throughout -> throughout
# their -> their
# life -> life
# . -> .
# They -> they
# are -> be
# unconventional -> unconventional
# , -> ,
# difficult -> difficult
# to -> to
# get -> get
# along -> along
# with -> with
# , -> ,
# eccentric -> eccentric
# and -> and
# original -> original
# when -> when
# they -> they
# create -> create
# art -> art
# . -> .
# They -> they
# are -> be
# just -> just
# as -> as
# unstable -> unstable
# in -> in
# their -> their
# ways -> way
# of -> of
# dealing -> deal
# with -> with
# money -> money
# . -> .
# They -> they
# are -> be
# adventurous -> adventurous
# and -> and
# they -> they
# lead -> lead
# unstable -> unstable
# love -> love
# life -> life
# . -> .
#
#
#   ->
#
#
# Venus -> Venus
# Contra -> Contra
# - -> -
# Parallel -> Parallel
# Neptune -> Neptune
# ( -> (
# 1 -> 1
# ° -> °
# 03 -> 03
# ’ -> '
# ) -> )
#
#  ->
#
# This -> this
# aspect -> aspect
# causes -> cause
# considerable -> considerable
# romantic -> romantic
# feelings -> feeling
# that -> that
# complicate -> complicate
# life -> life
# and -> and
# put -> put
# these -> these
# people -> people
# into -> into
# intricate -> intricate
# situations -> situation
# . -> .
# They -> they
# often -> often
# give -> give
# priority -> priority
# to -> to
# their -> their
# own -> own
# fantasies -> fantasy
# over -> over
# reality -> reality
# . -> .
# Esoteric -> esoteric
# activities -> activity
# sometimes -> sometimes
# become -> become
# more -> more
# important -> important
# to -> to
# them -> they
# than -> than
# the -> the
# reality -> reality
# and -> and
# take -> take
# away -> away
# considerable -> considerable
# amounts -> amount
# of -> of
# energy -> energy
# from -> from
# the -> the
# relationship -> relationship
# . -> .
# These -> these
# people -> people
# should -> should
# try -> try
# to -> to
# be -> be
# more -> more
# rational -> rational
# and -> and
# have -> have
# " -> "
# thick -> thick
# skin -> skin
# " -> "
# . -> .
# They -> they
# are -> be
# usually -> usually
# very -> very
# lazy -> lazy
# . -> .
# For -> for
# artists -> artist
# , -> ,
# this -> this
# aspect -> aspect
# brings -> bring
# inspiration -> inspiration
# , -> ,
# creativity -> creativity
# , -> ,
# imagination -> imagination
# , -> ,
# and -> and
# very -> very
# good -> good
# taste -> taste
# . -> .
#
#
#   ->
#
#
# Saturn -> Saturn
# Parallel -> Parallel
# Neptune -> Neptune
# ( -> (
# 0 -> 0
# ° -> °
# 10 -> 10
# ’ -> '
# ) -> )
#
#  ->
#
# It -> it
# is -> be
# necessary -> necessary
# to -> to
# distinguish -> distinguish
# which -> which
# of -> of
# the -> the
# two -> two
# planets -> planet
# is -> be
# dominant -> dominant
# in -> in
# this -> this
# conjunction -> conjunction
# . -> .
# If -> if
# Saturn -> Saturn
# is -> be
# dominant -> dominant
# , -> ,
# then -> then
# the -> the
# person -> person
# is -> be
# able -> able
# to -> to
# keep -> keep
# his -> his
# imagination -> imagination
# under -> under
# control -> control
# and -> and
# use -> use
# it -> it
# constructively -> constructively
# to -> to
# fulfill -> fulfill
# his -> his
# dreams -> dream
# . -> .
# However -> however
# , -> ,
# if -> if
# Neptune -> Neptune
# is -> be
# dominant -> dominant
# , -> ,
# then -> then
# the -> the
# fantasy -> fantasy
# is -> be
# too -> too
# vivid -> vivid
# , -> ,
# and -> and
# these -> these
# people -> people
# fail -> fail
# to -> to
# fulfill -> fulfill
# their -> their
# fantasies -> fantasy
# and -> and
# they -> they
# become -> become
# frustrated -> frustrated
# . -> .
# They -> they
# start -> start
# living -> live
# in -> in
# their -> their
# fantasy -> fantasy
# world -> world
# and -> and
# they -> they
# become -> become
# practically -> practically
# useless -> useless
# . -> .
# These -> these
# people -> people
# can -> can
# experience -> experience
# great -> great
# spiritual -> spiritual
# passion -> passion
# - -> -
# they -> they
# may -> may
# expand -> expand
# their -> their
# consciousness -> consciousness
# at -> at
# all -> all
# costs -> cost
# and -> and
# use -> use
# all -> all
# possible -> possible
# means -> mean
# to -> to
# achieve -> achieve
# their -> their
# goal -> goal
# ( -> (
# spiritual -> spiritual
# fanatics -> fanatic
# ) -> )
# . -> .
#
#
#   ->
#
#
# Ascendant -> Ascendant
# Contra -> Contra
# - -> -
# Parallel -> Parallel
# Mercury -> Mercury
# ( -> (
# 0 -> 0
# ° -> °
# 12 -> 12
# ’ -> '
# ) -> )
#
#  ->
#
# The -> the
# positive -> positive
# thing -> thing
# about -> about
# this -> this
# aspect -> aspect
# is -> be
# that -> that
# it -> it
# gives -> give
# people -> people
# vitality -> vitality
# and -> and
# curiosity -> curiosity
# . -> .
# The -> the
# negative -> negative
# side -> side
# of -> of
# this -> this
# aspect -> aspect
# is -> be
# that -> that
# it -> it
# may -> may
# cause -> cause
# distractibility -> distractibility
# and -> and
# restlessness -> restlessness
# . -> .

# %% [markdown]
# ## Stemming

# %%
ps = PorterStemmer()
stemmed_text = [ps.stem(word) for word in preprocessed_tokens]
print("\nStemming:")
print(stemmed_text)
# Out:
# Stemming:
# ['st', 'hous', 'ascend', 'asc', 'physic', 'person', 'ascend', 'asc', 'symbol', 'basic', 'person', 'trait', 'physic', 'appear', 'tempera', 'behaviour', 'relationship', 'life', 'first', 'impress', 'person', 'give', 'ascend', 'capricorn', 'capricorn', 'ruler', 'saturn', 'peopl', 'capricorn', 'ascend', 'must', 'first', 'becom', 'awar', 'two', 'oppos', 'side', 'one', 'obedi', 'perform', 'duti', 'properli', 'need', 'manag', 'energi', 'well', 'requir', 'disciplin', 'selfcontrol', 'must', 'achiev', 'social', 'prestig', 'recognit', 'side', 'abil', 'organ', 'practic', 'matter', 'achiev', 'goal', 'also', 'abil', 'enjoy', 'sensual', 'pleasur', 'ruler', 'ascend', 'saturn', 'peopl', 'tend', 'act', 'slowli', 'caution', 'avoid', 'kind', 'control', 'love', 'solitud', 'hate', 'crowd', 'want', 'stand', 'isol', 'other', 'action', 'valu', 'time', 'may', 'becom', 'politician', 'consult', 'engin', 'etc', 'main', 'featur', 'endur', 'ruler', 'ascend', 'saturn', 'capricorn', 'peopl', 'rais', 'slowli', 'steadili', 'without', 'other', 'notic', 'action', 'glamor', 'credit', 'construct', 'push', 'accord', 'time', 'ruler', 'ascend', 'saturn', 'th', 'hous', 'peopl', 'predestin', 'hide', 'run', 'away', 'subject', 'illus', 'close', 'other', 'rich', 'inner', 'life', 'social', 'life', 'may', 'caus', 'life', 'test', 'selfpunish', 'selfdestruct', 'may', 'occur', 'planet', 'st', 'hous', 'planet', 'ascend', 'aspect', 'squar', 'moon', 'separ', 'trine', 'jupit', 'separ', 'contraparallel', 'mercuri', 'th', 'hous', 'medium', 'coeli', 'mc', 'career', 'prestig', 'reput', 'medium', 'coeli', 'mc', 'symbol', 'social', 'statu', 'career', 'reput', 'honour', 'fame', 'success', 'authorit', 'person', 'father', 'th', 'hous', 'libra', 'libra', 'ruler', 'venu', 'peopl', 'libra', 'tenth', 'hous', 'cusp', 'often', 'busi', 'work', 'togeth', 'partner', 'may', 'also', 'work', 'project', 'togeth', 'peopl', 'peopl', 'job', 'seem', 'profession', 'calm', 'prudent', 'kind', 'tact', 'work', 'also', 'cultur', 'organis', 'becom', 'supervisor', 'administr', 'best', 'object', 'aspect', 'person', 'reveal', 'commun', 'public', 'ruler', 'th', 'hous', 'venu', 'th', 'hous', 'career', 'peopl', 'relat', 'entertain', 'game', 'theatr', 'possibl', 'creativ', 'activ', 'profess', 'peopl', 'love', 'job', 'often', 'author', 'area', 'planet', 'th', 'hous', 'pluto', 'mc', 'aspect', 'trine', 'sun', 'appli', 'opposit', 'moon', 'appli', 'interpret', 'planet', 'sign', 'planet', 'hous', 'planet', 'describ', 'certain', 'process', 'happen', 'eg', 'mar', 'fight', 'saturn', 'limit', 'jupit', 'expand', 'sign', 'planet', 'locat', 'determin', 'planet', 'manifest', 'exampl', 'mar', 'may', 'manifest', 'way', 'ari', 'would', 'behav', 'vigor', 'irrit', 'manner', 'tauru', 'slowli', 'gradual', 'consist', 'hous', 'show', 'special', 'area', 'everyday', 'life', 'take', 'place', 'locat', 'hous', 'show', 'whether', 'exampl', 'mar', 'manifest', 'relationship', 'th', 'hous', 'employ', 'th', 'hous', 'famili', 'th', 'hous', 'elsewher', 'hint', 'planet', 'show', 'us', 'happen', 'sign', 'show', 'us', 'happen', 'hous', 'show', 'us', 'happen', 'planet', 'sun', 'self', 'individu', 'person', 'sun', 'symbol', 'person', 'ident', 'show', 'us', 'area', 'person', 'learn', 'independ', 'fulfil', 'potenti', 'differenti', 'other', 'shine', 'posit', 'sun', 'may', 'tell', 'us', 'profess', 'would', 'best', 'suit', 'charact', 'person', 'sun', 'gemini', 'peopl', 'born', 'sign', 'gemini', 'peopl', 'mani', 'talent', 'abl', 'use', 'skill', 'theori', 'practic', 'intellig', 'quickwit', 'peopl', 'interest', 'everyth', 'happen', 'around', 'quickli', 'adapt', 'new', 'situat', 'open', 'novel', 'thing', 'world', 'quickli', 'see', 'advantag', 'tri', 'show', 'novel', 'thing', 'other', 'also', 'benefit', 'conserv', 'peopl', 'often', 'understand', 'sociabl', 'peopl', 'repres', 'person', 'inspir', 'influenc', 'other', 'innat', 'charm', 'vigour', 'sun', 'th', 'hous', 'sun', 'fifth', 'hous', 'creat', 'creativ', 'peopl', 'strong', 'desir', 'selfexpress', 'art', 'develop', 'fer ...

# %% [markdown]
# ## POS Tagging

# %%
from nltk import pos_tag

pos_tags = pos_tag(preprocessed_tokens)
print("\nPOS Tagging:")
for word, tag in pos_tags:
    print(f"{word} -> {tag}")
# Out:
# POS Tagging:
# st -> NN
# house -> NN
# ascendant -> JJ
# asc -> JJ
# physical -> JJ
# personality -> NN
# ascendant -> NN
# asc -> NN
# symbolizes -> VBZ
# basic -> JJ
# personality -> NN
# traits -> NNS
# physical -> JJ
# appearance -> NN
# temperament -> NN
# behaviour -> NN
# relationship -> NN
# life -> NN
# first -> JJ
# impression -> NN
# person -> NN
# gives -> VBZ
# ascendant -> JJ
# capricorn -> JJ
# capricorn -> VBN
# ruler -> NN
# saturn -> NN
# people -> NNS
# capricorn -> VBP
# ascendant -> JJ
# must -> MD
# first -> RB
# become -> VB
# aware -> JJ
# two -> CD
# opposing -> VBG
# sides -> NNS
# one -> CD
# obedience -> NN
# performing -> VBG
# duties -> NNS
# properly -> RB
# need -> VBP
# manage -> NN
# energy -> NN
# well -> RB
# requires -> VBZ
# discipline -> JJ
# selfcontrol -> NN
# must -> MD
# achieve -> VB
# social -> JJ
# prestige -> NN
# recognition -> NN
# side -> NN
# ability -> NN
# organize -> VB
# practical -> JJ
# matters -> NNS
# achieve -> VBP
# goals -> NNS
# also -> RB
# ability -> NN
# enjoy -> VBP
# sensual -> JJ
# pleasures -> NNS
# ruler -> VBP
# ascendant -> JJ
# saturn -> NN
# people -> NNS
# tend -> VBP
# act -> JJ
# slowly -> RB
# caution -> NN
# avoid -> JJ
# kind -> NN
# control -> NN
# love -> VBP
# solitude -> NN
# hate -> NN
# crowds -> NN
# want -> VBP
# stand -> NN
# isolate -> NN
# others -> NNS
# actions -> NNS
# valued -> VBN
# time -> NN
# may -> MD
# become -> VB
# politicians -> NNS
# consultants -> NNS
# engineers -> NNS
# etc -> VBP
# main -> JJ
# feature -> NN
# endurance -> NN
# ruler -> NN
# ascendant -> JJ
# saturn -> NN
# capricorn -> JJ
# people -> NNS
# raise -> VBP
# slowly -> RB
# steadily -> RB
# without -> IN
# others -> NNS
# noticing -> VBG
# actions -> NNS
# glamorous -> JJ
# creditable -> JJ
# constructive -> JJ
# push -> NN
# accordance -> NN
# time -> NN
# ruler -> NN
# ascendant -> JJ
# saturn -> NN
# th -> NN
# house -> NN
# people -> NNS
# predestined -> VBD
# hide -> JJ
# run -> VB
# away -> RB
# subject -> JJ
# illusions -> NNS
# closing -> VBG
# others -> NNS
# rich -> JJ
# inner -> JJ
# life -> NN
# social -> JJ
# life -> NN
# may -> MD
# cause -> VB
# life -> NN
# test -> NN
# selfpunishment -> NN
# selfdestruction -> NN
# may -> MD
# occur -> VB
# planets -> NNS
# st -> JJ
# house -> NN
# planet -> NN
# ascendant -> JJ
# aspects -> NNS
# square -> JJ
# moon -> NN
# separating -> VBG
# trine -> JJ
# jupiter -> NN
# separating -> VBG
# contraparallel -> JJ
# mercury -> NN
# th -> NN
# house -> NN
# medium -> NN
# coeli -> NN
# mc -> NNP
# career -> NN
# prestige -> NN
# reputation -> NN
# medium -> NN
# coeli -> NN
# mc -> NN
# symbolizes -> VBZ
# social -> JJ
# status -> NN
# career -> NN
# reputation -> NN
# honours -> NNS
# fame -> NN
# success -> NN
# authoritative -> JJ
# personality -> NN
# father -> RB
# th -> JJ
# house -> NN
# libra -> NN
# libra -> VBZ
# ruler -> JJ
# venus -> NN
# people -> NNS
# libra -> VBP
# tenth -> JJ
# house -> NN
# cusp -> NN
# often -> RB
# business -> NN
# work -> NN
# together -> RB
# partner -> NN
# may -> MD
# also -> RB
# work -> VB
# project -> NN
# together -> RB
# people -> NNS
# people -> NNS
# job -> NN
# seem -> VBP
# professional -> JJ
# calm -> NN
# prudent -> NN
# kind -> NN
# tactful -> JJ
# working -> NN
# also -> RB
# cultured -> VBD
# organised -> JJ
# become -> NN
# supervisors -> NNS
# administrators -> VBP
# best -> RB
# objective -> JJ
# aspects -> NNS
# personality -> NN
# revealed -> VBD
# communicate -> JJ
# public -> JJ
# ruler -> NN
# th -> NN
# house -> NN
# venus -> IN
# th -> JJ
# house -> NN
# career -> NN
# people -> NNS
# related -> JJ
# entertainment -> NN
# games -> NNS
# theatre -> VBP
# possibility -> NN
# creative -> JJ
# activity -> NN
# profession -> NN
# people -> NNS
# love -> VBP
# job -> NN
# often -> RB
# authority -> JJ
# area -> NN
# planets -> NNS
# th -> VBP
# house -> NN
# pluto -> NN
# mc -> NN
# aspects -> NNS
# trine -> VBP
# sun -> NN
# applying -> VBG
# opposition -> NN
# moon -> NN
# applying -> VBG
# interpretations -> NNS
# planets -> NNS
# signs -> NNS
# planets -> NNS
# houses -> NNS
# planets -> NNS
# describe -> VBP
# certain -> JJ
# process -> NN
# happening -> VBG
# eg -> JJ
# mars -> NNS
# fights -> NNS
# saturn -> VBP
# limits -> NNS
# jupiter -> NN
# expands -> VBZ
# sign -> JJ
# planet -> NN
# located -> VBN
# determines -> NNS
# planet -> IN
# manifesting -> VBG
# example -> NN
# mars -> NNS
# may -> MD
# manifest -> VB
# way -> NN
# aries -> NNS
# would -> MD
# behave -> VB
# vigorously -> RB
# irritably -> RB
# manner -> RBR
# taurus -> JJ
# slowly -> RB
# gradually -> RB
# consistently -> RB
# houses -> NNS
# show -> VBP
# special -> JJ
# areas -> NNS
# everyday -> JJ
# life -> NN
# takes -> VBZ
# place -> NN
# location -> NN
# house -> NN
# shows -> VBZ
# whether -> IN
# example -> NN
# mars -> NNS
# manifests -> VBZ
# relationships -> NNS
# th -> NN
# house -> NN
# employment -> NN
# th -> NN
# house -> NN
# family -> NN
# th -> NN
# house -> NN
# elsewhere -> RB
# hint -> JJ
# planets -> NNS
# show -> VBP
# us -> PRP
# happening -> VBG
# signs -> NNS
# show -> VBP
# us -> PRP
# happening -> VBG
# houses -> NNS
# show -> VBP
# us -> PRP
# happening -> VBG
# planets -> NNS
# sun -> VBD
# self -> PRP
# individuality -> NN
# personality -> NN
# sun -> NN
# symbolizes -> VBZ
# personal -> JJ
# identity -> NN
# shows -> VBZ
# us -> PRP
# areas -> NNS
# person -> NN
# learn -> VBP
# independent -> JJ
# fulfill -> JJ
# potential -> JJ
# differentiate -> NN
# others -> NNS
# shine -> VBP
# position -> NN
# sun -> NN
# may -> MD
# tell -> VB
# us -> PRP
# profession -> NN
# would -> MD
# best -> VB
# suit -> NN
# character -> NN
# person -> NN
# sun -> JJ
# gemini -> NN
# people -> NNS
# born -> VBP
# sign -> JJ
# gemini -> JJ
# people -> NNS
# many -> JJ
# talents -> NNS
# able -> JJ
# use -> NN
# skills -> NNS
# theory -> JJ
# practice -> NN
# intelligent -> NN
# quickwitted -> VBD
# people -> NNS
# interested -> JJ
# everything -> NN
# happen -> VB
# around -> IN
# quickly -> RB
# adapt -> VB
# new -> JJ
# situation -> NN
# open -> JJ
# novel -> JJ
# things -> NNS
# world -> NN
# quickly -> RB
# see -> VB
# advantages -> NNS
# try -> VB
# show -> VBP
# novel -> JJ
# things -> NNS
# others -> NNS
# also -> RB
# benefit -> VBP
# conservative -> JJ
# people -> NNS
# often -> RB
# understanding -> VBG
# sociable -> JJ
# people -> NNS
# representative -> JJ
# personalities -> NNS
# inspire -> VBP
# influence -> NN
# others -> NNS
# innate -> VBP
# charm -> JJ
# vigour -> NN
# sun -> NN
# th -> NN
# house -> NN
# sun -> VBD
# fifth -> JJ
# house -> NN
# creates -> VBZ
# creative -> JJ
# people -> NNS
# strong -> JJ
# desire -> NN
# selfexpression -> NN
# art -> NN
# development -> NN
# fertility -> NN
# people -> NNS
# need -> VBP
# others -> NNS
# notice -> JJ
# appreciate -> NN
# may -> MD
# tendency -> VB
# brag -> NN
# least -> JJS
# try -> JJ
# look -> NN
# best -> JJS
# happy -> JJ
# merry -> NN
# people -> NNS
# many -> JJ
# friends -> NNS
# may -> MD
# bit -> VB
# childish -> JJ
# sometimes -> RB
# try -> JJ
# mature -> NN
# subtle -> JJ
# order -> NN
# theatrical -> JJ
# selfish -> JJ
# sun -> NN
# fifth -> NN
# house -> NN
# gives -> VBZ
# people -> NNS
# considerable -> JJ
# amount -> JJ
# selfconfidence -> NN
# people -> NNS
# often -> RB
# focus -> VBP
# children -> NNS
# children -> NNS
# general -> JJ
# tend -> VBP
# spoil -> NN
# children -> NNS
# pass -> VBP
# dreams -> NNS
# sun -> JJ
# aspects -> NNS
# sextile -> JJ
# moon -> NN
# separating -> VBG
# conjunction -> NN
# mercury -> NN
# applying -> VBG
# conjunction -> NN
# venus -> NN
# applying -> VBG
# square -> JJ
# mars -> NNS
# separating -> VBG
# trine -> NN
# mc -> NN
# applying -> VBG
# square -> JJ
# node -> NN
# separating -> VBG
# parallel -> JJ
# venus -> NN
# contraparallel -> JJ
# saturn -> NN
# contraparallel -> JJ
# uranus -> JJ
# contraparallel -> NN
# neptune -> JJ
# moon -> NN
# emotions -> NNS
# instincts -> VBZ
# roots -> NNS
# mother -> RB
# place -> VBP
# horoscope -> NN
# moon -> NN
# tells -> NNS
# us -> PRP
# gives -> VBZ
# person -> NN
# sense -> JJ
# security -> NN
# find -> VBP
# describes -> JJ
# sensitive -> JJ
# instinctively -> RB
# interact -> JJ
# surroundings -> NNS
# moon -> NN
# also -> RB
# tells -> VBZ
# us -> PRP
# childhood -> NN
# experiences -> VBZ
# mother -> RB
# third -> JJ
# quarter -> NN
# moon -> NN
# waning -> VBG
# moon -> NN
# moon -> NN
# phase -> NN
# degree -> NN
# reality -> NN
# check -> NN
# revision -> NN
# integration -> NN
# cleansing -> VBG
# moon -> NN
# aries -> NNS
# feeling -> VBG
# uncertainty -> NN
# make -> VBP
# solve -> NN
# problems -> NNS
# faster -> RBR
# natural -> JJ
# rush -> NN
# deadline -> NN
# try -> NN
# slow -> JJ
# decide -> NN
# want -> VBP
# proceed -> NN
# comfortable -> JJ
# pace -> NN
# moon -> NN
# th -> NN
# house -> NN
# moon -> VBD
# fourth -> JJ
# house -> NN
# means -> VBZ
# strong -> JJ
# connection -> NN
# home -> NN
# house -> NN
# people -> NNS
# live -> VBP
# also -> RB
# home -> NN
# broader -> JJR
# sense -> NN
# country -> NN
# traditions -> NNS
# nature -> VBP
# etc -> JJ
# people -> NNS
# usually -> RB
# need -> VBP
# feel -> VB
# connection -> NN
# past -> IN
# interested -> JJ
# things -> NNS
# like -> IN
# antiques -> NNS
# family -> NN
# tree -> VBP
# often -> RB
# remain -> VBP
# strong -> JJ
# influence -> NN
# parents -> NNS
# moon -> VBP
# fourth -> JJ
# house -> NN
# indicates -> VBZ
# want -> VBP
# distance -> NN
# reality -> NN
# subjectivist -> JJ
# inclinations -> NNS
# people -> NNS
# may -> MD
# insecure -> VB
# nature -> NN
# needs -> VBZ
# stable -> JJ
# reliable -> JJ
# roots -> NNS
# moon -> NN
# aspects -> NNS
# sextile -> VBP
# sun -> NN
# separating -> VBG
# sextile -> JJ
# mercury -> NN
# separating -> VBG
# sextile -> JJ
# venus -> NN
# separating -> VBG
# trine -> JJ
# saturn -> NN
# applying -> VBG
# trine -> JJ
# uranus -> NN
# applying -> VBG
# square -> JJ
# ascendant -> JJ
# separating -> VBG
# opposition -> NN
# mc -> NN
# applying -> VBG
# mercury -> NN
# thinking -> VBG
# communication -> NN
# intellect -> NN
# learning -> VBG
# mercury -> NN
# planet -> NN
# brings -> VBZ
# us -> PRP
# interest -> NN
# intellectual -> JJ
# things -> NNS
# teaching -> VBG
# learning -> NN
# also -> RB
# indicates -> VBZ
# depth -> NN
# want -> VBP
# study -> NN
# things -> NNS
# gives -> VBZ
# us -> PRP
# natural -> JJ
# intelligence -> NN
# ability -> NN
# analyse -> NN
# reproduce -> VBP
# mercury -> NN
# gemini -> NN
# people -> NNS
# mercury -> VBP
# gemini -> JJ
# young -> JJ
# minds -> NNS
# full -> JJ
# energy -> NN
# want -> VBP
# discover -> IN
# new -> JJ
# things -> NNS
# move -> VBP
# one -> CD
# argument -> NN
# another -> DT
# try -> NN
# different -> JJ
# hobbies -> NNS
# work -> VBP
# discussions -> NNS
# interesting -> VBG
# people -> NNS
# usually -> RB
# try -> VBP
# many -> JJ
# different -> JJ
# jobs -> NNS
# jobs -> NNS
# enthusiasm -> VBP
# commitment -> NN
# people -> NNS
# also -> RB
# talented -> VBD
# public -> JJ
# speakers -> NNS
# said -> VBD
# mercury -> NN
# feels -> NNS
# well -> RB
# air -> RB
# signs -> NNS
# bit -> RB
# shallow -> JJ
# people -> NNS
# like -> IN
# study -> NN
# things -> NNS
# greatest -> JJS
# detail -> NN
# air -> NN
# ruling -> VBG
# element -> NN
# definitely -> RB
# solid -> JJ
# substance -> NN
# responsible -> JJ
# probably -> RB
# one -> CD
# shortcoming -> VBG
# mercury -> NN
# th -> NN
# house -> NN
# mercury -> NN
# fifth -> JJ
# house -> NN
# represents -> VBZ
# connection -> NN
# house -> NN
# creativity -> NN
# children -> NNS
# position -> NN
# usually -> RB
# means -> VBZ
# artistic -> JJ
# creative -> JJ
# talents -> NNS
# good -> JJ
# ability -> NN
# express -> NN
# thoughts -> NNS
# orally -> RB
# people -> NNS
# ability -> NN
# express -> VBP
# dramatically -> RB
# powerfully -> RB
# talented -> JJ
# teachers -> NNS
# actors -> NNS
# mentally -> RB
# competitive -> JJ
# require -> NN
# mental -> JJ
# activity -> NN
# mercury -> NN
# fifth -> NN
# house -> NN
# also -> RB
# indicates -> VBZ
# business -> NN
# activities -> NNS
# investments -> NNS
# creates -> NNS
# character -> VBP
# may -> MD
# critical -> JJ
# analytical -> JJ
# attitude -> NN
# towards -> NNS
# personal -> JJ
# relationships -> NNS
# life -> NN
# mercury -> NN
# aspects -> NNS
# conjunction -> NN
# sun -> NN
# applying -> VBG
# sextile -> JJ
# moon -> NN
# separating -> VBG
# conjunction -> NN
# venus -> NN
# separating -> VBG
# opposition -> NN
# saturn -> NN
# separating -> VBG
# opposition -> NN
# uranus -> IN
# separating -> VBG
# square -> JJ
# node -> JJ
# applying -> VBG
# contraparallel -> NN
# ascendant -> JJ
# venus -> NN
# sensuality -> NN
# love -> VBP
# harmony -> NN
# pleasure -> NN
# venus -> NN
# symbolizes -> VBZ
# attractivity -> NN
# sign -> NN
# venus -> NN
# tells -> VBZ
# us -> PRP
# attracted -> VBD
# enables -> NNS
# us -> PRP
# give -> VBP
# receive -> JJ
# love -> NN
# affection -> NN
# beauty -> NN
# happiness -> NN
# values -> NNS
# principles -> NNS
# negative -> JJ
# side -> NN
# represents -> VBZ
# weakness -> NN
# shallowness -> NN
# venus -> NN
# gemini -> NN
# gemini -> NN
# sign -> NN
# youth -> NN
# people -> NNS
# strong -> JJ
# urge -> JJ
# prevent -> NN
# stagnation -> NN
# maintain -> VBP
# flexibility -> JJ
# relationships -> NNS
# believe -> VBP
# relationship -> NN
# without -> IN
# freedom -> NN
# deemed -> VBN
# fail -> JJ
# venus -> NN
# gemini -> NN
# compared -> VBN
# love -> IN
# bud -> NN
# rather -> RB
# love -> CC
# full -> JJ
# bloom -> NN
# must -> MD
# given -> VBN
# opportunity -> NN
# bloom -> NN
# people -> NNS
# like -> IN
# diversity -> NN
# spark -> NN
# illuminate -> NN
# love -> NN
# beloved -> VBD
# partner -> NN
# people -> NNS
# venus -> VBP
# gemini -> JJ
# typically -> RB
# make -> VBP
# friends -> NNS
# acquaintances -> NNS
# easily -> RB
# like -> IN
# meet -> NN
# people -> NNS
# sexual -> VBP
# family -> NN
# relationships -> NNS
# heart -> NN
# diverse -> VBZ
# social -> JJ
# relationships -> NNS
# lungs -> NNS
# breathe -> VBP
# life -> NN
# venus -> NN
# th -> NN
# house -> NN
# venus -> IN
# fifth -> JJ
# house -> NN
# causes -> VBZ
# attraction -> NN
# opposite -> JJ
# sex -> NN
# creates -> VBZ
# romantic -> JJ
# popular -> JJ
# people -> NNS
# love -> VBP
# life -> NN
# position -> NN
# venus -> NN
# also -> RB
# brings -> VBZ
# popularity -> NN
# among -> IN
# children -> NNS
# people -> NNS
# usually -> RB
# become -> VBP
# excellent -> JJ
# parents -> NNS
# get -> VBP
# along -> IN
# young -> JJ
# people -> NNS
# relationships -> NNS
# benefit -> VBP
# way -> NN
# probably -> RB
# provide -> VB
# services -> NNS
# young -> JJ
# people -> NNS
# work -> VBP
# creative -> JJ
# people -> NNS
# often -> RB
# potential -> JJ
# become -> VBN
# successful -> JJ
# actors -> NNS
# venus -> VBP
# aspects -> NNS
# conjunction -> NN
# sun -> NN
# applying -> VBG
# sextile -> JJ
# moon -> NN
# separating -> VBG
# conjunction -> NN
# mercury -> NN
# separating -> VBG
# opposition -> NN
# saturn -> NN
# separating -> VBG
# opposition -> NN
# uranus -> IN
# separating -> VBG
# square -> JJ
# node -> JJ
# applying -> VBG
# parallel -> JJ
# sun -> NN
# contraparallel -> JJ
# saturn -> NN
# contraparallel -> JJ
# uranus -> JJ
# contraparallel -> NN
# neptune -> JJ
# mars -> NNS
# activity -> NN
# energy -> NN
# courage -> NN
# assertiveness -> JJ
# mars -> NNS
# symbolizes -> VBP
# need -> VBP
# get -> VB
# want -> JJ
# means -> NNS
# driving -> VBG
# force -> NN
# includes -> VBZ
# sex -> NN
# drive -> NN
# initiative -> JJ
# courage -> NN
# mars -> NNS
# tells -> VBZ
# us -> PRP
# desires -> VBZ
# sensuality -> NN
# courage -> NN
# also -> RB
# tells -> VBZ
# us -> PRP
# able -> JJ
# overcome -> JJ
# obstacles -> NNS
# active -> JJ
# mars -> NNS
# pisces -> VBZ
# mars -> NNS
# pisces -> VBZ
# gives -> VBZ
# people -> NNS
# opportunity -> NN
# work -> NN
# professions -> NNS
# one -> CD
# come -> NN
# direct -> JJ
# contact -> NN
# public -> NN
# exercises -> VBZ
# authority -> NN
# detached -> VBD
# workplace -> NN
# people -> NNS
# work -> VBP
# example -> NN
# detectives -> NNS
# prison -> VBP
# wardens -> NNS
# doctors -> NNS
# hospitals -> NNS
# may -> MD
# also -> RB
# work -> VB
# desolate -> JJ
# places -> NNS
# example -> NN
# oil -> NN
# rigs -> VBP
# people -> NNS
# mars -> NNS
# pisces -> NNS
# get -> VBP
# want -> JJ
# delicate -> NN
# indirect -> NN
# means -> VBZ
# tend -> VBP
# secret -> JJ
# love -> NN
# affairs -> NNS
# successfully -> RB
# hide -> VB
# relationship -> NN
# public -> JJ
# eye -> NN
# actions -> NNS
# affected -> VBD
# strong -> JJ
# emotional -> JJ
# undercurrents -> NNS
# want -> VBP
# negatively -> RB
# influence -> JJ
# efforts -> NNS
# reach -> VBP
# goals -> NNS
# figure -> VBP
# emotional -> JJ
# undercurrents -> NNS
# mean -> JJ
# mars -> NNS
# nd -> RB
# house -> NN
# mars -> NNS
# second -> JJ
# house -> NN
# suggests -> VBZ
# person -> NN
# looking -> VBG
# material -> JJ
# financial -> JJ
# gains -> NNS
# successful -> JJ
# area -> NN
# energy -> NN
# drives -> NNS
# make -> VBP
# money -> NN
# time -> NN
# forces -> NNS
# spend -> VBP
# everything -> NN
# earn -> NN
# need -> VBP
# learn -> JJR
# control -> VB
# financial -> JJ
# situation -> NN
# hard -> RB
# natural -> JJ
# talent -> NN
# people -> NNS
# competitive -> JJ
# business -> NN
# financial -> JJ
# matters -> NNS
# often -> RB
# run -> VBP
# business -> NN
# afraid -> NN
# taking -> VBG
# risks -> NNS
# area -> NN
# determined -> VBD
# reach -> NN
# goals -> NNS
# mars -> NNS
# aspects -> NNS
# square -> VBP
# sun -> JJ
# separating -> VBG
# sextile -> NN
# neptune -> NN
# separating -> VBG
# trine -> JJ
# pluto -> NN
# separating -> VBG
# jupiter -> NN
# happiness -> NN
# optimism -> NN
# expansion -> NN
# jupiter -> NN
# symbolizes -> VBZ
# growth -> NN
# expansion -> NN
# laws -> NNS
# faith -> VBP
# ethics -> NNS
# guide -> JJ
# represents -> VBZ
# sense -> NN
# development -> NN
# support -> NN
# lead -> NN
# opportunities -> NNS
# wealth -> VBP
# faith -> JJ
# however -> RB
# jupiter -> NN
# damaged -> VBD
# person -> NN
# becomes -> VBZ
# immoral -> JJ
# extremist -> NN
# jupiter -> NN
# taurus -> NN
# people -> NNS
# jupiter -> VBP
# taurus -> JJ
# believe -> VBP
# importance -> NN
# financial -> JJ
# security -> NN
# social -> JJ
# status -> NN
# comfort -> NN
# values -> NNS
# provide -> VBP
# greater -> JJR
# lesser -> JJR
# extent -> NN
# capable -> JJ
# attracting -> VBG
# wealth -> NN
# way -> NN
# jupiter -> NN
# taurus -> NN
# brings -> VBZ
# question -> NN
# money -> NN
# growth -> NN
# stabilisation -> NN
# means -> VBZ
# improvement -> NN
# material -> NN
# conditions -> NNS
# closely -> RB
# related -> JJ
# understanding -> JJ
# stability -> NN
# natural -> JJ
# state -> NN
# maintained -> VBD
# allowing -> VBG
# resources -> NNS
# flow -> RB
# well -> RB
# people -> NNS
# jupiter -> VBP
# taurus -> JJ
# understand -> NN
# wisdom -> NN
# likely -> RB
# find -> VBP
# managerial -> JJ
# position -> NN
# become -> VBN
# asset -> NN
# managers -> NNS
# someone -> NN
# responsible -> JJ
# growth -> NN
# somebodys -> JJ
# assets -> NNS
# jupiter -> VBP
# th -> JJ
# house -> NN
# jupiter -> NN
# fourth -> JJ
# house -> NN
# means -> VBZ
# planet -> JJ
# development -> NN
# expansion -> NN
# play -> NN
# important -> JJ
# role -> NN
# home -> NN
# family -> NN
# people -> NNS
# influence -> NN
# parents -> NNS
# quite -> RB
# old -> JJ
# parents -> NNS
# especially -> RB
# mothers -> NNS
# take -> VBP
# good -> JJ
# care -> NN
# help -> NN
# give -> VB
# good -> JJ
# manners -> NNS
# education -> VBP
# result -> NN
# high -> JJ
# quality -> NN
# education -> NN
# advantages -> VBZ
# social -> JJ
# life -> NN
# life -> NN
# people -> NNS
# full -> JJ
# happy -> JJ
# especially -> RB
# later -> JJ
# life -> NN
# jupiter -> NN
# aspects -> NNS
# trine -> VBP
# ascendant -> JJ
# separating -> VBG
# sextile -> JJ
# node -> NN
# separating -> VBG
# saturn -> JJ
# restriction -> NN
# order -> NN
# maturity -> NN
# time -> NN
# saturn -> VB
# strict -> JJ
# teacher -> NN
# able -> JJ
# ruthlessly -> RB
# examine -> VBP
# maturity -> NN
# however -> RB
# despot -> NN
# also -> RB
# archetype -> JJ
# sage -> NN
# uses -> VBZ
# pain -> NN
# means -> NNS
# get -> VBP
# attention -> NN
# focus -> NN
# continue -> VBP
# develop -> VB
# saturn -> JJ
# capricorn -> JJ
# people -> NNS
# saturn -> VBP
# capricorn -> JJ
# keep -> VB
# track -> NN
# goals -> NNS
# unquenchable -> JJ
# determination -> NN
# regardless -> NN
# time -> NN
# compared -> VBN
# rock -> NN
# gibraltar -> NN
# without -> IN
# exaggeration -> NN
# spite -> NN
# obstacles -> NNS
# failures -> NNS
# eventually -> RB
# achieve -> VBP
# great -> JJ
# success -> NN
# respected -> VBD
# others -> NNS
# people -> NNS
# saturn -> VBP
# capricorn -> VBN
# learn -> NN
# know -> JJ
# place -> NN
# people -> NNS
# tend -> VBP
# succumb -> JJ
# society -> NN
# expects -> VBZ
# people -> NNS
# social -> JJ
# status -> NN
# class -> NN
# belief -> NN
# race -> NN
# etc -> NN
# yet -> RB
# compensatory -> JJ
# reaction -> NN
# may -> MD
# occur -> VB
# may -> MD
# want -> VB
# avoid -> JJ
# resist -> NN
# expected -> VBN
# basis -> NN
# social -> JJ
# status -> NN
# class -> NN
# race -> NN
# want -> VBP
# put -> VBN
# box -> RP
# saturn -> NN
# th -> NN
# house -> NN
# saturn -> VBD
# twelfth -> JJ
# house -> NN
# suggests -> VBZ
# work -> VBP
# background -> NN
# usually -> RB
# large -> JJ
# organisation -> NN
# people -> NNS
# usually -> RB
# achieve -> VBP
# recognition -> NN
# abilities -> NNS
# results -> NNS
# usually -> RB
# doubt -> VBP
# abilities -> NNS
# long -> RB
# solitude -> VBP
# usually -> RB
# loners -> NNS
# lack -> VBP
# selfconfidence -> NN
# saturn -> NN
# aspects -> NNS
# trine -> VBP
# moon -> NN
# applying -> VBG
# opposition -> NN
# mercury -> NN
# separating -> VBG
# opposition -> NN
# venus -> NN
# separating -> VBG
# conjunction -> NN
# uranus -> IN
# applying -> VBG
# contraparallel -> JJ
# sun -> NN
# contraparallel -> NN
# venus -> NN
# parallel -> JJ
# neptune -> JJ
# uranus -> JJ
# originality -> NN
# freedom -> NN
# revolution -> NN
# uranus -> JJ
# power -> NN
# awakening -> VBG
# often -> RB
# means -> VBZ
# disruption -> JJ
# change -> NN
# events -> NNS
# influence -> NN
# uranus -> RB
# unexpected -> VBD
# unpredictable -> JJ
# forcing -> VBG
# us -> PRP
# things -> NNS
# new -> JJ
# way -> NN
# face -> NN
# truth -> NN
# issue -> NN
# uranus -> JJ
# sagittarius -> JJ
# note -> NN
# uranus -> IN
# slow -> JJ
# transpersonal -> JJ
# planet -> NN
# may -> MD
# remain -> VB
# single -> JJ
# sign -> NN
# many -> JJ
# years -> NNS
# description -> VBP
# uranus -> JJ
# sagittarius -> NN
# therefore -> RB
# valid -> JJ
# entire -> JJ
# generation -> NN
# people -> NNS
# general -> JJ
# characteristic -> JJ
# personality -> NN
# description -> NN
# uranus -> IN
# th -> JJ
# house -> NN
# people -> NNS
# uranus -> VBP
# sagittarius -> JJ
# strive -> JJ
# spiritual -> JJ
# progress -> NN
# intellectual -> JJ
# growth -> NN
# often -> RB
# revolutionary -> JJ
# thoughts -> NNS
# see -> VBP
# races -> NNS
# equals -> NNS
# often -> RB
# fight -> VBP
# xenophobia -> NNS
# love -> VB
# flying -> VBG
# consider -> VB
# expeditions -> NNS
# space -> NN
# exciting -> VBG
# bring -> VBG
# new -> JJ
# directions -> NNS
# philosophy -> VBP
# optimistic -> JJ
# tend -> VBP
# make -> VBP
# unexpected -> JJ
# unplanned -> JJ
# journeys -> NN
# countries -> NNS
# uranus -> VBP
# th -> JJ
# house -> NN
# uranus -> JJ
# twelfth -> JJ
# house -> NN
# suggests -> VBZ
# volatility -> NN
# changes -> NNS
# subconscious -> JJ
# mind -> NN
# mean -> VBP
# subconscious -> JJ
# feeling -> NN
# imprisonment -> NN
# desire -> NN
# liberation -> NN
# independence -> NN
# people -> NNS
# like -> IN
# spend -> JJ
# time -> NN
# alone -> RB
# often -> RB
# find -> JJ
# job -> NN
# work -> NN
# independently -> RB
# gifted -> VBD
# researchers -> NNS
# may -> MD
# good -> VB
# mental -> JJ
# potential -> JJ
# need -> NN
# accept -> JJ
# life -> NN
# stop -> VBD
# subconsciously -> RB
# opposition -> NN
# uranus -> JJ
# aspects -> NNS
# trine -> VBP
# moon -> NN
# applying -> VBG
# opposition -> NN
# mercury -> NN
# separating -> VBG
# opposition -> NN
# venus -> NN
# separating -> VBG
# conjunction -> NN
# saturn -> NN
# applying -> VBG
# contraparallel -> JJ
# sun -> NN
# contraparallel -> NN
# venus -> NN
# neptune -> JJ
# fantasy -> JJ
# illusion -> NN
# spirituality -> NN
# imagination -> NN
# neptune -> NN
# called -> VBN
# lord -> NN
# invisible -> JJ
# empire -> NN
# mysterious -> JJ
# name -> NN
# mysterious -> JJ
# planet -> NN
# perhaps -> RB
# could -> MD
# describe -> VB
# dimension -> NN
# life -> NN
# experienced -> VBD
# five -> CD
# senses -> NNS
# understand -> VBP
# perceive -> JJ
# imagination -> NN
# neptune -> FW
# capricorn -> JJ
# note -> NN
# neptune -> RB
# slow -> JJ
# transpersonal -> JJ
# planet -> NN
# may -> MD
# remain -> VB
# single -> JJ
# sign -> NN
# many -> JJ
# years -> NNS
# description -> VBP
# neptune -> RB
# capricorn -> VBN
# therefore -> RB
# valid -> JJ
# entire -> JJ
# generation -> NN
# people -> NNS
# general -> JJ
# characteristic -> JJ
# personality -> NN
# description -> NN
# neptune -> IN
# th -> JJ
# house -> NN
# neptune -> JJ
# capricorn -> JJ
# gives -> VBZ
# people -> NNS
# determination -> NN
# ability -> NN
# concentrate -> VBP
# however -> RB
# ruin -> JJ
# typical -> JJ
# capricorn -> NN
# rationality -> NN
# position -> NN
# somewhat -> IN
# shatters -> NNS
# natural -> JJ
# desire -> NN
# perfection -> NN
# gives -> VBZ
# people -> NNS
# desire -> VBP
# achieve -> VBP
# spiritual -> JJ
# goals -> NNS
# neptune -> JJ
# th -> JJ
# house -> NN
# neptune -> JJ
# twelfth -> JJ
# house -> NN
# affects -> VBZ
# unconscious -> JJ
# mind -> NN
# sometimes -> RB
# causes -> VBZ
# fears -> JJ
# difficulties -> NNS
# problems -> NNS
# spring -> VBG
# past -> JJ
# people -> NNS
# tendency -> NN
# focus -> NN
# wrong -> JJ
# side -> JJ
# life -> NN
# often -> RB
# display -> VBZ
# great -> JJ
# empathy -> JJ
# towards -> NNS
# physically -> RB
# mentally -> RB
# handicapped -> JJ
# people -> NNS
# neptune -> VBP
# twelfth -> JJ
# house -> NN
# suggests -> VBZ
# people -> NNS
# focus -> VBP
# soul -> JJ
# avoid -> NN
# everyday -> JJ
# affairs -> NNS
# neptune -> JJ
# aspects -> NNS
# sextile -> JJ
# mars -> NNS
# separating -> VBG
# sextile -> JJ
# pluto -> NN
# separating -> VBG
# contraparallel -> JJ
# sun -> NN
# contraparallel -> NN
# venus -> NN
# parallel -> JJ
# saturn -> NN
# pluto -> JJ
# transformation -> NN
# regeneration -> NN
# power -> NN
# pluto -> NN
# planet -> NN
# death -> NN
# rebirth -> JJ
# end -> NN
# things -> NNS
# judgment -> JJ
# day -> NN
# give -> VB
# rise -> NN
# obsessions -> NNS
# convictions -> NNS
# dark -> JJ
# end -> VBP
# spectrum -> JJ
# manifest -> JJS
# succumbing -> VBG
# urge -> JJ
# create -> JJ
# individual -> JJ
# ability -> NN
# get -> VBP
# core -> JJ
# things -> NNS
# destroy -> VBP
# negative -> JJ
# things -> NNS
# bring -> VBP
# healing -> VBG
# transformation -> NN
# pluto -> NN
# scorpio -> JJ
# note -> NN
# pluto -> NN
# slow -> JJ
# transpersonal -> JJ
# planet -> NN
# may -> MD
# remain -> VB
# single -> JJ
# sign -> NN
# many -> JJ
# years -> NNS
# description -> VBP
# pluto -> NN
# scorpio -> NN
# therefore -> RB
# valid -> JJ
# entire -> JJ
# generation -> NN
# people -> NNS
# general -> JJ
# characteristic -> JJ
# personality -> NN
# description -> NN
# pluto -> NN
# th -> NN
# house -> NN
# people -> NNS
# pluto -> VBP
# scorpio -> JJ
# passionate -> NN
# desire -> NN
# mystery -> NN
# like -> IN
# use -> NN
# intrigues -> NNS
# great -> JJ
# disposition -> JJ
# personal -> JJ
# transformation -> NN
# happen -> VB
# especially -> RB
# desires -> VBZ
# prolific -> JJ
# universal -> NN
# capable -> JJ
# radiate -> NN
# occult -> NN
# powers -> NNS
# sexuality -> NN
# also -> RB
# transforming -> VBG
# time -> NN
# feel -> NN
# restricted -> VBD
# pluto -> JJ
# th -> NN
# house -> NN
# pluto -> VBD
# tenth -> JJ
# house -> NN
# suggests -> VBZ
# person -> NN
# strong -> JJ
# need -> NN
# achieve -> VBP
# success -> NN
# career -> NN
# pluto -> NN
# house -> NN
# suggests -> VBZ
# career -> VBP
# scientific -> JJ
# field -> NN
# healing -> VBG
# medicine -> JJ
# profession -> NN
# one -> CD
# deal -> NN
# powerful -> JJ
# individuals -> NNS
# example -> NN
# politics -> NNS
# planet -> NN
# cause -> NN
# changes -> NNS
# interruptions -> NNS
# business -> NN
# occupational -> JJ
# matters -> NNS
# pluto -> VBP
# aspects -> NNS
# trine -> JJ
# mars -> NNS
# separating -> VBG
# sextile -> JJ
# neptune -> JJ
# separating -> VBG
# objects -> NNS
# lunar -> JJ
# nodes -> NNS
# north -> JJ
# node -> JJ
# south -> NN
# node -> JJ
# lunar -> NN
# nodes -> NNS
# arent -> JJ
# planets -> NNS
# rather -> RB
# astrology -> RB
# mathematical -> JJ
# points -> NNS
# directly -> RB
# opposite -> JJ
# chart -> NN
# said -> VBD
# life -> NN
# purpose -> NN
# encoded -> VBD
# line -> NN
# north -> JJ
# node -> JJ
# south -> NN
# node -> JJ
# south -> JJ
# node -> NN
# indicates -> VBZ
# comfort -> VBP
# zone -> CD
# habitual -> JJ
# place -> NN
# north -> JJ
# node -> NN
# shows -> VBZ
# life -> NN
# lessons -> NNS
# youre -> VBP
# striving -> VBG
# lifetime -> NN
# lunar -> NN
# nodes -> VBZ
# almost -> RB
# always -> RB
# retrogade -> VB
# north -> JJ
# node -> JJ
# mean -> NN
# pisces -> NNS
# south -> RB
# node -> JJ
# virgo -> NNS
# north -> JJ
# node -> JJ
# pisces -> NNS
# brings -> VBZ
# conflict -> JJ
# transcendental -> JJ
# effort -> NN
# everyday -> JJ
# reality -> NN
# chaos -> NN
# order -> NN
# spirituality -> NN
# reason -> NN
# people -> NNS
# need -> VBP
# open -> JJ
# spirituality -> NN
# imagination -> NN
# need -> VBP
# escape -> NN
# constraints -> NNS
# usual -> JJ
# explainable -> JJ
# open -> JJ
# unusual -> JJ
# unexplainable -> JJ
# need -> NN
# go -> VBP
# beyond -> IN
# rational -> JJ
# analytical -> JJ
# develop -> NN
# imaginative -> JJ
# powers -> NNS
# spiritual -> JJ
# awareness -> RB
# stop -> JJ
# working -> VBG
# hard -> JJ
# find -> NN
# time -> NN
# learn -> JJ
# make -> VB
# selfsacrifice -> NN
# show -> NN
# love -> IN
# people -> NNS
# beware -> VBP
# morbid -> JJ
# obsession -> NN
# order -> NN
# cleanliness -> NN
# rejection -> NN
# everything -> NN
# perfect -> JJ
# order -> NN
# explained -> VBD
# north -> JJ
# node -> JJ
# mean -> NN
# rd -> NN
# house -> NN
# south -> JJ
# node -> JJ
# th -> NN
# house -> NN
# north -> JJ
# node -> JJ
# third -> JJ
# house -> NN
# brings -> VBZ
# conflict -> NN
# seeking -> VBG
# objectivity -> NN
# lively -> RB
# communication -> NN
# one -> CD
# hand -> NN
# clinging -> VBG
# highly -> RB
# subjective -> JJ
# understanding -> VBG
# firmly -> RB
# anchored -> VBN
# opinions -> NNS
# commands -> VBZ
# people -> NNS
# need -> VBP
# learn -> JJ
# express -> NN
# complex -> JJ
# contexts -> NN
# ideas -> NNS
# everyday -> JJ
# language -> NN
# convey -> VBD
# spiritual -> JJ
# thinking -> NN
# practical -> JJ
# life -> NN
# transfer -> NN
# comprehensible -> JJ
# form -> NN
# show -> VBP
# clearly -> RB
# connection -> NN
# philosophical -> JJ
# noble -> JJ
# knowledge -> NN
# values -> NNS
# everyday -> JJ
# life -> NN
# beware -> NN
# prejudices -> NNS
# stubborn -> VBP
# beliefs -> JJ
# node -> JJ
# mean -> NN
# aspects -> NNS
# square -> VBP
# sun -> JJ
# separating -> VBG
# square -> JJ
# mercury -> NN
# applying -> VBG
# square -> JJ
# venus -> NN
# applying -> VBG
# sextile -> JJ
# jupiter -> NN
# separating -> VBG
# lilith -> JJ
# black -> JJ
# moon -> NN
# fascination -> NN
# denial -> NN
# lilith -> VBD
# fictional -> JJ
# point -> NN
# second -> JJ
# empty -> JJ
# focal -> JJ
# point -> NN
# elliptical -> JJ
# orbit -> NN
# moon -> NN
# around -> IN
# earth -> JJ
# mythology -> NN
# lilith -> NN
# refused -> VBD
# submit -> NN
# adam -> NN
# rebelled -> VBD
# connection -> NN
# adam -> IN
# eve -> NN
# decided -> VBD
# escape -> JJ
# world -> NN
# people -> NNS
# made -> VBN
# connection -> NN
# satan -> JJ
# astrology -> NN
# lilith -> NN
# symbolizes -> VBZ
# either -> DT
# fascination -> NN
# refusal -> NN
# topics -> NNS
# connected -> VBN
# fascination -> NN
# rejection -> NN
# given -> VBN
# topics -> NNS
# eventually -> RB
# engulf -> VBP
# person -> NN
# take -> VB
# away -> RP
# human -> JJ
# world -> NN
# lilith -> NN
# mean -> JJ
# virgo -> NN
# rebellion -> NN
# order -> NN
# provocative -> JJ
# humour -> NN
# sensuality -> NN
# strongly -> RB
# suppressed -> VBD
# trying -> VBG
# appear -> JJ
# calm -> JJ
# emotional -> JJ
# conflicts -> NNS
# often -> RB
# occur -> VBP
# difficult -> JJ
# people -> NNS
# feel -> VBP
# relaxed -> JJ
# want -> VBP
# suppress -> JJ
# instincts -> NNS
# appear -> VBP
# cold -> JJ
# perverted -> VBN
# beware -> NN
# alcoholism -> NN
# surgery -> NN
# intestines -> NNS
# lilith -> VBP
# mean -> JJ
# th -> NN
# house -> NN
# tendency -> NN
# ask -> JJ
# questions -> NNS
# death -> NN
# obsession -> NN
# death -> NN
# chiron -> NN
# wounded -> VBD
# healer -> NN
# inner -> NN
# teacher -> NN
# chiron -> NN
# asteroid -> JJ
# saturn -> NN
# uranus -> JJ
# orbit -> NN
# unusual -> JJ
# represents -> VBZ
# bridge -> NN
# material -> NN
# spiritual -> JJ
# worlds -> NNS
# according -> VBG
# mythology -> NN
# chiron -> NN
# great -> JJ
# healer -> NN
# wise -> NN
# teacher -> CC
# one -> CD
# immortal -> NN
# centaurs -> NN
# unfortunately -> RB
# deadly -> RB
# injured -> JJ
# poisonous -> JJ
# arrow -> NN
# heracles -> NNS
# favourite -> RB
# disciple -> JJ
# suffering -> VBG
# great -> JJ
# pain -> NN
# could -> MD
# die -> VB
# finally -> RB
# gave -> VBD
# immortality -> NN
# benefit -> NN
# prometheus -> NN
# also -> RB
# suffering -> VBG
# chiron -> NN
# sent -> VBD
# underworld -> JJ
# underworld -> NN
# zeus -> NN
# mercy -> NN
# raised -> VBD
# heaven -> JJ
# astrology -> NN
# chiron -> NN
# symbolizes -> VBZ
# unhealable -> JJ
# injuries -> NNS
# incurable -> JJ
# trauma -> NNS
# however -> RB
# person -> NN
# instead -> RB
# drowning -> VBG
# trauma -> NN
# able -> JJ
# accept -> NN
# trauma -> NN
# help -> NN
# others -> NNS
# also -> RB
# suffering -> VBG
# accept -> IN
# suffering -> VBG
# part -> NN
# life -> NN
# chiron -> NN
# may -> MD
# key -> VB
# wisdom -> VB
# even -> RB
# sort -> JJ
# initiation -> NN
# gate -> NN
# chiron -> NN
# gemini -> NN
# without -> IN
# success -> NN
# people -> NNS
# keep -> VB
# trying -> VBG
# explain -> RB
# wanted -> VBD
# say -> NN
# said -> VBD
# meant -> JJ
# either -> CC
# believe -> VB
# nobody -> NN
# listens -> VBZ
# matter -> RB
# hard -> JJ
# try -> NN
# others -> NNS
# understand -> VBP
# want -> JJ
# understand -> NN
# try -> NN
# correct -> VBP
# misunderstanding -> VBG
# sense -> NN
# misunderstanding -> VBG
# never -> RB
# overcome -> VBN
# hurts -> NNS
# chiron -> VBD
# th -> JJ
# house -> NN
# people -> NNS
# sick -> JJ
# life -> NN
# illnesses -> VBZ
# serious -> JJ
# chronic -> JJ
# seems -> VBZ
# cured -> VBN
# especially -> RB
# medical -> JJ
# professionals -> NNS
# traditional -> JJ
# healers -> NNS
# give -> VBP
# correct -> JJ
# diagnosis -> NN
# people -> NNS
# took -> VBD
# illness -> JJ
# others -> NNS
# choice -> NN
# learn -> VBP
# live -> JJ
# health -> NN
# problems -> NNS
# keep -> VBP
# searching -> VBG
# new -> JJ
# ways -> NNS
# cure -> NN
# least -> JJS
# alleviate -> NN
# symptoms -> NNS
# always -> RB
# fear -> VBP
# one -> CD
# illness -> NN
# cured -> VBD
# another -> DT
# serious -> JJ
# illness -> NN
# suddenly -> RB
# appear -> VBP
# main -> JJ
# aspects -> NNS
# sun -> VBP
# sextile -> JJ
# moon -> NN
# separating -> VBG
# emotions -> NNS
# feelings -> NNS
# moon -> RB
# harmony -> VBP
# ego -> JJ
# individuality -> NN
# sun -> NN
# contributes -> NNS
# balance -> IN
# relaxation -> NN
# inner -> JJ
# peace -> NN
# aspect -> NN
# also -> RB
# greatly -> RB
# increases -> VBZ
# chance -> NN
# find -> NN
# success -> NN
# satisfaction -> NN
# life -> NN
# relationships -> NNS
# opposite -> JJ
# sex -> NN
# mostly -> RB
# balanced -> VBD
# harmonious -> JJ
# sun -> NN
# conjunction -> NN
# mercury -> NN
# applying -> VBG
# conjunction -> NN
# sun -> JJ
# mercury -> NN
# people -> NNS
# aspect -> VBP
# subjective -> JJ
# creative -> JJ
# express -> NN
# ideas -> NNS
# well -> RB
# often -> RB
# artistic -> JJ
# great -> JJ
# aspect -> JJ
# artists -> NNS
# perform -> VBP
# stage -> NN
# people -> NNS
# intellectuals -> NNS
# thinking -> VBG
# subjective -> JJ
# sometimes -> RB
# lack -> VBP
# objectivity -> JJ
# ability -> NN
# see -> VBP
# things -> NNS
# outside -> IN
# sun -> JJ
# conjunction -> NN
# venus -> NN
# applying -> VBG
# conjunction -> NN
# sun -> NN
# venus -> NN
# aspect -> NN
# highlights -> NNS
# feminine -> VBP
# characteristics -> NNS
# sexes -> NNS
# also -> RB
# supports -> VBZ
# artistic -> JJ
# creative -> JJ
# inclinations -> NNS
# people -> NNS
# often -> RB
# optimistic -> JJ
# enjoy -> NNS
# company -> NN
# people -> NNS
# good -> JJ
# taste -> NN
# fashionable -> JJ
# clothes -> NNS
# sun -> VBP
# square -> JJ
# mars -> NNS
# separating -> VBG
# aspect -> JJ
# give -> JJ
# people -> NNS
# physical -> JJ
# strength -> NN
# ability -> NN
# work -> NN
# hard -> RB
# however -> RB
# tend -> VBP
# take -> VBP
# unnecessary -> JJ
# risks -> NNS
# may -> MD
# also -> RB
# impulsive -> VB
# easily -> RB
# excitable -> JJ
# selfish -> JJ
# moon -> NN
# sextile -> JJ
# mercury -> NN
# separating -> VBG
# harmonious -> JJ
# aspect -> JJ
# give -> JJ
# people -> NNS
# good -> JJ
# memory -> NN
# poetic -> JJ
# soul -> NN
# ability -> NN
# understand -> VBP
# others -> NNS
# helps -> VBP
# people -> NNS
# become -> VBP
# good -> JJ
# teachers -> NNS
# journalists -> NNS
# psychologists -> NNS
# people -> NNS
# interested -> JJ
# origin -> JJ
# roots -> NNS
# environmental -> JJ
# problems -> NNS
# often -> RB
# intelligent -> JJ
# moon -> NN
# sextile -> NN
# venus -> NN
# separating -> VBG
# harmonious -> JJ
# aspect -> JJ
# gives -> VBZ
# people -> NNS
# balanced -> VBD
# temperament -> JJ
# charming -> VBG
# manners -> NNS
# usually -> RB
# also -> RB
# good -> JJ
# looks -> NNS
# social -> JJ
# success -> NN
# almost -> RB
# guaranteed -> JJ
# people -> NNS
# creative -> JJ
# abilities -> NNS
# need -> VBP
# create -> VBP
# pleasant -> JJ
# home -> NN
# environment -> NN
# moon -> NN
# trine -> NN
# saturn -> NN
# applying -> VBG
# harmonious -> JJ
# aspect -> JJ
# gives -> VBZ
# people -> NNS
# emotional -> JJ
# stability -> NN
# home -> NN
# environment -> NN
# often -> RB
# things -> NNS
# way -> NN
# think -> VBP
# right -> JJ
# reliable -> JJ
# stable -> JJ
# helpful -> JJ
# however -> RB
# sometimes -> RB
# may -> MD
# pedant -> VB
# moon -> NN
# trine -> NN
# uranus -> IN
# applying -> VBG
# harmonious -> JJ
# aspect -> JJ
# brings -> NNS
# people -> NNS
# need -> VBP
# considerable -> JJ
# emotional -> JJ
# independence -> NN
# freedom -> NN
# family -> NN
# environment -> NN
# people -> NNS
# often -> RB
# lead -> VBP
# unconventional -> JJ
# life -> NN
# like -> IN
# yield -> NN
# others -> NNS
# feel -> VBP
# separated -> JJ
# society -> NN
# complex -> JJ
# separation -> NN
# often -> RB
# experience -> JJ
# stormy -> JJ
# emotions -> NNS
# mood -> NN
# swings -> NNS
# mercury -> NN
# conjunction -> NN
# venus -> IN
# separating -> VBG
# conjunction -> NN
# gives -> VBZ
# people -> NNS
# good -> JJ
# manners -> NNS
# mental -> JJ
# balance -> NN
# express -> NN
# well -> RB
# convincing -> VBG
# views -> NNS
# also -> RB
# wellbalanced -> VBD
# thinking -> VBG
# often -> RB
# rational -> JJ
# able -> JJ
# express -> NN
# feelings -> NNS
# openly -> RB
# mercury -> VBP
# opposition -> NN
# saturn -> NN
# separating -> VBG
# aspect -> JJ
# gives -> VBZ
# people -> NNS
# serious -> JJ
# conservative -> JJ
# practical -> JJ
# mental -> NN
# processes -> VBZ
# however -> RB
# people -> NNS
# also -> RB
# ability -> NN
# calculate -> VBP
# clearly -> RB
# calmly -> JJ
# ability -> NN
# often -> RB
# responsible -> JJ
# success -> NN
# mercury -> NN
# opposition -> NN
# uranus -> IN
# separating -> VBG
# aspect -> JJ
# often -> RB
# brings -> VBZ
# extreme -> JJ
# views -> NNS
# strong -> JJ
# need -> JJ
# independence -> NN
# people -> NNS
# force -> VBP
# opinions -> NNS
# often -> RB
# extreme -> VBP
# unrealistic -> JJ
# others -> NNS
# arrogance -> VBP
# reluctance -> NN
# compromise -> NN
# opinions -> NNS
# often -> RB
# way -> NN
# ahead -> RB
# people -> NNS
# inclined -> JJ
# get -> VBP
# involved -> VBN
# movements -> NNS
# views -> NNS
# may -> MD
# even -> RB
# accepted -> VB
# future -> NN
# curious -> JJ
# intelligent -> NN
# novel -> JJ
# way -> NN
# thinking -> VBG
# like -> IN
# argue -> JJ
# opinions -> NNS
# creative -> JJ
# activity -> NN
# often -> RB
# destructive -> JJ
# tends -> NNS
# rebellious -> JJ
# chaotic -> JJ
# venus -> NN
# opposition -> NN
# saturn -> NN
# separating -> VBG
# people -> NNS
# aspect -> VBP
# responsible -> JJ
# reserved -> VBN
# hesitant -> NN
# also -> RB
# restraints -> VBZ
# often -> RB
# result -> JJ
# poor -> JJ
# parenting -> VBG
# fear -> NN
# authorities -> NNS
# also -> RB
# causes -> VBZ
# fear -> JJ
# loss -> NN
# afraid -> NN
# lose -> JJ
# property -> NN
# loved -> VBD
# ones -> NNS
# people -> NNS
# often -> RB
# submit -> VBP
# feelings -> NNS
# practicality -> NN
# typical -> JJ
# manifestation -> NN
# getting -> VBG
# married -> JJ
# security -> NN
# subconsciously -> RB
# fear -> JJ
# unemployment -> NN
# poverty -> NN
# venus -> NN
# opposition -> NN
# uranus -> IN
# separating -> VBG
# aspect -> JJ
# complicates -> NNS
# relationship -> NN
# people -> NNS
# see -> VBP
# relationships -> NNS
# literally -> RB
# loss -> NN
# personal -> JJ
# freedom -> NN
# integrity -> NN
# mentally -> RB
# unstable -> JJ
# feelings -> NNS
# constantly -> RB
# change -> VBP
# often -> RB
# get -> VBP
# involved -> VBN
# great -> JJ
# number -> NN
# relationships -> NNS
# throughout -> IN
# life -> NN
# unconventional -> JJ
# difficult -> JJ
# get -> NN
# along -> IN
# eccentric -> JJ
# original -> JJ
# create -> NN
# art -> NN
# unstable -> JJ
# ways -> NNS
# dealing -> VBG
# money -> NN
# adventurous -> JJ
# lead -> NN
# unstable -> JJ
# love -> JJ
# life -> NN
# mars -> NNS
# sextile -> JJ
# neptune -> JJ
# separating -> VBG
# harmonious -> JJ
# aspect -> JJ
# manifests -> NNS
# giving -> VBG
# people -> NNS
# great -> JJ
# fantasy -> JJ
# creativity -> NN
# idealism -> NN
# artistic -> JJ
# talent -> NN
# however -> RB
# people -> NNS
# aspect -> VBP
# impractical -> JJ
# typical -> JJ
# image -> NN
# people -> NNS
# aspect -> VBP
# artist -> JJ
# knows -> NNS
# entire -> JJ
# world -> NN
# culture -> NN
# useless -> JJ
# private -> JJ
# life -> NN
# mars -> NNS
# trine -> JJ
# pluto -> NN
# separating -> VBG
# aspect -> JJ
# increases -> NNS
# mars -> VBZ
# power -> NN
# people -> NNS
# hardworking -> VBG
# thorough -> JJ
# activities -> NNS
# however -> RB
# also -> RB
# stubborn -> JJ
# goal -> NN
# easily -> RB
# discouraged -> VBD
# trying -> VBG
# achieve -> RB
# harmonious -> JJ
# aspect -> JJ
# typical -> JJ
# army -> NN
# commanders -> NNS
# gives -> VBZ
# great -> JJ
# talent -> NN
# strategy -> NN
# peoples -> NNS
# aim -> VBP
# control -> NN
# others -> NNS
# aspect -> VBP
# gives -> VBZ
# people -> NNS
# ability -> NN
# achieve -> VBP
# objectives -> NNS
# despite -> IN
# possible -> JJ
# obstacles -> NNS
# saturn -> VBP
# conjunction -> NN
# uranus -> IN
# applying -> VBG
# conjunction -> NN
# gives -> VBZ
# people -> NNS
# determination -> NN
# originality -> NN
# ability -> NN
# work -> NN
# hard -> JJ
# ability -> NN
# find -> VBP
# new -> JJ
# solutions -> NNS
# problems -> NNS
# people -> NNS
# democratic -> JJ
# ideals -> NNS
# often -> RB
# authoritative -> JJ
# neptune -> NNS
# sextile -> JJ
# pluto -> NN
# separating -> VBG
# harmonious -> JJ
# aspect -> NN
# longlasting -> VBG
# affects -> NNS
# peacemaking -> VBG
# attitudes -> NNS
# connection -> NN
# aspects -> NNS
# enhances -> VBZ
# peacebuilding -> VBG
# transformative -> JJ
# actions -> NNS
# global -> JJ
# scale -> NN
# aspects -> NNS
# ascendant -> JJ
# square -> JJ
# moon -> NN
# separating -> VBG
# aspect -> JJ
# bring -> NN
# people -> NNS
# instability -> NN
# may -> MD
# easily -> RB
# get -> VB
# influenced -> JJ
# others -> NNS
# ascendant -> VBP
# trine -> JJ
# jupiter -> NN
# separating -> VBG
# positive -> JJ
# thing -> NN
# aspect -> JJ
# people -> NNS
# generous -> JJ
# kind -> NN
# usually -> RB
# excellent -> JJ
# health -> NN
# mc -> NN
# trine -> NN
# sun -> NN
# applying -> VBG
# aspect -> JJ
# indicates -> NNS
# ability -> NN
# succeed -> VB
# using -> VBG
# means -> NNS
# help -> VBP
# others -> NNS
# mc -> VB
# opposition -> NN
# moon -> NN
# applying -> VBG
# aspect -> JJ
# bring -> NN
# instability -> NN
# professional -> JJ
# life -> NN
# people -> NNS
# often -> RB
# unstable -> JJ
# professions -> NNS
# node -> CC
# square -> JJ
# sun -> NN
# separating -> VBG
# frequent -> JJ
# conflicts -> NNS
# tension -> NN
# among -> IN
# demands -> NNS
# sun -> JJ
# tasks -> NNS
# lunar -> VBP
# node -> RB
# waiting -> VBG
# realised -> VBN
# reason -> NN
# life -> NN
# path -> NN
# people -> NNS
# clear -> VBP
# indecisive -> JJ
# chaotic -> JJ
# restraints -> NNS
# node -> JJ
# square -> JJ
# mercury -> NN
# applying -> VBG
# positive -> JJ
# thing -> NN
# aspect -> JJ
# gives -> VBZ
# people -> NNS
# intelligence -> NN
# good -> JJ
# life -> NN
# orientation -> NN
# enjoy -> IN
# searching -> VBG
# background -> NN
# motives -> NNS
# able -> JJ
# critically -> RB
# creatively -> RB
# deal -> JJ
# personality -> NN
# open -> JJ
# towards -> NNS
# others -> NNS
# accept -> VBP
# criticism -> NN
# easily -> RB
# avoid -> VBZ
# conflicts -> NNS
# manage -> JJ
# life -> NN
# challenges -> NNS
# help -> VBP
# analytical -> JJ
# logical -> JJ
# thinking -> VBG
# negative -> JJ
# side -> NN
# aspect -> JJ
# people -> NNS
# may -> MD
# poor -> JJ
# focus -> VB
# life -> NN
# path -> NN
# intellect -> NN
# always -> RB
# finds -> VBZ
# good -> JJ
# reasons -> NNS
# stop -> VBP
# focusing -> VBG
# set -> NN
# goal -> NN
# reason -> NN
# people -> NNS
# often -> RB
# stubborn -> JJ
# defensive -> JJ
# attitudes -> NNS
# cling -> VBG
# things -> NNS
# put -> VBN
# disadvantage -> NN
# node -> NN
# square -> JJ
# venus -> NN
# applying -> VBG
# positive -> JJ
# thing -> NN
# aspect -> JJ
# people -> NNS
# often -> RB
# pleasant -> JJ
# graceful -> JJ
# sexy -> NN
# affectionate -> NN
# appreciate -> JJ
# beauty -> NN
# like -> IN
# art -> NN
# good -> JJ
# taste -> NN
# harmonious -> JJ
# connection -> NN
# forms -> NNS
# focal -> JJ
# point -> NN
# life -> NN
# helps -> VBZ
# achieve -> VBP
# goals -> NNS
# somewhat -> RB
# feminine -> VBP
# radiating -> VBG
# power -> NN
# valuable -> JJ
# deserves -> NNS
# acknowledged -> VBD
# developed -> JJ
# negative -> JJ
# side -> NN
# aspect -> NN
# difficult -> JJ
# people -> NNS
# find -> VBP
# inner -> JJ
# peace -> NN
# love -> VB
# life -> NN
# constant -> JJ
# conflict -> NN
# direction -> NN
# life -> NN
# experience -> NN
# feelings -> NNS
# unfulfillment -> NN
# may -> MD
# great -> JJ
# need -> VB
# affection -> JJ
# hard -> JJ
# satisfy -> NN
# node -> NN
# sextile -> NN
# jupiter -> NN
# separating -> VBG
# positive -> JJ
# thing -> NN
# aspect -> JJ
# people -> NNS
# confident -> JJ
# abilities -> NNS
# helps -> VBZ
# overcome -> VB
# challenges -> NNS
# life -> NN
# life -> NN
# challenges -> NNS
# often -> RB
# connected -> VBN
# profound -> JJ
# sensory -> JJ
# experience -> NN
# gives -> VBZ
# people -> NNS
# luck -> JJ
# life -> NN
# journey -> NN
# declination -> NN
# aspects -> NNS
# parallels -> VBP
# contraparallels -> NNS
# parallels -> NNS
# contraparallels -> NNS
# aspects -> NNS
# refer -> VBP
# degrees -> NNS
# declination -> VBP
# celestial -> JJ
# equator -> NN
# parallel -> VBD
# similar -> JJ
# conjunction -> NN
# usually -> RB
# provides -> VBZ
# benefits -> NNS
# contraparallel -> NN
# said -> VBD
# similar -> JJ
# opposition -> NN
# weaker -> NN
# note -> NN
# following -> VBG
# parallel -> JJ
# contraparallel -> JJ
# interpretations -> NNS
# interpretations -> NNS
# used -> VBN
# conjunction -> NN
# opposition -> NN
# sun -> NN
# parallel -> JJ
# venus -> NN
# conjunction -> NN
# sun -> NN
# venus -> NN
# aspect -> NN
# highlights -> NNS
# feminine -> VBP
# characteristics -> NNS
# sexes -> NNS
# also -> RB
# supports -> VBZ
# artistic -> JJ
# creative -> JJ
# inclinations -> NNS
# people -> NNS
# often -> RB
# optimistic -> JJ
# enjoy -> NNS
# company -> NN
# people -> NNS
# good -> JJ
# taste -> NN
# fashionable -> JJ
# clothes -> NNS
# sun -> VBP
# contraparallel -> JJ
# saturn -> NN
# aspect -> JJ
# creates -> VBZ
# two -> CD
# groups -> NNS
# people -> NNS
# people -> NNS
# first -> JJ
# group -> NN
# tend -> VBP
# give -> VBP
# encounter -> NN
# problems -> NNS
# people -> NNS
# second -> JJ
# group -> NN
# encounter -> NN
# problems -> NNS
# get -> VBP
# stimulated -> VBN
# perform -> NN
# better -> RBR
# people -> NNS
# often -> RB
# lower -> JJR
# selfesteem -> NN
# improved -> VBD
# good -> JJ
# work -> NN
# sun -> NN
# contraparallel -> JJ
# uranus -> NN
# aspect -> NN
# creates -> VBZ
# people -> NNS
# individualistic -> JJ
# selfish -> JJ
# eccentric -> JJ
# independent -> JJ
# guard -> NN
# independence -> NN
# carefully -> RB
# always -> RB
# considerate -> VB
# towards -> NNS
# people -> NNS
# sometimes -> RB
# suffer -> VBP
# mental -> JJ
# exhaustion -> NN
# people -> NNS
# need -> VBP
# different -> JJ
# want -> VBP
# show -> NN
# uniqueness -> JJ
# want -> JJ
# teachers -> NNS
# mentors -> NNS
# examples -> VBZ
# others -> NNS
# people -> NNS
# willing -> JJ
# go -> VBP
# extremes -> RB
# order -> NN
# show -> NN
# originality -> NN
# trouble -> NN
# accepting -> VBG
# authorities -> NNS
# use -> VBP
# rebellion -> NN
# means -> NNS
# attracting -> VBG
# attention -> NN
# people -> NNS
# sun -> VBP
# contraparallel -> JJ
# neptune -> NN
# aspect -> JJ
# creates -> VBZ
# people -> NNS
# overly -> RB
# empathetic -> JJ
# willing -> JJ
# sacrifice -> NN
# thus -> RB
# may -> MD
# easily -> RB
# used -> VBN
# others -> NNS
# cheated -> VBD
# people -> NNS
# stay -> VB
# away -> RB
# drugs -> NNS
# alcohol -> VBP
# tobacco -> NN
# considerable -> JJ
# tendencies -> NNS
# use -> VBP
# drugs -> NNS
# alcohol -> VBP
# solve -> VB
# problems -> NNS
# venus -> FW
# contraparallel -> JJ
# saturn -> NN
# people -> NNS
# aspect -> VBP
# responsible -> JJ
# reserved -> VBN
# hesitant -> NN
# also -> RB
# restraints -> VBZ
# often -> RB
# result -> JJ
# poor -> JJ
# parenting -> VBG
# fear -> NN
# authorities -> NNS
# also -> RB
# causes -> VBZ
# fear -> JJ
# loss -> NN
# afraid -> NN
# lose -> JJ
# property -> NN
# loved -> VBD
# ones -> NNS
# people -> NNS
# often -> RB
# submit -> VBP
# feelings -> NNS
# practicality -> NN
# typical -> JJ
# manifestation -> NN
# getting -> VBG
# married -> JJ
# security -> NN
# subconsciously -> RB
# fear -> JJ
# unemployment -> NN
# poverty -> NN
# venus -> NN
# contraparallel -> NN
# uranus -> JJ
# aspect -> NN
# complicates -> VBZ
# relationship -> NN
# people -> NNS
# see -> VBP
# relationships -> NNS
# literally -> RB
# loss -> NN
# personal -> JJ
# freedom -> NN
# integrity -> NN
# mentally -> RB
# unstable -> JJ
# feelings -> NNS
# constantly -> RB
# change -> VBP
# often -> RB
# get -> VBP
# involved -> VBN
# great -> JJ
# number -> NN
# relationships -> NNS
# throughout -> IN
# life -> NN
# unconventional -> JJ
# difficult -> JJ
# get -> NN
# along -> IN
# eccentric -> JJ
# original -> JJ
# create -> NN
# art -> NN
# unstable -> JJ
# ways -> NNS
# dealing -> VBG
# money -> NN
# adventurous -> JJ
# lead -> NN
# unstable -> JJ
# love -> JJ
# life -> NN
# venus -> NN
# contraparallel -> NN
# neptune -> JJ
# aspect -> NN
# causes -> VBZ
# considerable -> JJ
# romantic -> JJ
# feelings -> NNS
# complicate -> VBP
# life -> NN
# put -> VBD
# people -> NNS
# intricate -> JJ
# situations -> NNS
# often -> RB
# give -> VBP
# priority -> NN
# fantasies -> NNS
# reality -> NN
# esoteric -> JJ
# activities -> NNS
# sometimes -> RB
# become -> VBP
# important -> JJ
# reality -> NN
# take -> VB
# away -> RP
# considerable -> JJ
# amounts -> NNS
# energy -> NN
# relationship -> NN
# people -> NNS
# try -> VBP
# rational -> JJ
# thick -> JJ
# skin -> NN
# usually -> RB
# lazy -> JJ
# artists -> NNS
# aspect -> VBP
# brings -> VBZ
# inspiration -> NN
# creativity -> NN
# imagination -> NN
# good -> JJ
# taste -> NN
# saturn -> NN
# parallel -> JJ
# neptune -> RB
# necessary -> JJ
# distinguish -> JJ
# two -> CD
# planets -> NNS
# dominant -> JJ
# conjunction -> NN
# saturn -> NN
# dominant -> JJ
# person -> NN
# able -> JJ
# keep -> JJ
# imagination -> NN
# control -> NN
# use -> NN
# constructively -> RB
# fulfill -> JJ
# dreams -> NNS
# however -> RB
# neptune -> RB
# dominant -> JJ
# fantasy -> JJ
# vivid -> NN
# people -> NNS
# fail -> VBP
# fulfill -> JJ
# fantasies -> NNS
# become -> VBP
# frustrated -> JJ
# start -> NN
# living -> VBG
# fantasy -> JJ
# world -> NN
# become -> VBN
# practically -> RB
# useless -> JJ
# people -> NNS
# experience -> RB
# great -> JJ
# spiritual -> JJ
# passion -> NN
# may -> MD
# expand -> VB
# consciousness -> NN
# costs -> NNS
# use -> VBP
# possible -> JJ
# means -> NNS
# achieve -> VBP
# goal -> NN
# spiritual -> JJ
# fanatics -> NNS
# ascendant -> JJ
# contraparallel -> JJ
# mercury -> NN
# positive -> JJ
# thing -> NN
# aspect -> JJ
# gives -> VBZ
# people -> NNS
# vitality -> NN
# curiosity -> NN
# negative -> JJ
# side -> NN
# aspect -> NN
# may -> MD
# cause -> VB
# distractibility -> NN
# restlessness -> NN

# %% [markdown]
# ## Análisis de sentimiento

# %%
# Crear un objeto TextBlob para el análisis
blob = TextBlob(extracted_text)

sentimiento = blob.sentiment

print(f"Polaridad: {sentimiento.polarity}")
print(f"Sujeción: {sentimiento.subjectivity}")
# Out:
# Polaridad: 0.13688797464068223
# Sujeción: 0.5303579698480421

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize import sent_tokenize

extracted_text_list = sent_tokenize(extracted_text)

sid = SentimentIntensityAnalyzer()
for sentence in extracted_text_list:
  print(sentence)
  ss = sid.polarity_scores(sentence)
  for k in sorted(ss):
    print('{0}: {1}, '.format(k, ss[k]), end='')
# Out:
# 1st house - Ascendant (ASC)
# Physical personality
# Ascendant (ASC) - Symbolizes basic personality traits such as physical appearance, temperament, behaviour, relationship to life and the first impression the person gives.
# compound: 0.2263, neg: 0.0, neu: 0.934, pos: 0.066, Ascendant in Capricorn (Capricorn ruler is Saturn)
# People with Capricorn Ascendant must first become aware of their two opposing sides.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, One is obedience and performing their duties properly.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, They need to manage energy well and this requires discipline and self-control.
# compound: 0.4939, neg: 0.0, neu: 0.704, pos: 0.296, They must achieve some social prestige and recognition.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, The other side is the ability to organize practical matters and achieve their goals, and also the ability to enjoy sensual pleasures.
# compound: 0.8689, neg: 0.0, neu: 0.59, pos: 0.41, ... more -»
#
# The ruler of the Ascendant - Saturn
# These people tend to act slowly and with caution.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, They avoid any kind of control.
# compound: -0.296, neg: 0.306, neu: 0.694, pos: 0.0, They love solitude and they hate crowds.
# compound: 0.128, neg: 0.287, neu: 0.388, pos: 0.326, They want to stand out and isolate themselves from others.
# compound: -0.128, neg: 0.162, neu: 0.721, pos: 0.117, Their actions will be valued in time.
# compound: 0.4404, neg: 0.0, neu: 0.674, pos: 0.326, They may become politicians, consultants, engineers etc.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Their main feature is endurance.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, The ruler of the Ascendant (Saturn) in Capricorn
# These people raise slowly but steadily without others noticing.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Their actions are not glamorous, but they are creditable and constructive.
# compound: 0.4308, neg: 0.127, neu: 0.619, pos: 0.254, They push through in accordance with time.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, The ruler of the Ascendant (Saturn) in the 12th House
# These people are predestined to hide and run away from themselves, to subject themselves to illusions, and to closing themselves to others.
# compound: -0.1779, neg: 0.052, neu: 0.948, pos: 0.0, They have a rich inner life.
# compound: 0.5574, neg: 0.0, neu: 0.526, pos: 0.474, Social life may be the cause of some life test.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Self-punishment and self-destruction may occur.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Planets in the 1st House
# There is no planet.
# compound: -0.296, neg: 0.216, neu: 0.784, pos: 0.0, Ascendant aspects
# Square Moon (3°22’, Separating)
# Trine Jupiter (6°26’, Separating)
# Contra-Parallel Mercury (0°12’)
#
# 10th house - Medium Coeli (MC)
# Career, prestige and reputation
# Medium Coeli (MC) - Symbolizes social status, career, reputation, honours, fame, success, authoritative personality, father.
# compound: 0.8689, neg: 0.0, neu: 0.771, pos: 0.229, 10th house in Libra (Libra ruler is Venus)
# People with Libra on the tenth house cusp often have their own business or they work together with their partner.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, They may also work on a project together with other people.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, When these people do their job, they seem very professional.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, They are calm, prudent, kind, and tactful when they are working.
# compound: 0.6908, neg: 0.0, neu: 0.612, pos: 0.388, They are also cultured and organised so they can become supervisors or administrators.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, The best and most objective aspects of their personality are revealed when they communicate with the public.
# compound: 0.6369, neg: 0.0, neu: 0.792, pos: 0.208, The ruler of the 10th House (Venus) in the 5th House
# Career of these people is related to entertainment, games or theatre.
# compound: 0.4215, neg: 0.0, neu: 0.882, pos: 0.118, There is a possibility of creative activity in their profession.
# compound: 0.4404, neg: 0.0, neu: 0.734, pos: 0.266, These people love their job and they often have authority in this area.
# compound: 0.6705, neg: 0.0, neu: 0.667, pos: 0.333, Planets in the 10th House
# Pluto
#
# MC aspects
# Trine Sun (2°55’, Applying)
# Opposition Moon (8°14’, Applying)
#
# Interpretations - Planets in Signs, Planets in Houses
# Planets describe a certain process of what is happening - eg.
# compound: 0.2732, neg: 0.0, neu: 0.937, pos: 0.063, Mars fights, Saturn limits, Jupiter expands..
# Sign in which the planet is located determines how the planet is manifesting itself, for example Mars may manifest itself in a way Aries would behave (vigorously and irritably) or in the manner of Taurus (more slowly, gradually and consistently)
# Houses show special areas of everyday life, in which all this takes place.
# compound: 0.0, neg: 0.044, neu: 0.912, pos: 0.044, Location in a house shows whether, for example Mars manifests in relationships (7th house), employment (6th house), family (4th house) or elsewhere.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Hint:
# Planets show us what is happening;
# Signs show us how it is happening;
# Houses show us where it is happening.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Planets:
#
#  Sun - Self, individuality, personality
# The Sun symbolizes a personal identity.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, It shows us areas where the person should learn to be independent, where he should fulfill his potential, differentiate himself from others and shine.
# compound: 0.4404, neg: 0.0, neu: 0.888, pos: 0.112, The position of the Sun may tell us which profession would best suit the character of a person.
# compound: 0.6369, neg: 0.0, neu: 0.792, pos: 0.208, Sun in Gemini
# People born under the sign of Gemini are people of many talents and they are able to use their skills in both theory and practice.
# compound: 0.4588, neg: 0.0, neu: 0.9, pos: 0.1, They are very intelligent and quick-witted people who are interested in everything that happen around them, and they can quickly adapt to any new situation.
# compound: 0.7178, neg: 0.0, neu: 0.793, pos: 0.207, They are open to all novel things in the world, because they can quickly see their advantages.
# compound: 0.5859, neg: 0.0, neu: 0.758, pos: 0.242, They try to show these novel things to others so that they can also benefit from them.
# compound: 0.6486, neg: 0.0, neu: 0.739, pos: 0.261, But more conservative people often do not have an understanding for this.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, They are sociable people that have representative personalities and they can inspire and influence others with their innate charm and vigour.
# compound: 0.8807, neg: 0.0, neu: 0.603, pos: 0.397, more -»
#
# Sun in the 5th House
# The Sun in the fifth house creates very creative people with a very strong desire for self-expression.
# compound: 0.8971, neg: 0.0, neu: 0.616, pos: 0.384, It can be art, development or fertility.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, These people need others to notice and appreciate them.
# compound: 0.4019, neg: 0.0, neu: 0.748, pos: 0.252, They may have a tendency to brag or they at least try to look their best.
# compound: 0.6369, neg: 0.0, neu: 0.769, pos: 0.231, They are happy and merry people that have many friends.
# compound: 0.8834, neg: 0.0, neu: 0.405, pos: 0.595, They may be a bit childish and sometimes they try to be more mature and subtle in order not to be so theatrical or selfish.
# compound: -0.355, neg: 0.188, neu: 0.708, pos: 0.104, The Sun in the fifth house gives people considerable amount of self-confidence.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, These people often focus on their own children or on children in general.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, They tend to spoil children or they pass their dreams on to them.
# compound: 0.4019, neg: 0.0, neu: 0.816, pos: 0.184, Sun aspects
# Sextile Moon (5°18’, Separating)
# Conjunction Mercury (4°47’, Applying)
# Conjunction Venus (4°45’, Applying)
# Square Mars (7°41’, Separating)
# Trine MC (2°55’, Applying)
# Square Node (0°40’, Separating)
# Parallel Venus (0°10’)
# Contra-Parallel Saturn (0°43’)
# Contra-Parallel Uranus (0°38’)
# Contra-Parallel Neptune (0°53’)
#
#  Moon - Emotions, instincts, roots, mother
# Place in the horoscope where the Moon is tells us what gives the person a sense of security, and where to find it.
# compound: 0.34, neg: 0.0, neu: 0.964, pos: 0.036, It describes how sensitive we are and how we instinctively interact with our surroundings.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, The Moon also tells us about our childhood and our experiences with our mother.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Third Quarter Moon (Waning Moon)
# (305°18’ Moon Phase Degree)
# Reality check, Revision, Integration, Cleansing
#
# Moon in Aries
# The feeling of uncertainty can make you solve problems faster then is natural.
# compound: -0.0772, neg: 0.142, neu: 0.696, pos: 0.162, Do not rush as if there was a deadline.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Try to slow down so that you can decide what you want to do and proceed at your own comfortable pace.
# compound: 0.5574, neg: 0.0, neu: 0.805, pos: 0.195, more -»
#
# Moon in the 4th House
# The Moon in the fourth house means a strong connection with home - not only the house where people live, but also with home in a broader sense - with their country, traditions, nature etc.
# compound: 0.2846, neg: 0.0, neu: 0.945, pos: 0.055, These people usually have the need to feel a connection with the past and they are interested in things like antiques or their family tree.
# compound: 0.6369, neg: 0.0, neu: 0.809, pos: 0.191, They often remain under the strong influence of their parents.
# compound: 0.5106, neg: 0.0, neu: 0.732, pos: 0.268, The Moon in the fourth house indicates that they want to distance themselves from the reality and they have subjectivist inclinations.
# compound: 0.0772, neg: 0.0, neu: 0.939, pos: 0.061, These people may be insecure.
# compound: -0.4215, neg: 0.412, neu: 0.588, pos: 0.0, Their nature needs stable and reliable roots.
# compound: 0.296, neg: 0.0, neu: 0.732, pos: 0.268, Moon aspects
# Sextile Sun (5°18’, Separating)
# Sextile Mercury (0°31’, Separating)
# Sextile Venus (0°33’, Separating)
# Trine Saturn (5°22’, Applying)
# Trine Uranus (4°49’, Applying)
# Square Ascendant (3°22’, Separating)
# Opposition MC (8°14’, Applying)
#
#  Mercury - Thinking, communication, intellect, learning
# Mercury is the planet that brings us interest in intellectual things, about teaching and learning.
# compound: 0.8519, neg: 0.0, neu: 0.835, pos: 0.165, It also indicates into what depth we want to study things.
# compound: 0.0772, neg: 0.0, neu: 0.885, pos: 0.115, It gives us natural intelligence and the ability to analyse and reproduce.
# compound: 0.7845, neg: 0.0, neu: 0.533, pos: 0.467, Mercury in Gemini
# People with Mercury in Gemini have young minds and they are full of energy.
# compound: 0.2732, neg: 0.0, neu: 0.884, pos: 0.116, They want to discover new things, move from one argument to another, try different hobbies and work, and have discussions with interesting people.
# compound: 0.128, neg: 0.094, neu: 0.755, pos: 0.151, They will usually try many different jobs, and do all these jobs with enthusiasm and commitment.
# compound: 0.6705, neg: 0.0, neu: 0.718, pos: 0.282, These people are also talented public speakers.
# compound: 0.5106, neg: 0.0, neu: 0.645, pos: 0.355, It can be said that Mercury feels well in all air signs, but it can be a bit shallow in them - these people do not like to study things into the greatest detail.
# compound: 0.6893, neg: 0.068, neu: 0.743, pos: 0.188, Air, the ruling element that is definitely not a solid substance, is responsible for this, probably only one, shortcoming.
# compound: 0.5508, neg: 0.067, neu: 0.699, pos: 0.233, Mercury in the 5th House
# Mercury in the fifth house represents a connection with the house of creativity and children.
# compound: 0.3818, neg: 0.0, neu: 0.874, pos: 0.126, This position usually means artistic and creative talents and good ability to express thoughts orally.
# compound: 0.8779, neg: 0.0, neu: 0.498, pos: 0.502, These people have the ability to express themselves dramatically and powerfully and they are talented teachers and actors.
# compound: 0.6808, neg: 0.0, neu: 0.741, pos: 0.259, They are mentally competitive and require mental activity.
# compound: 0.1779, neg: 0.0, neu: 0.805, pos: 0.195, Mercury in the fifth house also indicates business activities and investments.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, It creates a character that may have a critical and analytical attitude towards personal relationships and life.
# compound: -0.0516, neg: 0.132, neu: 0.747, pos: 0.121, Mercury aspects
# Conjunction Sun (4°47’, Applying)
# Sextile Moon (0°31’, Separating)
# Conjunction Venus (0°01’, Separating)
# Opposition Saturn (5°54’, Separating)
# Opposition Uranus (5°21’, Separating)
# Square Node (5°27’, Applying)
# Contra-Parallel Ascendant (0°12’)
#
#  Venus - Sensuality, love, harmony, pleasure
# Venus symbolizes attractivity.
# compound: 0.891, neg: 0.0, neu: 0.762, pos: 0.238, Sign in which Venus is tells us what we are attracted to and this enables us to give or receive love and affection, beauty and happiness, values and principles.
# compound: 0.9661, neg: 0.0, neu: 0.529, pos: 0.471, The negative side is that it represents weakness and shallowness.
# compound: -0.7579, neg: 0.448, neu: 0.552, pos: 0.0, Venus in Gemini
# Gemini is a sign of youth, and these people have a strong urge to prevent stagnation and maintain flexibility in their relationships.
# compound: 0.7003, neg: 0.0, neu: 0.746, pos: 0.254, They believe that relationship without freedom is deemed to fail.
# compound: -0.7825, neg: 0.462, neu: 0.538, pos: 0.0, Venus in the Gemini can be more compared with love bud rather than love in a full bloom, so it must be given the opportunity to bloom.
# compound: 0.914, neg: 0.0, neu: 0.662, pos: 0.338, These people like diversity and they have a spark that is here to illuminate their love and their beloved partner.
# compound: 0.8979, neg: 0.0, neu: 0.558, pos: 0.442, People with Venus in Gemini typically make friends and acquaintances easily.
# compound: 0.6705, neg: 0.0, neu: 0.621, pos: 0.379, They like to meet people.
# compound: 0.3612, neg: 0.0, neu: 0.615, pos: 0.385, Sexual and family relationships are their "heart", but diverse social relationships are their "lungs" that breathe life into their being.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Venus in the 5th House
# Venus in the fifth house causes attraction to the opposite sex.
# compound: 0.4588, neg: 0.0, neu: 0.833, pos: 0.167, It creates romantic and popular people who love life.
# compound: 0.8957, neg: 0.0, neu: 0.298, pos: 0.702, This position of Venus also brings popularity among children, so these people usually become excellent parents.
# compound: 0.7783, neg: 0.0, neu: 0.673, pos: 0.327, They get along with young people and relationships with them will benefit them in some way; they will probably provide services to young people or they will work with them.
# compound: 0.4588, neg: 0.0, neu: 0.906, pos: 0.094, They are creative people who often have the potential to become successful actors.
# compound: 0.7717, neg: 0.0, neu: 0.621, pos: 0.379, Venus aspects
# Conjunction Sun (4°45’, Applying)
# Sextile Moon (0°33’, Separating)
# Conjunction Mercury (0°01’, Separating)
# Opposition Saturn (5°56’, Separating)
# Opposition Uranus (5°23’, Separating)
# Square Node (5°25’, Applying)
# Parallel Sun (0°10’)
# Contra-Parallel Saturn (0°53’)
# Contra-Parallel Uranus (0°28’)
# Contra-Parallel Neptune (1°03’)
#
#  Mars - Activity, energy, courage, assertiveness
# Mars symbolizes the need to get what we want.
# compound: 0.6808, neg: 0.0, neu: 0.881, pos: 0.119, This means our driving force which includes sex drive, initiative and courage.
# compound: 0.4939, neg: 0.0, neu: 0.775, pos: 0.225, Mars tells us about our desires, sensuality, courage and will.
# compound: 0.4939, neg: 0.0, neu: 0.738, pos: 0.262, It also tells us about how we are able to overcome obstacles and how active we are.
# compound: 0.0258, neg: 0.128, neu: 0.739, pos: 0.133, Mars in Pisces
# Mars in Pisces gives people the opportunity to work in professions where one does not come into direct contact with the public but exercises his authority in a detached workplace.
# compound: 0.1531, neg: 0.051, neu: 0.85, pos: 0.098, These people can work for example as detectives, prison wardens or doctors in hospitals.
# compound: -0.5106, neg: 0.202, neu: 0.798, pos: 0.0, They may also work in desolate places, for example on oil rigs.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, People with Mars in Pisces get what they want by delicate or indirect means.
# compound: 0.128, neg: 0.0, neu: 0.828, pos: 0.172, They tend to have secret love affairs and they can successfully hide such relationship from the public eye.
# compound: 0.7717, neg: 0.071, neu: 0.622, pos: 0.307, Their actions are affected by strong emotional undercurrents and if they do not want them to negatively influence their efforts to reach their goals they have to figure out what these emotional undercurrents mean.
# compound: 0.5828, neg: 0.073, neu: 0.729, pos: 0.198, Mars in the 2nd House
# Mars in the second house suggests a person who is looking for material and financial gains and who is successful in this area.
# compound: 0.7351, neg: 0.0, neu: 0.801, pos: 0.199, They have energy that drives them to make money but at the same time forces them to spend everything they earn.
# compound: 0.1406, neg: 0.0, neu: 0.928, pos: 0.072, They need to learn to control their financial situation which is hard for them because they have no natural talent for it.
# compound: 0.4019, neg: 0.134, neu: 0.669, pos: 0.197, These people are competitive in business and financial matters and they often run their own business.
# compound: 0.2023, neg: 0.0, neu: 0.833, pos: 0.167, They are not afraid of taking risks in this area and they are determined to reach their goals.
# compound: 0.1027, neg: 0.102, neu: 0.728, pos: 0.17, Mars aspects
# Square Sun (7°41’, Separating)
# Sextile Neptune (2°16’, Separating)
# Trine Pluto (1°26’, Separating)
#
#  Jupiter - Happiness, optimism, expansion
# Jupiter symbolizes growth, expansion, laws, faith and ethics that guide it.
# compound: 0.91, neg: 0.0, neu: 0.667, pos: 0.333, It represents a sense for development and support, which can lead to opportunities, wealth and faith.
# compound: 0.8834, neg: 0.0, neu: 0.493, pos: 0.507, However, if Jupiter is damaged, the person becomes immoral and extremist.
# compound: -0.7096, neg: 0.396, neu: 0.604, pos: 0.0, Jupiter in Taurus
# People with Jupiter in Taurus believe in the importance of financial security and social status, and the comfort these values provide.
# compound: 0.8442, neg: 0.0, neu: 0.664, pos: 0.336, To a greater or lesser extent, they are capable of attracting wealth in some way.
# compound: 0.886, neg: 0.0, neu: 0.467, pos: 0.533, Jupiter in Taurus brings the question of what to do with money.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Growth through stabilisation means that the improvement of material conditions is closely related to the understanding that stability is a natural state and it is maintained by allowing resources to flow in as well as out.
# compound: 0.8481, neg: 0.0, neu: 0.752, pos: 0.248, If people with Jupiter in Taurus understand this wisdom, they will likely find themselves in a managerial position or they will become asset managers or someone who is responsible for the growth of somebody´s assets.
# compound: 0.9022, neg: 0.0, neu: 0.689, pos: 0.311, Jupiter in the 4th House
# Jupiter in the fourth house means that this planet of development and expansion will play an important role in the home and family of these people who will be under the influence of their parents until they are quite old.
# compound: 0.4939, neg: 0.0, neu: 0.911, pos: 0.089, Parents, especially mothers, take good care of them, help them and give them good manners and education.
# compound: 0.9048, neg: 0.0, neu: 0.515, pos: 0.485, This will result in high quality education and advantages in their social life.
# compound: 0.3612, neg: 0.0, neu: 0.828, pos: 0.172, The life of these people will be full and happy, especially in later life.
# compound: 0.5719, neg: 0.0, neu: 0.778, pos: 0.222, Jupiter aspects
# Trine Ascendant (6°26’, Separating)
# Sextile Node (2°54’, Separating)
#
#  Saturn - Restriction, order, maturity, time
# Saturn is our strict teacher who is able to ruthlessly examine our maturity.
# compound: -0.2732, neg: 0.072, neu: 0.928, pos: 0.0, However, it is not only the despot, but also the archetype of the sage who uses pain as a means to get our attention on what we should focus on and what we should continue to develop.
# compound: -0.6652, neg: 0.113, neu: 0.887, pos: 0.0, Saturn in Capricorn
# People with Saturn in Capricorn keep track of their goals with unquenchable determination regardless of time and they can be compared to the Rock of Gibraltar without exaggeration.
# compound: 0.4019, neg: 0.0, neu: 0.917, pos: 0.083, In spite of all the obstacles and failures, they eventually achieve great success and they are respected by others.
# compound: 0.4404, neg: 0.274, neu: 0.395, pos: 0.331, People with Saturn in Capricorn have to learn to know their place.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, These people tend to succumb to what society expects from people of their social status, class, belief, race etc.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Yet, a compensatory reaction may occur, that is, they may want to avoid and resist all that is expected of them on the basis of their social status, class or race, and they do not want to be put in a box.
# compound: -0.1531, neg: 0.053, neu: 0.885, pos: 0.062, Saturn in the 12th House
# Saturn in the twelfth house suggests work in the background, usually in a large organisation.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, These people usually do not achieve recognition for their abilities and results.
# compound: 0.25, neg: 0.0, neu: 0.846, pos: 0.154, They usually doubt their abilities and long for solitude.
# compound: -0.128, neg: 0.217, neu: 0.609, pos: 0.174, They are usually loners who lack self-confidence.
# compound: -0.4939, neg: 0.457, neu: 0.543, pos: 0.0, Saturn aspects
# Trine Moon (5°22’, Applying)
# Opposition Mercury (5°54’, Separating)
# Opposition Venus (5°56’, Separating)
# Conjunction Uranus (0°32’, Applying)
# Contra-Parallel Sun (0°43’)
# Contra-Parallel Venus (0°53’)
# Parallel Neptune (0°10’)
#
#  Uranus - Originality, freedom, revolution
# Uranus is the power of awakening, which often means that there will be some disruption and change.
# compound: 0.4019, neg: 0.047, neu: 0.873, pos: 0.08, Events under the influence of Uranus are unexpected or unpredictable, forcing us to do things in a new way and face the truth about this or that issue.
# compound: 0.3182, neg: 0.0, neu: 0.919, pos: 0.081, Uranus in Sagittarius
# (Note: Uranus is a slow transpersonal planet and may remain in a single sign for up to many years.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, The description of Uranus in Sagittarius is therefore valid for the entire generation of people and is very general.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, The characteristic of the personality is in the description of Uranus in the 12th house.)
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, People with Uranus in Sagittarius strive for spiritual progress and intellectual growth.
# compound: 0.8271, neg: 0.0, neu: 0.508, pos: 0.492, They often have revolutionary thoughts.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, They see other races as equals and they often fight against xenophobia.
# compound: -0.3818, neg: 0.191, neu: 0.809, pos: 0.0, They love flying and they consider expeditions to space very exciting.
# compound: 0.8268, neg: 0.0, neu: 0.539, pos: 0.461, They bring new directions to philosophy.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, They are optimistic and they tend to make unexpected and unplanned journeys to other countries.
# compound: 0.3182, neg: 0.0, neu: 0.859, pos: 0.141, Uranus in the 12th House
# Uranus in the twelfth house suggests volatility and changes in the subconscious mind.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, It can mean a subconscious feeling of imprisonment or a desire for liberation and independence.
# compound: 0.4939, neg: 0.0, neu: 0.724, pos: 0.276, These people like to spend time alone so they often find a job where they can work independently.
# compound: 0.128, neg: 0.103, neu: 0.769, pos: 0.128, They are gifted researchers who may have a good mental potential.
# compound: 0.4404, neg: 0.0, neu: 0.756, pos: 0.244, They need to accept life as it is and stop subconsciously being in the opposition.
# compound: 0.1027, neg: 0.124, neu: 0.73, pos: 0.146, Uranus aspects
# Trine Moon (4°49’, Applying)
# Opposition Mercury (5°21’, Separating)
# Opposition Venus (5°23’, Separating)
# Conjunction Saturn (0°32’, Applying)
# Contra-Parallel Sun (0°38’)
# Contra-Parallel Venus (0°28’)
#
#  Neptune - Fantasy, illusion, spirituality, imagination
# Neptune is called the Lord of the Invisible Empire, which is a mysterious name of a mysterious planet.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Perhaps we could describe it as a dimension of life that cannot be experienced by our five senses and we can only understand and perceive it in our imagination.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Neptune in Capricorn
# (Note: Neptune is a slow transpersonal planet and may remain in a single sign for up to many years.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, The description of Neptune in Capricorn is therefore valid for the entire generation of people and is very general.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, The characteristic of the personality is in the description of Neptune in the 12th house.)
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Neptune in Capricorn gives people determination and the ability to concentrate.
# compound: 0.6124, neg: 0.0, neu: 0.643, pos: 0.357, However, it can ruin their typical Capricorn rationality.
# compound: -0.5859, neg: 0.352, neu: 0.648, pos: 0.0, This position somewhat shatters their natural desire for perfection, but it gives people desire to achieve spiritual goals.
# compound: 0.811, neg: 0.0, neu: 0.599, pos: 0.401, Neptune in the 12th House
# Neptune in the twelfth house affects the unconscious mind.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Sometimes it causes fears and difficulties with problems that spring from the past.
# compound: -0.7717, neg: 0.435, neu: 0.565, pos: 0.0, These people have the tendency to focus on the wrong side of life.
# compound: -0.4767, neg: 0.205, neu: 0.795, pos: 0.0, They often display great empathy towards physically or mentally handicapped people.
# compound: 0.6249, neg: 0.0, neu: 0.709, pos: 0.291, Neptune in the twelfth house suggests people who focus on their own soul and avoid everyday affairs.
# compound: -0.296, neg: 0.121, neu: 0.879, pos: 0.0, Neptune aspects
# Sextile Mars (2°16’, Separating)
# Sextile Pluto (0°50’, Separating)
# Contra-Parallel Sun (0°53’)
# Contra-Parallel Venus (1°03’)
# Parallel Saturn (0°10’)
#
#  Pluto - Transformation, regeneration, power
# Pluto is the planet of death and rebirth.
# compound: -0.5994, neg: 0.115, neu: 0.885, pos: 0.0, It is the end of all things, it is the Judgment Day.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, It can give rise to obsessions or convictions.
# compound: -0.2263, neg: 0.213, neu: 0.787, pos: 0.0, On the dark end of its spectrum it can manifest as "succumbing to the urge," or it can create an individual who has the ability to get to the core of things, destroy negative things and bring on healing and transformation.
# compound: -0.5859, neg: 0.148, neu: 0.761, pos: 0.091, Pluto in Scorpio
# (Note: Pluto is a slow transpersonal planet and may remain in a single sign for up to many years.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, The description of Pluto in Scorpio is therefore valid for the entire generation of people and is very general.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, The characteristic of the personality is in the description of Pluto in the 10th house.)
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, People with Pluto in Scorpio have a passionate desire for mystery.
# compound: 0.7269, neg: 0.0, neu: 0.567, pos: 0.433, They like to use intrigues and they have a great disposition for personal transformation that can happen especially through their desires.
# compound: 0.8176, neg: 0.0, neu: 0.667, pos: 0.333, They are prolific, universal and capable.
# compound: 0.3818, neg: 0.0, neu: 0.658, pos: 0.342, They radiate occult powers.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Their sexuality is also transforming for them, but at the same time they can feel restricted by it.
# compound: -0.5267, neg: 0.167, neu: 0.833, pos: 0.0, Pluto in the 10th House
# Pluto in the tenth house suggests a person who has a strong will and need to achieve success in his career.
# compound: 0.7906, neg: 0.0, neu: 0.759, pos: 0.241, Pluto in this house suggests a career in a scientific field, in healing or medicine, or in a profession where one can deal with powerful individuals, for example politics.
# compound: 0.4215, neg: 0.0, neu: 0.899, pos: 0.101, This planet will cause changes and interruptions in business or occupational matters.
# compound: -0.3818, neg: 0.196, neu: 0.725, pos: 0.08, Pluto aspects
# Trine Mars (1°26’, Separating)
# Sextile Neptune (0°50’, Separating)
#
# Objects:
#
#  Lunar Nodes - North Node and South Node
# The Lunar Nodes aren’t planets, but rather astrology mathematical points, that are directly opposite each other in the chart.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, It is said, that your life purpose is encoded between them - in the line between North Node and South Node.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, The South Node indicates your comfort zone, your habitual place, while your North Node shows life lessons and what you’re striving for in this lifetime.
# compound: 0.3612, neg: 0.0, neu: 0.906, pos: 0.094, Both Lunar Nodes are almost always retrogade.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, North Node (Mean) in Pisces - South Node in Virgo
# North Node in Pisces brings the conflict between transcendental effort and everyday reality, between chaos and order, and between spirituality and reason.
# compound: -0.7184, neg: 0.171, neu: 0.829, pos: 0.0, These people need to open up to their spirituality and imagination.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, They need to escape the constraints of the usual and explainable and be open to the unusual and unexplainable.
# compound: 0.1779, neg: 0.0, neu: 0.914, pos: 0.086, They need to go beyond the rational and analytical, develop imaginative powers and spiritual awareness.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, They should stop working so hard and find time for themselves.
# compound: -0.4391, neg: 0.302, neu: 0.698, pos: 0.0, They should learn to make self-sacrifice and show love for other people.
# compound: 0.6369, neg: 0.0, neu: 0.724, pos: 0.276, Beware of morbid obsession with order, cleanliness and rejection of everything that is not in perfect order or cannot be explained.
# compound: -0.8359, neg: 0.331, neu: 0.669, pos: 0.0, North Node (Mean) in the 3rd House - South Node in the 9th House
# North Node in the third house brings the conflict between seeking objectivity and lively communication on the one hand, and clinging to a highly subjective understanding, firmly anchored opinions and commands on the other.
# compound: 0.5859, neg: 0.045, neu: 0.837, pos: 0.119, These people need to learn how to express complex contexts and ideas in everyday language, how to convey spiritual thinking into practical life, transfer it in comprehensible form and show clearly the connection between the philosophical and noble knowledge and values of everyday life.
# compound: 0.8126, neg: 0.0, neu: 0.83, pos: 0.17, Beware of prejudices and stubborn beliefs.
# compound: -0.6705, neg: 0.579, neu: 0.421, pos: 0.0, Node (Mean) aspects
# Square Sun (0°40’, Separating)
# Square Mercury (5°27’, Applying)
# Square Venus (5°25’, Applying)
# Sextile Jupiter (2°54’, Separating)
#
#  Lilith - Black Moon - Fascination and Denial
# Lilith is a fictional point - the second empty focal point of elliptical orbit of the Moon around the Earth.
# compound: 0.34, neg: 0.039, neu: 0.891, pos: 0.07, In mythology, Lilith refused to submit to Adam, rebelled against the connection between Adam and Eve, decided to escape from the world of people and made a connection with Satan.
# compound: -0.3612, neg: 0.132, neu: 0.815, pos: 0.053, In astrology, Lilith symbolizes either fascination or refusal of topics with which she is connected with.
# compound: 0.4939, neg: 0.0, neu: 0.824, pos: 0.176, Both, the fascination or the rejection of the given topics, can eventually engulf the person and take him "away" from the human world.
# compound: -0.0772, neg: 0.126, neu: 0.758, pos: 0.116, Lilith (Mean) in Virgo
# Rebellion against order; provocative humour.
# compound: 0.3818, neg: 0.129, neu: 0.603, pos: 0.267, Their sensuality is strongly suppressed by trying to appear calm; emotional conflicts often occur because it is very difficult for these people to feel relaxed.
# compound: 0.4228, neg: 0.161, neu: 0.566, pos: 0.274, They want to suppress their instincts or they appear to be cold and perverted.
# compound: -0.4939, neg: 0.208, neu: 0.714, pos: 0.077, Beware of alcoholism and surgery of the intestines.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Lilith (Mean) in the 8th House
# Tendency to ask questions about death or an obsession with death.
# compound: -0.8807, neg: 0.421, neu: 0.579, pos: 0.0, Chiron - Wounded Healer, inner teacher
# Chiron is an asteroid between Saturn and Uranus.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Its orbit is very unusual and represents a bridge between material and spiritual worlds.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, According to mythology, Chiron was a great healer, wise teacher and one of the immortal Centaurs.
# compound: 0.8481, neg: 0.0, neu: 0.566, pos: 0.434, Unfortunately, he was "deadly" injured by a poisonous arrow by Heracles, his favourite disciple.
# compound: -0.8316, neg: 0.468, neu: 0.532, pos: 0.0, He was suffering in great pain but he could not die.
# compound: 0.5528, neg: 0.234, neu: 0.39, pos: 0.377, Finally, he gave up his immortality for the benefit of Prometheus who was also suffering, and Chiron was sent to the underworld.
# compound: -0.0258, neg: 0.119, neu: 0.766, pos: 0.115, In the underworld Zeus had mercy for him and he raised him to the heaven.
# compound: 0.7003, neg: 0.0, neu: 0.691, pos: 0.309, In astrology, Chiron symbolizes our unhealable injuries and incurable trauma.
# compound: -0.4215, neg: 0.237, neu: 0.763, pos: 0.0, However, if a person, instead of drowning in his own trauma, is able to accept the trauma and help others who are also suffering, and accept that suffering is part of life, then Chiron may be the key to wisdom, or even to some sort of "Initiation Gate".
# compound: -0.128, neg: 0.19, neu: 0.628, pos: 0.182, Chiron in Gemini
# Without success, these people keep trying to explain to other what they wanted to say, what they said and what they meant by it.
# compound: -0.4585, neg: 0.103, neu: 0.897, pos: 0.0, They either believe that nobody listens to them, or that no matter how hard they try, others cannot understand them or do not want to understand them.
# compound: -0.4063, neg: 0.167, neu: 0.795, pos: 0.038, The more they try to correct this misunderstanding, the more this sense of misunderstanding that they can never overcome hurts them.
# compound: -0.6054, neg: 0.24, neu: 0.665, pos: 0.094, Chiron in the 6th House
# These people are sick all their life; their illnesses are not too serious, but they are chronic and it seems that they cannot be cured, especially when both medical professionals and traditional healers cannot give the correct diagnosis.
# compound: -0.4835, neg: 0.094, neu: 0.882, pos: 0.024, It is as if these people took all the illness of others on themselves and had no choice but to learn to live with their health problems and keep searching for new ways to cure them or at least to alleviate the symptoms.
# compound: -0.7184, neg: 0.149, neu: 0.851, pos: 0.0, But there is always the fear that once one illness is cured, another, more serious illness will suddenly appear.
# compound: -0.923, neg: 0.47, neu: 0.53, pos: 0.0, Main aspects
#  Sun Sextile Moon (5°18’, Separating)
# Emotions and feelings of the Moon are in harmony with ego and individuality of the Sun.
# compound: 0.4019, neg: 0.0, neu: 0.891, pos: 0.109, This contributes to balance, relaxation and inner peace.
# compound: 0.7845, neg: 0.0, neu: 0.465, pos: 0.535, This aspect also greatly increases the chance to find success and satisfaction in life.
# compound: 0.8344, neg: 0.0, neu: 0.554, pos: 0.446, Relationships with the opposite sex are mostly balanced and harmonious.
# compound: 0.4588, neg: 0.0, neu: 0.75, pos: 0.25, Sun Conjunction Mercury (4°47’, Applying)
# There can only be conjunction between the Sun and Mercury.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, People with this aspect are subjective and creative; they can express their ideas well and they are often very artistic.
# compound: 0.6124, neg: 0.0, neu: 0.783, pos: 0.217, This is a great aspect for artists who perform on stage.
# compound: 0.6249, neg: 0.0, neu: 0.687, pos: 0.313, These people are intellectuals, but their thinking is very subjective and they can sometimes lack objectivity or the ability to see things from the outside.
# compound: 0.2023, neg: 0.099, neu: 0.741, pos: 0.16, Sun Conjunction Venus (4°45’, Applying)
# There can only be conjunction between the Sun and Venus.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, This aspect highlights feminine characteristics of both sexes.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, It also supports artistic and creative inclinations.
# compound: 0.6597, neg: 0.0, neu: 0.481, pos: 0.519, These people are often optimistic and they enjoy the company of other people.
# compound: 0.6705, neg: 0.0, neu: 0.667, pos: 0.333, They have a good taste for fashionable clothes.
# compound: 0.4404, neg: 0.0, neu: 0.674, pos: 0.326, Sun Square Mars (7°41’, Separating)
# This aspect give these people physical strength and the ability to work hard.
# compound: 0.6249, neg: 0.064, neu: 0.685, pos: 0.251, However they tend to take unnecessary risks.
# compound: -0.2732, neg: 0.259, neu: 0.741, pos: 0.0, They may also be too impulsive, easily excitable and selfish.
# compound: 0.2023, neg: 0.207, neu: 0.467, pos: 0.327, Moon Sextile Mercury (0°31’, Separating)
# This harmonious aspect give people good memory, poetic soul and the ability to understand others.
# compound: 0.802, neg: 0.0, neu: 0.675, pos: 0.325, It helps people to become good teachers, journalists and psychologists.
# compound: 0.6705, neg: 0.0, neu: 0.593, pos: 0.407, These people are interested in their origin and roots and in environmental problems.
# compound: 0.0, neg: 0.165, neu: 0.671, pos: 0.165, They are often very intelligent.
# compound: 0.5095, neg: 0.0, neu: 0.548, pos: 0.452, Moon Sextile Venus (0°33’, Separating)
# This harmonious aspect gives people balanced temperament, charming manners and usually also good looks.
# compound: 0.8658, neg: 0.0, neu: 0.623, pos: 0.377, Social success is almost guaranteed.
# compound: 0.5719, neg: 0.0, neu: 0.519, pos: 0.481, These people have creative abilities and they need to create a pleasant home environment.
# compound: 0.8519, neg: 0.0, neu: 0.466, pos: 0.534, Moon Trine Saturn (5°22’, Applying)
# This harmonious aspect gives people emotional stability.
# compound: 0.5574, neg: 0.0, neu: 0.685, pos: 0.315, In their home environment they often do things in a way they think is right.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, They are reliable, stable and helpful.
# compound: 0.6124, neg: 0.0, neu: 0.444, pos: 0.556, However, sometimes they may be pedant.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Moon Trine Uranus (4°49’, Applying)
# This harmonious aspect brings people the need for considerable emotional independence and freedom in the family environment.
# compound: 0.8316, neg: 0.0, neu: 0.683, pos: 0.317, These people often lead unconventional life and they do not like to yield to the will of others.
# compound: -0.2755, neg: 0.11, neu: 0.89, pos: 0.0, They feel separated from society (complex of separation).
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, They often experience stormy emotions and mood swings.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Mercury Conjunction Venus (0°01’, Separating)
# This conjunction gives people good manners and mental balance.
# compound: 0.4404, neg: 0.0, neu: 0.818, pos: 0.182, They can express themselves well and they are convincing.
# compound: 0.5859, neg: 0.0, neu: 0.593, pos: 0.407, Their views are also well-balanced.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Their thinking is often so rational that they are not able to express their feelings too openly.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Mercury Opposition Saturn (5°54’, Separating)
# This aspect gives people serious, conservative and practical mental processes.
# compound: -0.0772, neg: 0.085, neu: 0.915, pos: 0.0, However, these people also have the ability to calculate clearly and calmly, and this ability is often responsible for their success.
# compound: 0.9274, neg: 0.0, neu: 0.49, pos: 0.51, Mercury Opposition Uranus (5°21’, Separating)
# This aspect often brings extreme views and a strong need for independence.
# compound: 0.5106, neg: 0.0, neu: 0.82, pos: 0.18, These people force their opinions, which are often extreme an unrealistic, on others with arrogance and reluctance to compromise.
# compound: -0.7003, neg: 0.254, neu: 0.746, pos: 0.0, Their opinions are often way ahead and these people are inclined to get involved in movements that have views that may even be accepted in the future.
# compound: 0.2732, neg: 0.0, neu: 0.925, pos: 0.075, They are curious and intelligent.
# compound: 0.6486, neg: 0.0, neu: 0.361, pos: 0.639, They have novel way of thinking and they like to argue about opinions.
# compound: 0.34, neg: 0.14, neu: 0.581, pos: 0.279, Their creative activity is often destructive and it tends to be rebellious and chaotic.
# compound: -0.7579, neg: 0.422, neu: 0.448, pos: 0.13, Venus Opposition Saturn (5°56’, Separating)
# People with this aspect are responsible, reserved and hesitant.
# compound: 0.0772, neg: 0.123, neu: 0.736, pos: 0.141, They also have restraints that are often the result of poor parenting or fear of other authorities.
# compound: -0.743, neg: 0.296, neu: 0.704, pos: 0.0, This also causes fear of loss - they are afraid to lose both their property and their loved ones.
# compound: -0.5106, neg: 0.314, neu: 0.536, pos: 0.149, These people often submit their feelings to practicality (typical manifestation of this is getting married for security).
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, They subconsciously fear unemployment and poverty.
# compound: -0.8555, neg: 0.758, neu: 0.242, pos: 0.0, Venus Opposition Uranus (5°23’, Separating)
# This aspect complicates any relationship because these people see relationships literally as a loss of personal freedom and integrity.
# compound: 0.6705, neg: 0.079, neu: 0.687, pos: 0.234, They are mentally unstable and their feelings constantly change.
# compound: -0.3612, neg: 0.238, neu: 0.762, pos: 0.0, They often get involved in great number of relationships throughout their life.
# compound: 0.6597, neg: 0.0, neu: 0.649, pos: 0.351, They are unconventional, difficult to get along with, eccentric and original when they create art.
# compound: 0.2263, neg: 0.132, neu: 0.635, pos: 0.233, They are just as unstable in their ways of dealing with money.
# compound: -0.3612, neg: 0.185, neu: 0.815, pos: 0.0, They are adventurous and they lead unstable love life.
# compound: 0.6249, neg: 0.166, neu: 0.397, pos: 0.437, Mars Sextile Neptune (2°16’, Separating)
# This harmonious aspect manifests itself by giving people great fantasy, creativity, idealism and artistic talent.
# compound: 0.9485, neg: 0.0, neu: 0.443, pos: 0.557, However, people with this aspect are very impractical.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, A typical image of people with this aspect is an artist who knows the entire world of culture but he or she is useless in his or her private life.
# compound: -0.5719, neg: 0.117, neu: 0.883, pos: 0.0, Mars Trine Pluto (1°26’, Separating)
# This aspect increases Mars' power, so these people are hardworking and very thorough in all their activities.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, However, they are also stubborn, and if they have a goal, they are not easily discouraged from trying to achieve it.
# compound: -0.3565, neg: 0.197, neu: 0.709, pos: 0.094, This harmonious aspect is typical for army commanders and it gives them great talent for strategy.
# compound: 0.872, neg: 0.0, neu: 0.568, pos: 0.432, These people´s aim is to control both themselves and others.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, It is the only aspect that gives people the ability to achieve their objectives despite all possible obstacles.
# compound: 0.5399, neg: 0.0, neu: 0.781, pos: 0.219, Saturn Conjunction Uranus (0°32’, Applying)
# This conjunction gives people determination, originality, the ability to work hard, and the ability to find new solutions to all problems.
# compound: 0.5994, neg: 0.124, neu: 0.604, pos: 0.272, These people have democratic ideals but they are often too authoritative.
# compound: 0.1027, neg: 0.0, neu: 0.877, pos: 0.123, Neptune Sextile Pluto (0°50’, Separating)
# This harmonious aspect is long-lasting and it affects peace-making attitudes.
# compound: 0.4588, neg: 0.0, neu: 0.824, pos: 0.176, In connection with other aspects it further enhances peace-building and transformative actions on global scale.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Other aspects
#  Ascendant Square Moon (3°22’, Separating)
# This aspect can bring people instability and they may easily get influenced by others.
# compound: 0.34, neg: 0.0, neu: 0.893, pos: 0.107, Ascendant Trine Jupiter (6°26’, Separating)
# The positive thing about this aspect is that these people are generous, kind and that they are usually in excellent health.
# compound: 0.9325, neg: 0.0, neu: 0.611, pos: 0.389, MC Trine Sun (2°55’, Applying)
# This aspect indicates the ability to succeed using own means or with the help of others.
# compound: 0.802, neg: 0.0, neu: 0.687, pos: 0.313, MC Opposition Moon (8°14’, Applying)
# This aspect can bring instability in professional life and these people often have unstable professions.
# compound: -0.3612, neg: 0.116, neu: 0.884, pos: 0.0, Node Square Sun (0°40’, Separating)
# Frequent conflicts and tension among the demands of the Sun and the tasks of the lunar node that are waiting to be realised.
# compound: -0.5994, neg: 0.159, neu: 0.841, pos: 0.0, For this reason the life path of these people is not clear.
# compound: -0.2924, neg: 0.166, neu: 0.834, pos: 0.0, They are indecisive, chaotic and they have restraints.
# compound: -0.6369, neg: 0.464, neu: 0.536, pos: 0.0, Node Square Mercury (5°27’, Applying)
# The positive thing about this aspect is that it gives people intelligence and good life orientation.
# compound: 0.8625, neg: 0.0, neu: 0.652, pos: 0.348, They enjoy searching for the background of their motives and they are able to critically and creatively deal with their personality.
# compound: 0.6908, neg: 0.0, neu: 0.769, pos: 0.231, They are open towards others.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, They accept criticism easily and they do not avoid conflicts.
# compound: 0.6336, neg: 0.171, neu: 0.295, pos: 0.535, They manage life challenges with the help of their analytical and logical thinking.
# compound: 0.4588, neg: 0.0, neu: 0.733, pos: 0.267, The negative side of this aspect is that these people may have poor focus on their life path.
# compound: -0.7783, neg: 0.298, neu: 0.702, pos: 0.0, Their intellect always finds "good reasons" that stop them from focusing on a set goal.
# compound: 0.5719, neg: 0.115, neu: 0.576, pos: 0.309, This is the reason why these people are often stubborn, have defensive attitudes and why they cling to things that put them at disadvantage.
# compound: -0.6597, neg: 0.199, neu: 0.761, pos: 0.04, Node Square Venus (5°25’, Applying)
# The positive thing about this aspect is that these people are often pleasant, graceful, sexy and affectionate.
# compound: 0.9451, neg: 0.0, neu: 0.512, pos: 0.488, They can appreciate beauty and they like art.
# compound: 0.8402, neg: 0.0, neu: 0.357, pos: 0.643, They have a good taste.
# compound: 0.4404, neg: 0.0, neu: 0.508, pos: 0.492, This harmonious connection forms the focal point of their life and it helps them achieve their goals.
# compound: 0.6808, neg: 0.0, neu: 0.728, pos: 0.272, They have somewhat feminine radiating power that is very valuable and deserves to be acknowledged and developed.
# compound: 0.5256, neg: 0.0, neu: 0.825, pos: 0.175, The negative side of this aspect is that it can be difficult for these people to find inner peace because their love life is in constant conflict with the direction of their life.
# compound: 0.0516, neg: 0.192, neu: 0.633, pos: 0.174, They can experience feelings of unfulfillment and they may have great need for affection that is very hard to satisfy.
# compound: 0.877, neg: 0.059, neu: 0.562, pos: 0.378, Node Sextile Jupiter (2°54’, Separating)
# The positive thing about this aspect is that these people are confident in their abilities and this helps them overcome challenges in life.
# compound: 0.8934, neg: 0.0, neu: 0.644, pos: 0.356, Their life challenges are often connected with profound sensory experience and it gives people luck on their life journey.
# compound: 0.5106, neg: 0.0, neu: 0.798, pos: 0.202, Declination aspects - Parallels and Contra-Parallels
# Parallels and Contra-Parallels are aspects, which refer to degrees of declination above or below the celestial equator.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Parallel is similar to a conjunction, but usually provides benefits.
# compound: 0.5267, neg: 0.0, neu: 0.702, pos: 0.298, Contra-Parallel is said to be similar to the opposition, but weaker.
# compound: -0.5927, neg: 0.278, neu: 0.722, pos: 0.0, Note: The following parallel and contra-parallel interpretations are the same as the interpretations used for the conjunction and opposition.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Sun Parallel Venus (0°10’)
# There can only be conjunction between the Sun and Venus.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, This aspect highlights feminine characteristics of both sexes.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, It also supports artistic and creative inclinations.
# compound: 0.6597, neg: 0.0, neu: 0.481, pos: 0.519, These people are often optimistic and they enjoy the company of other people.
# compound: 0.6705, neg: 0.0, neu: 0.667, pos: 0.333, They have a good taste for fashionable clothes.
# compound: 0.4404, neg: 0.0, neu: 0.674, pos: 0.326, Sun Contra-Parallel Saturn (0°43’)
# This aspect creates two groups of people.
# compound: 0.2732, neg: 0.0, neu: 0.826, pos: 0.174, People in the first group tend to give up when they encounter problems.
# compound: -0.4019, neg: 0.184, neu: 0.816, pos: 0.0, When people in the second group encounter problems they get stimulated by them and perform better.
# compound: 0.2732, neg: 0.132, neu: 0.634, pos: 0.234, These people often have lower self-esteem that can be improved by good work.
# compound: 0.5859, neg: 0.121, neu: 0.549, pos: 0.33, Sun Contra-Parallel Uranus (0°38’)
# This aspect creates people that are too individualistic, selfish and eccentric.
# compound: -0.25, neg: 0.17, neu: 0.714, pos: 0.115, They are very independent and they guard their independence carefully.
# compound: 0.128, neg: 0.0, neu: 0.857, pos: 0.143, They are not always considerate towards other people and they sometimes suffer from mental exhaustion.
# compound: -0.8129, neg: 0.412, neu: 0.588, pos: 0.0, These people have the need to be different and they want to show their uniqueness.
# compound: 0.0772, neg: 0.0, neu: 0.915, pos: 0.085, They want to be teachers, mentors and examples to others.
# compound: 0.0772, neg: 0.0, neu: 0.874, pos: 0.126, These people are willing to go to the extremes in order to show their originality.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, They have trouble accepting authorities.
# compound: -0.0258, neg: 0.325, neu: 0.361, pos: 0.313, They use rebellion as means of attracting attention of other people.
# compound: 0.3818, neg: 0.11, neu: 0.662, pos: 0.228, Sun Contra-Parallel Neptune (0°53’)
# This aspect creates people that are overly empathetic and too willing to sacrifice themselves, and thus they may easily be used by others or cheated.
# compound: 0.4404, neg: 0.093, neu: 0.704, pos: 0.203, These people should stay away from drugs, alcohol and tobacco because they have considerable tendencies to use drugs and alcohol to solve their problems.
# compound: -0.2263, neg: 0.102, neu: 0.83, pos: 0.068, Venus Contra-Parallel Saturn (0°53’)
# People with this aspect are responsible, reserved and hesitant.
# compound: 0.0772, neg: 0.131, neu: 0.719, pos: 0.15, They also have restraints that are often the result of poor parenting or fear of other authorities.
# compound: -0.743, neg: 0.296, neu: 0.704, pos: 0.0, This also causes fear of loss - they are afraid to lose both their property and their loved ones.
# compound: -0.5106, neg: 0.314, neu: 0.536, pos: 0.149, These people often submit their feelings to practicality (typical manifestation of this is getting married for security).
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, They subconsciously fear unemployment and poverty.
# compound: -0.8555, neg: 0.758, neu: 0.242, pos: 0.0, Venus Contra-Parallel Uranus (0°28’)
# This aspect complicates any relationship because these people see relationships literally as a loss of personal freedom and integrity.
# compound: 0.6705, neg: 0.082, neu: 0.676, pos: 0.242, They are mentally unstable and their feelings constantly change.
# compound: -0.3612, neg: 0.238, neu: 0.762, pos: 0.0, They often get involved in great number of relationships throughout their life.
# compound: 0.6597, neg: 0.0, neu: 0.649, pos: 0.351, They are unconventional, difficult to get along with, eccentric and original when they create art.
# compound: 0.2263, neg: 0.132, neu: 0.635, pos: 0.233, They are just as unstable in their ways of dealing with money.
# compound: -0.3612, neg: 0.185, neu: 0.815, pos: 0.0, They are adventurous and they lead unstable love life.
# compound: 0.6249, neg: 0.166, neu: 0.397, pos: 0.437, Venus Contra-Parallel Neptune (1°03’)
# This aspect causes considerable romantic feelings that complicate life and put these people into intricate situations.
# compound: 0.5106, neg: 0.0, neu: 0.807, pos: 0.193, They often give priority to their own fantasies over reality.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, Esoteric activities sometimes become more important to them than the reality and take away considerable amounts of energy from the relationship.
# compound: 0.4927, neg: 0.0, neu: 0.819, pos: 0.181, These people should try to be more rational and have "thick skin".
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, They are usually very lazy.
# compound: -0.4201, neg: 0.411, neu: 0.589, pos: 0.0, For artists, this aspect brings inspiration, creativity, imagination, and very good taste.
# compound: 0.8479, neg: 0.0, neu: 0.495, pos: 0.505, Saturn Parallel Neptune (0°10’)
# It is necessary to distinguish which of the two planets is dominant in this conjunction.
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, If Saturn is dominant, then the person is able to keep his imagination under control and use it constructively to fulfill his dreams.
# compound: 0.6808, neg: 0.0, neu: 0.789, pos: 0.211, However, if Neptune is dominant, then the fantasy is too vivid, and these people fail to fulfill their fantasies and they become frustrated.
# compound: -0.6124, neg: 0.232, neu: 0.671, pos: 0.097, They start living in their fantasy world and they become practically useless.
# compound: -0.4215, neg: 0.203, neu: 0.797, pos: 0.0, These people can experience great spiritual passion - they may expand their consciousness at all costs and use all possible means to achieve their goal (spiritual fanatics).
# compound: 0.8555, neg: 0.0, neu: 0.71, pos: 0.29, Ascendant Contra-Parallel Mercury (0°12’)
# The positive thing about this aspect is that it gives people vitality and curiosity.
# compound: 0.7096, neg: 0.0, neu: 0.731, pos: 0.269, The negative side of this aspect is that it may cause distractibility and restlessness.
# compound: -0.802, neg: 0.427, neu: 0.573, pos: 0.0,

# %% [markdown]
# ## TF-IDF

# %%
# Crear el vectorizador TF-IDF
vectorizer = TfidfVectorizer(stop_words='english')  # Esto elimina palabras comunes (como "the", "and", etc.)

# Ajustar el modelo y transformar el texto
tfidf_matrix = vectorizer.fit_transform([extracted_text])

# Obtener los nombres de las características (palabras)
palabras = vectorizer.get_feature_names_out()

# Convertir la matriz TF-IDF en un formato más legible
tfidf_scores = tfidf_matrix.toarray()

# Mostrar los resultados (palabras y sus respectivos TF-IDF scores)
for palabra, score in zip(palabras, tfidf_scores[0]):
    print(f"{palabra}: {score:.4f}")
# Out:
# 01: 0.0141
# 03: 0.0141
# 10: 0.0283
# 10th: 0.0283
# 12: 0.0141
# 12th: 0.0283
# 14: 0.0141
# 16: 0.0141
# 18: 0.0188
# 1st: 0.0094
# 21: 0.0141
# 22: 0.0283
# 23: 0.0141
# 25: 0.0141
# 26: 0.0283
# 27: 0.0141
# 28: 0.0141
# 2nd: 0.0047
# 305: 0.0047
# 31: 0.0141
# 32: 0.0141
# 33: 0.0141
# 38: 0.0141
# 3rd: 0.0047
# 40: 0.0141
# 41: 0.0141
# 43: 0.0141
# 45: 0.0141
# 47: 0.0141
# 49: 0.0141
# 4th: 0.0141
# 50: 0.0141
# 53: 0.0283
# 54: 0.0283
# 55: 0.0141
# 56: 0.0141
# 5th: 0.0188
# 6th: 0.0094
# 7th: 0.0047
# 8th: 0.0047
# 9th: 0.0047
# abilities: 0.0188
# ability: 0.0753
# able: 0.0330
# accept: 0.0188
# accepted: 0.0047
# accepting: 0.0047
# accordance: 0.0047
# according: 0.0047
# achieve: 0.0471
# acknowledged: 0.0047
# acquaintances: 0.0047
# act: 0.0047
# actions: 0.0188
# active: 0.0047
# activities: 0.0141
# activity: 0.0188
# actors: 0.0094
# adam: 0.0094
# adapt: 0.0047
# administrators: 0.0047
# advantages: 0.0094
# adventurous: 0.0094
# affairs: 0.0094
# affected: 0.0047
# affection: 0.0094
# affectionate: 0.0047
# affects: 0.0094
# afraid: 0.0141
# ahead: 0.0047
# aim: 0.0047
# air: 0.0094
# alcohol: 0.0094
# alcoholism: 0.0047
# alleviate: 0.0047
# allowing: 0.0047
# amounts: 0.0047
# analyse: 0.0047
# analytical: 0.0141
# anchored: 0.0047
# antiques: 0.0047
# appear: 0.0141
# appearance: 0.0047
# applying: 0.1271
# appreciate: 0.0094
# archetype: 0.0047
# area: 0.0141
# areas: 0.0094
# aren: 0.0047
# argue: 0.0047
# argument: 0.0047
# aries: 0.0094
# army: 0.0047
# arrogance: 0.0047
# arrow: 0.0047
# art: 0.0188
# artist: 0.0047
# artistic: 0.0235
# artists: 0.0094
# asc: 0.0094
# ascendant: 0.0659
# ask: 0.0047
# aspect: 0.1836
# aspects: 0.0895
# assertiveness: 0.0047
# asset: 0.0047
# assets: 0.0047
# asteroid: 0.0047
# astrology: 0.0141
# attention: 0.0094
# attitude: 0.0047
# attitudes: 0.0094
# attracted: 0.0047
# attracting: 0.0094
# attraction: 0.0047
# attractivity: 0.0047
# authoritative: 0.0094
# authorities: 0.0141
# authority: 0.0094
# avoid: 0.0188
# awakening: 0.0047
# aware: 0.0047
# awareness: 0.0047
# away: 0.0188
# background: 0.0094
# balance: 0.0094
# balanced: 0.0141
# basic: 0.0047
# basis: 0.0047
# beauty: 0.0094
# behave: 0.0047
# behaviour: 0.0047
# belief: 0.0047
# beliefs: 0.0047
# believe: 0.0141
# beloved: 0.0047
# benefit: 0.0141
# benefits: 0.0047
# best: 0.0141
# better: 0.0047
# beware: 0.0141
# bit: 0.0094
# black: 0.0047
# bloom: 0.0094
# born: 0.0047
# box: 0.0047
# brag: 0.0047
# breathe: 0.0047
# bridge: 0.0047
# bring: 0.0188
# brings: 0.0377
# broader: 0.0047
# bud: 0.0047
# building: 0.0047
# business: 0.0235
# calculate: 0.0047
# called: 0.0047
# calm: 0.0094
# calmly: 0.0047
# capable: 0.0094
# capricorn: 0.0518
# care: 0.0047
# career: 0.0235
# carefully: 0.0047
# cause: 0.0141
# causes: 0.0235
# caution: 0.0047
# celestial: 0.0047
# centaurs: 0.0047
# certain: 0.0047
# challenges: 0.0141
# chance: 0.0047
# change: 0.0141
# changes: 0.0094
# chaos: 0.0047
# chaotic: 0.0094
# character: 0.0094
# characteristic: 0.0141
# characteristics: 0.0094
# charm: 0.0047
# charming: 0.0047
# chart: 0.0047
# cheated: 0.0047
# check: 0.0047
# childhood: 0.0047
# childish: 0.0047
# children: 0.0235
# chiron: 0.0377
# choice: 0.0047
# chronic: 0.0047
# class: 0.0094
# cleanliness: 0.0047
# cleansing: 0.0047
# clear: 0.0047
# clearly: 0.0094
# cling: 0.0047
# clinging: 0.0047
# closely: 0.0047
# closing: 0.0047
# clothes: 0.0094
# coeli: 0.0094
# cold: 0.0047
# come: 0.0047
# comfort: 0.0094
# comfortable: 0.0047
# commanders: 0.0047
# commands: 0.0047
# commitment: 0.0047
# communicate: 0.0047
# communication: 0.0094
# company: 0.0094
# compared: 0.0094
# compensatory: 0.0047
# competitive: 0.0094
# complex: 0.0094
# complicate: 0.0047
# complicates: 0.0094
# comprehensible: 0.0047
# compromise: 0.0047
# concentrate: 0.0047
# conditions: 0.0047
# confidence: 0.0094
# confident: 0.0047
# conflict: 0.0141
# conflicts: 0.0141
# conjunction: 0.0942
# connected: 0.0094
# connection: 0.0377
# consciousness: 0.0047
# conservative: 0.0094
# consider: 0.0047
# considerable: 0.0235
# considerate: 0.0047
# consistently: 0.0047
# constant: 0.0047
# constantly: 0.0094
# constraints: 0.0047
# constructive: 0.0047
# constructively: 0.0047
# consultants: 0.0047
# contact: 0.0047
# contexts: 0.0047
# continue: 0.0047
# contra: 0.1177
# contributes: 0.0047
# control: 0.0235
# convey: 0.0047
# convictions: 0.0047
# convincing: 0.0047
# core: 0.0047
# correct: 0.0094
# costs: 0.0047
# countries: 0.0047
# country: 0.0047
# courage: 0.0141
# create: 0.0188
# creates: 0.0283
# creative: 0.0424
# creatively: 0.0047
# creativity: 0.0141
# creditable: 0.0047
# critical: 0.0047
# critically: 0.0047
# criticism: 0.0047
# crowds: 0.0047
# culture: 0.0047
# cultured: 0.0047
# cure: 0.0047
# cured: 0.0094
# curiosity: 0.0047
# curious: 0.0047
# cusp: 0.0047
# damaged: 0.0047
# dark: 0.0047
# day: 0.0047
# deadline: 0.0047
# deadly: 0.0047
# deal: 0.0094
# dealing: 0.0094
# death: 0.0141
# decide: 0.0047
# decided: 0.0047
# declination: 0.0094
# deemed: 0.0047
# defensive: 0.0047
# definitely: 0.0047
# degree: 0.0047
# degrees: 0.0047
# delicate: 0.0047
# demands: 0.0047
# democratic: 0.0047
# denial: 0.0047
# depth: 0.0047
# describes: 0.0047
# description: 0.0283
# deserves: 0.0047
# desire: 0.0235
# desires: 0.0094
# desolate: 0.0047
# despite: 0.0047
# despot: 0.0047
# destroy: 0.0047
# destruction: 0.0047
# destructive: 0.0047
# detached: 0.0047
# detectives: 0.0047
# determination: 0.0141
# determined: 0.0047
# determines: 0.0047
# develop: 0.0094
# developed: 0.0047
# development: 0.0141
# diagnosis: 0.0047
# die: 0.0047
# different: 0.0141
# differentiate: 0.0047
# difficult: 0.0188
# difficulties: 0.0047
# dimension: 0.0047
# direct: 0.0047
# direction: 0.0047
# directions: 0.0047
# directly: 0.0047
# disadvantage: 0.0047
# disciple: 0.0047
# discipline: 0.0047
# discouraged: 0.0047
# discover: 0.0047
# discussions: 0.0047
# display: 0.0047
# disposition: 0.0047
# disruption: 0.0047
# distance: 0.0047
# distinguish: 0.0047
# distractibility: 0.0047
# diverse: 0.0047
# diversity: 0.0047
# doctors: 0.0047
# does: 0.0047
# dominant: 0.0141
# doubt: 0.0047
# dramatically: 0.0047
# dreams: 0.0094
# drive: 0.0047
# drives: 0.0047
# driving: 0.0047
# drowning: 0.0047
# drugs: 0.0094
# duties: 0.0047
# earn: 0.0047
# earth: 0.0047
# easily: 0.0283
# eccentric: 0.0141
# education: 0.0094
# effort: 0.0047
# efforts: 0.0047
# ego: 0.0047
# element: 0.0047
# elliptical: 0.0047
# emotional: 0.0235
# emotions: 0.0141
# empathetic: 0.0047
# empathy: 0.0047
# empire: 0.0047
# employment: 0.0047
# enables: 0.0047
# encoded: 0.0047
# encounter: 0.0094
# end: 0.0094
# endurance: 0.0047
# energy: 0.0235
# engineers: 0.0047
# engulf: 0.0047
# enhances: 0.0047
# enjoy: 0.0188
# entertainment: 0.0047
# enthusiasm: 0.0047
# entire: 0.0188
# environment: 0.0141
# environmental: 0.0047
# equals: 0.0047
# equator: 0.0047
# escape: 0.0094
# esoteric: 0.0047
# especially: 0.0188
# esteem: 0.0047
# ethics: 0.0047
# eve: 0.0047
# events: 0.0047
# eventually: 0.0094
# everyday: 0.0235
# exaggeration: 0.0047
# examine: 0.0047
# example: 0.0235
# examples: 0.0047
# excellent: 0.0094
# excitable: 0.0047
# exciting: 0.0047
# exercises: 0.0047
# exhaustion: 0.0047
# expand: 0.0047
# expands: 0.0047
# expansion: 0.0141
# expected: 0.0047
# expects: 0.0047
# expeditions: 0.0047
# experience: 0.0188
# experienced: 0.0047
# experiences: 0.0047
# explain: 0.0047
# explainable: 0.0047
# explained: 0.0047
# express: 0.0283
# expression: 0.0047
# extent: 0.0047
# extreme: 0.0094
# extremes: 0.0047
# extremist: 0.0047
# eye: 0.0047
# face: 0.0047
# fail: 0.0094
# failures: 0.0047
# faith: 0.0094
# fame: 0.0047
# family: 0.0235
# fanatics: 0.0047
# fantasies: 0.0094
# fantasy: 0.0188
# fascination: 0.0141
# fashionable: 0.0094
# faster: 0.0047
# father: 0.0047
# favourite: 0.0047
# fear: 0.0330
# fears: 0.0047
# feature: 0.0047
# feel: 0.0188
# feeling: 0.0094
# feelings: 0.0377
# feels: 0.0047
# feminine: 0.0141
# fertility: 0.0047
# fictional: 0.0047
# field: 0.0047
# fifth: 0.0235
# fight: 0.0047
# fights: 0.0047
# figure: 0.0047
# finally: 0.0047
# financial: 0.0188
# finds: 0.0047
# firmly: 0.0047
# flexibility: 0.0047
# flow: 0.0047
# flying: 0.0047
# focal: 0.0094
# focus: 0.0235
# focusing: 0.0047
# following: 0.0047
# force: 0.0094
# forces: 0.0047
# forcing: 0.0047
# form: 0.0047
# forms: 0.0047
# fourth: 0.0141
# freedom: 0.0235
# frequent: 0.0047
# friends: 0.0094
# frustrated: 0.0047
# fulfill: 0.0141
# future: 0.0047
# gains: 0.0047
# games: 0.0047
# gate: 0.0047
# gave: 0.0047
# gemini: 0.0424
# general: 0.0188
# generation: 0.0141
# generous: 0.0047
# getting: 0.0094
# gibraltar: 0.0047
# gifted: 0.0047
# given: 0.0094
# gives: 0.0801
# giving: 0.0047
# glamorous: 0.0047
# global: 0.0047
# goal: 0.0141
# goals: 0.0283
# good: 0.0706
# graceful: 0.0047
# gradually: 0.0047
# great: 0.0565
# greater: 0.0047
# greatest: 0.0047
# greatly: 0.0047
# group: 0.0094
# groups: 0.0047
# growth: 0.0188
# guaranteed: 0.0047
# guard: 0.0047
# guide: 0.0047
# habitual: 0.0047
# hand: 0.0047
# handicapped: 0.0047
# happen: 0.0094
# happening: 0.0188
# happiness: 0.0094
# happy: 0.0094
# hard: 0.0283
# hardworking: 0.0047
# harmonious: 0.0424
# harmony: 0.0094
# hate: 0.0047
# healer: 0.0094
# healers: 0.0047
# healing: 0.0094
# health: 0.0094
# heart: 0.0047
# heaven: 0.0047
# help: 0.0188
# helpful: 0.0047
# helps: 0.0141
# heracles: 0.0047
# hesitant: 0.0094
# hide: 0.0094
# high: 0.0047
# highlights: 0.0094
# highly: 0.0047
# hint: 0.0047
# hobbies: 0.0047
# home: 0.0235
# honours: 0.0047
# horoscope: 0.0047
# hospitals: 0.0047
# house: 0.2260
# houses: 0.0141
# human: 0.0047
# humour: 0.0047
# hurts: 0.0047
# idealism: 0.0047
# ideals: 0.0047
# ideas: 0.0094
# identity: 0.0047
# illness: 0.0141
# illnesses: 0.0047
# illuminate: 0.0047
# illusion: 0.0047
# illusions: 0.0047
# image: 0.0047
# imagination: 0.0235
# imaginative: 0.0047
# immoral: 0.0047
# immortal: 0.0047
# immortality: 0.0047
# importance: 0.0047
# important: 0.0094
# impractical: 0.0047
# impression: 0.0047
# imprisonment: 0.0047
# improved: 0.0047
# improvement: 0.0047
# impulsive: 0.0047
# inclinations: 0.0141
# inclined: 0.0047
# includes: 0.0047
# increases: 0.0094
# incurable: 0.0047
# indecisive: 0.0047
# independence: 0.0188
# independent: 0.0094
# independently: 0.0047
# indicates: 0.0235
# indirect: 0.0047
# individual: 0.0047
# individualistic: 0.0047
# individuality: 0.0094
# individuals: 0.0047
# influence: 0.0235
# influenced: 0.0047
# initiation: 0.0047
# initiative: 0.0047
# injured: 0.0047
# injuries: 0.0047
# innate: 0.0047
# inner: 0.0188
# insecure: 0.0047
# inspiration: 0.0047
# inspire: 0.0047
# instability: 0.0094
# instead: 0.0047
# instinctively: 0.0047
# instincts: 0.0094
# integration: 0.0047
# integrity: 0.0094
# intellect: 0.0094
# intellectual: 0.0094
# intellectuals: 0.0047
# intelligence: 0.0094
# intelligent: 0.0141
# interact: 0.0047
# interested: 0.0141
# interesting: 0.0047
# interpretations: 0.0141
# interruptions: 0.0047
# intestines: 0.0047
# intricate: 0.0047
# intrigues: 0.0047
# investments: 0.0047
# invisible: 0.0047
# involved: 0.0141
# irritably: 0.0047
# isolate: 0.0047
# issue: 0.0047
# job: 0.0141
# jobs: 0.0094
# journalists: 0.0047
# journey: 0.0047
# journeys: 0.0047
# judgment: 0.0047
# jupiter: 0.0706
# just: 0.0094
# key: 0.0047
# kind: 0.0141
# know: 0.0047
# knowledge: 0.0047
# knows: 0.0047
# lack: 0.0094
# language: 0.0047
# large: 0.0047
# lasting: 0.0047
# later: 0.0047
# laws: 0.0047
# lazy: 0.0047
# lead: 0.0188
# learn: 0.0283
# learning: 0.0094
# lesser: 0.0047
# lessons: 0.0047
# liberation: 0.0047
# libra: 0.0141
# life: 0.1836
# lifetime: 0.0047
# like: 0.0424
# likely: 0.0047
# lilith: 0.0283
# limits: 0.0047
# line: 0.0047
# listens: 0.0047
# literally: 0.0094
# live: 0.0094
# lively: 0.0047
# living: 0.0047
# located: 0.0047
# location: 0.0047
# logical: 0.0047
# loners: 0.0047
# long: 0.0094
# look: 0.0047
# looking: 0.0047
# looks: 0.0047
# lord: 0.0047
# lose: 0.0094
# loss: 0.0188
# love: 0.0659
# loved: 0.0094
# lower: 0.0047
# luck: 0.0047
# lunar: 0.0188
# lungs: 0.0047
# main: 0.0094
# maintain: 0.0047
# maintained: 0.0047
# make: 0.0235
# making: 0.0047
# manage: 0.0094
# managerial: 0.0047
# managers: 0.0047
# manifest: 0.0094
# manifestation: 0.0094
# manifesting: 0.0047
# manifests: 0.0094
# manner: 0.0047
# manners: 0.0141
# married: 0.0094
# mars: 0.0895
# material: 0.0141
# mathematical: 0.0047
# matter: 0.0047
# matters: 0.0141
# mature: 0.0047
# maturity: 0.0094
# mc: 0.0330
# mean: 0.0330
# means: 0.0518
# meant: 0.0047
# medical: 0.0047
# medicine: 0.0047
# medium: 0.0094
# meet: 0.0047
# memory: 0.0047
# mental: 0.0235
# mentally: 0.0188
# mentors: 0.0047
# mercury: 0.1130
# mercy: 0.0047
# merry: 0.0047
# mind: 0.0094
# minds: 0.0047
# misunderstanding: 0.0094
# money: 0.0188
# mood: 0.0047
# moon: 0.1318
# morbid: 0.0047
# mother: 0.0094
# mothers: 0.0047
# motives: 0.0047
# movements: 0.0047
# mysterious: 0.0094
# mystery: 0.0047
# mythology: 0.0094
# natural: 0.0235
# nature: 0.0094
# necessary: 0.0047
# need: 0.0753
# needs: 0.0047
# negative: 0.0235
# negatively: 0.0047
# neptune: 0.1036
# new: 0.0283
# noble: 0.0047
# node: 0.1036
# nodes: 0.0141
# north: 0.0330
# note: 0.0188
# notice: 0.0047
# noticing: 0.0047
# novel: 0.0141
# number: 0.0094
# obedience: 0.0047
# objective: 0.0047
# objectives: 0.0047
# objectivity: 0.0094
# objects: 0.0047
# obsession: 0.0094
# obsessions: 0.0047
# obstacles: 0.0141
# occult: 0.0047
# occupational: 0.0047
# occur: 0.0141
# oil: 0.0047
# old: 0.0047
# ones: 0.0094
# open: 0.0188
# openly: 0.0047
# opinions: 0.0188
# opportunities: 0.0047
# opportunity: 0.0094
# opposing: 0.0047
# opposite: 0.0141
# opposition: 0.0848
# optimism: 0.0047
# optimistic: 0.0141
# orally: 0.0047
# orbit: 0.0094
# order: 0.0330
# organisation: 0.0047
# organised: 0.0047
# organize: 0.0047
# orientation: 0.0047
# origin: 0.0047
# original: 0.0094
# originality: 0.0141
# outside: 0.0047
# overcome: 0.0141
# overly: 0.0047
# pace: 0.0047
# pain: 0.0094
# parallel: 0.1460
# parallels: 0.0188
# parenting: 0.0094
# parents: 0.0188
# partner: 0.0094
# pass: 0.0047
# passion: 0.0047
# passionate: 0.0047
# past: 0.0094
# path: 0.0094
# peace: 0.0188
# pedant: 0.0047
# people: 0.6075
# perceive: 0.0047
# perfect: 0.0047
# perfection: 0.0047
# perform: 0.0094
# performing: 0.0047
# person: 0.0471
# personal: 0.0235
# personalities: 0.0047
# personality: 0.0424
# perverted: 0.0047
# phase: 0.0047
# philosophical: 0.0047
# philosophy: 0.0047
# physical: 0.0141
# physically: 0.0047
# pisces: 0.0235
# place: 0.0188
# places: 0.0047
# planet: 0.0518
# planets: 0.0424
# play: 0.0047
# pleasant: 0.0094
# pleasure: 0.0047
# pleasures: 0.0047
# pluto: 0.0753
# poetic: 0.0047
# point: 0.0141
# points: 0.0047
# poisonous: 0.0047
# politicians: 0.0047
# politics: 0.0047
# poor: 0.0141
# popular: 0.0047
# popularity: 0.0047
# position: 0.0235
# positive: 0.0235
# possibility: 0.0047
# possible: 0.0094
# potential: 0.0141
# poverty: 0.0094
# power: 0.0188
# powerful: 0.0047
# powerfully: 0.0047
# powers: 0.0094
# practical: 0.0141
# practicality: 0.0094
# practically: 0.0047
# practice: 0.0047
# predestined: 0.0047
# prejudices: 0.0047
# prestige: 0.0094
# prevent: 0.0047
# principles: 0.0047
# priority: 0.0047
# prison: 0.0047
# private: 0.0047
# probably: 0.0094
# problems: 0.0377
# proceed: 0.0047
# process: 0.0047
# processes: 0.0047
# profession: 0.0141
# professional: 0.0094
# professionals: 0.0047
# professions: 0.0094
# profound: 0.0047
# progress: 0.0047
# project: 0.0047
# prolific: 0.0047
# prometheus: 0.0047
# properly: 0.0047
# property: 0.0094
# provide: 0.0094
# provides: 0.0047
# provocative: 0.0047
# prudent: 0.0047
# psychologists: 0.0047
# public: 0.0188
# punishment: 0.0047
# purpose: 0.0047
# push: 0.0047
# quality: 0.0047
# quarter: 0.0047
# question: 0.0047
# questions: 0.0047
# quick: 0.0047
# quickly: 0.0094
# quite: 0.0047
# race: 0.0094
# races: 0.0047
# radiate: 0.0047
# radiating: 0.0047
# raise: 0.0047
# raised: 0.0047
# rational: 0.0141
# rationality: 0.0047
# reach: 0.0094
# reaction: 0.0047
# realised: 0.0047
# reality: 0.0235
# reason: 0.0141
# reasons: 0.0047
# rebelled: 0.0047
# rebellion: 0.0094
# rebellious: 0.0047
# rebirth: 0.0047
# receive: 0.0047
# recognition: 0.0094
# refer: 0.0047
# refusal: 0.0047
# refused: 0.0047
# regardless: 0.0047
# regeneration: 0.0047
# rejection: 0.0094
# related: 0.0094
# relationship: 0.0283
# relationships: 0.0518
# relaxation: 0.0047
# relaxed: 0.0047
# reliable: 0.0094
# reluctance: 0.0047
# remain: 0.0188
# representative: 0.0047
# represents: 0.0188
# reproduce: 0.0047
# reputation: 0.0094
# require: 0.0047
# requires: 0.0047
# researchers: 0.0047
# reserved: 0.0094
# resist: 0.0047
# resources: 0.0047
# respected: 0.0047
# responsible: 0.0235
# restlessness: 0.0047
# restraints: 0.0141
# restricted: 0.0047
# restriction: 0.0047
# result: 0.0141
# results: 0.0047
# retrogade: 0.0047
# revealed: 0.0047
# revision: 0.0047
# revolution: 0.0047
# revolutionary: 0.0047
# rich: 0.0047
# right: 0.0047
# rigs: 0.0047
# rise: 0.0047
# risks: 0.0094
# rock: 0.0047
# role: 0.0047
# romantic: 0.0094
# roots: 0.0141
# ruin: 0.0047
# ruler: 0.0283
# ruling: 0.0047
# run: 0.0094
# rush: 0.0047
# ruthlessly: 0.0047
# sacrifice: 0.0094
# sage: 0.0047
# sagittarius: 0.0141
# said: 0.0188
# satan: 0.0047
# satisfaction: 0.0047
# satisfy: 0.0047
# saturn: 0.1366
# say: 0.0047
# scale: 0.0047
# scientific: 0.0047
# scorpio: 0.0141
# searching: 0.0094
# second: 0.0141
# secret: 0.0047
# security: 0.0188
# seeking: 0.0047
# self: 0.0424
# selfish: 0.0141
# sense: 0.0188
# senses: 0.0047
# sensitive: 0.0047
# sensory: 0.0047
# sensual: 0.0047
# sensuality: 0.0141
# sent: 0.0047
# separated: 0.0047
# separating: 0.2260
# separation: 0.0047
# services: 0.0047
# set: 0.0047
# sex: 0.0141
# sexes: 0.0094
# sextile: 0.0848
# sexual: 0.0047
# sexuality: 0.0047
# sexy: 0.0047
# shallow: 0.0047
# shallowness: 0.0047
# shatters: 0.0047
# shine: 0.0047
# shortcoming: 0.0047
# shows: 0.0141
# sick: 0.0047
# sides: 0.0047
# sign: 0.0330
# signs: 0.0141
# similar: 0.0094
# single: 0.0141
# situation: 0.0094
# situations: 0.0047
# skills: 0.0047
# skin: 0.0047
# slow: 0.0188
# slowly: 0.0141
# sociable: 0.0047
# social: 0.0424
# society: 0.0094
# solid: 0.0047
# solitude: 0.0094
# solutions: 0.0047
# solve: 0.0094
# somebody: 0.0047
# somewhat: 0.0094
# sort: 0.0047
# soul: 0.0094
# south: 0.0235
# space: 0.0047
# spark: 0.0047
# speakers: 0.0047
# special: 0.0047
# spectrum: 0.0047
# spend: 0.0094
# spiritual: 0.0330
# spirituality: 0.0141
# spite: 0.0047
# spoil: 0.0047
# spring: 0.0047
# square: 0.0706
# stabilisation: 0.0047
# stability: 0.0094
# stable: 0.0094
# stage: 0.0047
# stagnation: 0.0047
# stand: 0.0047
# start: 0.0047
# state: 0.0047
# status: 0.0188
# stay: 0.0047
# steadily: 0.0047
# stimulated: 0.0047
# stop: 0.0141
# stormy: 0.0047
# strategy: 0.0047
# strength: 0.0047
# strict: 0.0047
# strive: 0.0047
# striving: 0.0047
# strong: 0.0330
# strongly: 0.0047
# stubborn: 0.0141
# study: 0.0094
# subconscious: 0.0094
# subconsciously: 0.0141
# subject: 0.0047
# subjective: 0.0141
# subjectivist: 0.0047
# submit: 0.0141
# substance: 0.0047
# subtle: 0.0047
# succeed: 0.0047
# success: 0.0330
# successful: 0.0094
# successfully: 0.0047
# succumb: 0.0047
# succumbing: 0.0047
# suddenly: 0.0047
# suffer: 0.0047
# suffering: 0.0188
# suggests: 0.0283
# suit: 0.0047
# sun: 0.1554
# supervisors: 0.0047
# support: 0.0047
# supports: 0.0094
# suppress: 0.0047
# suppressed: 0.0047
# surgery: 0.0047
# surroundings: 0.0047
# swings: 0.0047
# symbolizes: 0.0377
# symptoms: 0.0047
# tactful: 0.0047
# takes: 0.0047
# taking: 0.0047
# talent: 0.0141
# talented: 0.0094
# talents: 0.0094
# tasks: 0.0047
# taste: 0.0188
# taurus: 0.0235
# teacher: 0.0141
# teachers: 0.0141
# teaching: 0.0047
# tell: 0.0047
# tells: 0.0235
# temperament: 0.0094
# tend: 0.0330
# tendencies: 0.0047
# tendency: 0.0141
# tends: 0.0047
# tension: 0.0047
# tenth: 0.0094
# test: 0.0047
# theatre: 0.0047
# theatrical: 0.0047
# theory: 0.0047
# thing: 0.0235
# things: 0.0659
# think: 0.0047
# thinking: 0.0283
# thorough: 0.0047
# thoughts: 0.0094
# time: 0.0377
# tobacco: 0.0047
# took: 0.0047
# topics: 0.0094
# track: 0.0047
# traditional: 0.0047
# traditions: 0.0047
# traits: 0.0047
# transcendental: 0.0047
# transfer: 0.0047
# transformation: 0.0141
# transformative: 0.0047
# transforming: 0.0047
# transpersonal: 0.0141
# trauma: 0.0141
# tree: 0.0047
# trine: 0.0706
# trouble: 0.0047
# truth: 0.0047
# try: 0.0424
# trying: 0.0141
# twelfth: 0.0188
# typical: 0.0235
# typically: 0.0047
# uncertainty: 0.0047
# unconscious: 0.0047
# unconventional: 0.0141
# undercurrents: 0.0094
# understand: 0.0235
# understanding: 0.0141
# underworld: 0.0094
# unemployment: 0.0094
# unexpected: 0.0094
# unexplainable: 0.0047
# unfortunately: 0.0047
# unfulfillment: 0.0047
# unhealable: 0.0047
# uniqueness: 0.0047
# universal: 0.0047
# unnecessary: 0.0047
# unplanned: 0.0047
# unpredictable: 0.0047
# unquenchable: 0.0047
# unrealistic: 0.0047
# unstable: 0.0330
# unusual: 0.0094
# uranus: 0.1130
# urge: 0.0094
# use: 0.0283
# used: 0.0094
# useless: 0.0094
# uses: 0.0047
# using: 0.0047
# usual: 0.0047
# usually: 0.0565
# valid: 0.0141
# valuable: 0.0047
# valued: 0.0047
# values: 0.0141
# venus: 0.1601
# views: 0.0141
# vigorously: 0.0047
# vigour: 0.0047
# virgo: 0.0094
# vitality: 0.0047
# vivid: 0.0047
# volatility: 0.0047
# waiting: 0.0047
# waning: 0.0047
# want: 0.0659
# wanted: 0.0047
# wardens: 0.0047
# way: 0.0330
# ways: 0.0141
# weaker: 0.0047
# weakness: 0.0047
# wealth: 0.0094
# willing: 0.0094
# wisdom: 0.0094
# wise: 0.0047
# witted: 0.0047
# work: 0.0565
# working: 0.0094
# workplace: 0.0047
# world: 0.0235
# worlds: 0.0047
# wounded: 0.0047
# wrong: 0.0047
# xenophobia: 0.0047
# years: 0.0141
# yield: 0.0047
# young: 0.0141
# youth: 0.0047
# zeus: 0.0047
# zone: 0.0047

# %% [markdown]
# ### Resumen

# %%
import re
import numpy as np
import pandas as pd
from collections import Counter
from nltk.cluster.util import cosine_distance
import networkx as nx

def pre_processing(text):
  sentences = {}
  default_st = nltk.sent_tokenize
  sents = default_st(text=text)

  pattern = r'[^a-zA-z0-9\s]'
  default_wt = nltk.word_tokenize

  for x in sents:

    t= re.sub(pattern, '', x)
    words = default_wt(t)

    new_words = [w.lower() for w in words if not w in nltk_stopwords]
    sentences[x] = new_words

  return sentences

# %%
def sentence_similarity(sent1, sent2):

    all_words = list(set(sent1 + sent2))

    sent1_vals = Counter(sent1)
    sent2_vals = Counter(sent2)

    # convert to word-vectors
    sent1_vect = [sent1_vals.get(word, 0) for word in all_words]
    sent2_vect = [sent2_vals.get(word, 0) for word in all_words]

    return 1 - cosine_distance(sent1_vect, sent2_vect)

def build_similarity_matrix(sentences):
    zero_data = np.zeros(shape=(len(sentences),len(sentences)))
    similarity_matrix = pd.DataFrame(zero_data, columns=sentences.keys(),index=sentences.keys())

    for k1, v1 in sentences.items():
      for k2, v2 in sentences.items():
        if k1 != k2: # ignoramos la diagonal de la matriz
            similarity_matrix[k1][k2] = sentence_similarity(v1, v2)

    return similarity_matrix

def generate_summary(text, top_n=100):

  summarize_text = []

  # 1 - Procesamos el texto de entrada
  sentences =  pre_processing(text)

  # 2 - Generamos la matriz de semejanzas entre las oraciones
  sentence_similarity_martix = build_similarity_matrix(sentences)

  # 3 - Construimos el grafo para el pageRank de las oraciones
  sentence_similarity_graph = nx.from_numpy_array(sentence_similarity_martix.to_numpy())
  scores = nx.pagerank(sentence_similarity_graph)

  # 4 - Ordenamos las oraciones de acuerdo a su score
  ranked_sentence = sorted(((scores[i],s) for i,s in enumerate(sentences)), reverse=True)

  summarize_text = [ranked_sentence[i][1] for i in range(top_n)]

  # 5 - Retornamos el resumen
  return " ".join(summarize_text)

# %%
generate_summary(extracted_text)
# Out:
# <ipython-input-20-6a621f98d746>:21: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   similarity_matrix[k1][k2] = sentence_similarity(v1, v2)
# 'They like to meet people. They may also work on a project together with other people. These people are often optimistic and they enjoy the company of other people. They are creative people who often have the potential to become successful actors. They should learn to make self-sacrifice and show love for other people. They are happy and merry people that have many friends. They use rebellion as means of attracting attention of other people. They get along with young people and relationships with them will benefit them in some way; they will probably provide services to young people or they will work with them. These people may be insecure. They often display great empathy towards physically or mentally handicapped people. These people often lead unconventional life and they do not like to yield to the will of others. The negative side of this aspect is that these people may have poor focus on their life path. Moon Sextile Venus (0°33’, Separating)\nThis harmonious aspect gives people balanced temperament, charming manners and usually also good looks. However, people with this aspect are very impractical. MC Opposition Moon (8°14’, Applying)\nThis aspect can bring instability in professional life and these people often have unstable professions. Node Square Mercury (5°27’, Applying)\nThe positive thing about this aspect is that it gives people intelligence and good life orientation. They are not always considerate towards other people and they sometimes suffer from mental exhaustion. Other aspects\n Ascendant Square Moon (3°22’, Separating)\nThis aspect can bring people instability and they may easily get influenced by others. Moon Sextile Mercury (0°31’, Separating)\nThis harmonious aspect give people good memory, poetic soul and the ability to understand others. They are often very intelligent. Sun Square Mars (7°41’, Separating)\nThis aspect give these people physical strength and the ability to work hard. The Sun in the fifth house gives people considerable amount of self-confidence. Sun Contra-Parallel Saturn (0°43’)\nThis aspect creates two groups of people. Moon Trine Saturn (5°22’, Applying)\nThis harmonious aspect gives people emotional stability. Venus Opposition Saturn (5°56’, Separating)\nPeople with this aspect are responsible, reserved and hesitant. Mercury Opposition Saturn (5°54’, Separating)\nThis aspect gives people serious, conservative and practical mental processes. Node Sextile Jupiter (2°54’, Separating)\nThe positive thing about this aspect is that these people are confident in their abilities and this helps them overcome challenges in life. more -»\n\nSun in the 5th House\nThe Sun in the fifth house creates very creative people with a very strong desire for self-expression. These people love their job and they often have authority in this area. These people have democratic ideals but they are often too authoritative. Sun Contra-Parallel Uranus (0°38’)\nThis aspect creates people that are too individualistic, selfish and eccentric. Node Square Venus (5°25’, Applying)\nThe positive thing about this aspect is that these people are often pleasant, graceful, sexy and affectionate. These people need others to notice and appreciate them. These people are also talented public speakers. These people tend to succumb to what society expects from people of their social status, class, belief, race etc. It creates romantic and popular people who love life. These people have the tendency to focus on the wrong side of life. These people often have lower self-esteem that can be improved by good work. Venus Contra-Parallel Neptune (1°03’)\nThis aspect causes considerable romantic feelings that complicate life and put these people into intricate situations. The ruler of the Ascendant (Saturn) in the 12th House\nThese people are predestined to hide and run away from themselves, to subject themselves to illusions, and to closing themselves to others. Venus Contra-Parallel Saturn (0°53’)\nPeople with this aspect are respons ...
